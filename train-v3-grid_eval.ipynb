# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np
import random
import pandas as pd
from torch import nn
from glob import glob
from tqdm.auto import tqdm
from torchaudio import transforms as T
import pytorch_lightning as pl 
from maatool.data.feats_itdataset_v2 import FeatsIterableDatasetV2
from maatool.models.transformer import TransformerWithSinPos
torch.cuda.is_available()
# Out:
# True

# %%
import logging
import logging.config

def configure_logging(log_level):
    handlers =  {
            "maa": {
                "class": "logging.StreamHandler",
                "formatter": "maa_basic",
                "stream": "ext://sys.stdout",
            }
    }
    CONFIG = {
        "version": 1,
        "disable_existing_loggers": False,
        "formatters": {"maa_basic": {"format": '%(asctime)s %(name)s %(pathname)s:%(lineno)d - %(levelname)s - %(message)s'}},
        "handlers": handlers,
        "loggers": {"maa": {"handlers": handlers.keys(), "level": log_level}},
        "root": {"handlers": handlers.keys(), "level": log_level}
    }
    logging.config.dictConfig(CONFIG)
configure_logging("INFO")

# %%
torch.distributed.is_initialized()
# Out:
# False

# %%
from collections import defaultdict

# %%
def get_new_tgt(prev_tgt, hyp_logprobs, logits, topk=4):
    """
    prev_tgt - (T, N_hyp)
    hyp_logprobs - (N_hyp, )
    logits - (N_hyp, C)
    """
    assert len(prev_tgt.shape) == 2, f"{prev_tgt.shape=}"
    assert len(hyp_logprobs.shape) == 1, f"{hyp_logprobs.shape=}"
    assert len(logits.shape) == 2, f"{logits.shape=}"
    assert prev_tgt.shape[1] == hyp_logprobs.shape[0] == logits.shape[0], (
        f"{prev_tgt.shape=} {hyp_logprobs.shape=} {logits.shape=}"
    )
        
    nt_topk_logits, nt_topk_idx = logits.topk(k=topk, axis=-1)
    #print("nt_topk_idx", nt_topk_idx, nt_topk_idx.shape)
    # (N, K)
    next_tokens = nt_topk_idx.T.reshape(1, -1)
    #print("next_tokens", next_tokens, next_tokens.shape)
    # (1, N*(repeat k times)) 
    # (T, N*(repeat k times))  
    new_hyp_tgt = torch.concatenate([prev_tgt.repeat(1, topk), next_tokens], axis=0)
    #print(f"{new_hyp_tgt=}", new_hyp_tgt.shape)
    # (T+1, N*(repeat k times))
    new_scores = nt_topk_logits.T.reshape(-1)
    # N*(repeat k times)
    prew_scores = hyp_logprobs.repeat(topk)
    #print("prew_scores", prew_scores)
    # N*(repeat k times)
    new_hyp_logprob = prew_scores + new_scores
    #print("new_hyp_logprob", new_hyp_logprob)
    new_hyp_logprob, idx = new_hyp_logprob.topk(k=topk)
    #print(idx)
    new_hyps = new_hyp_tgt[:, idx]
    #print("new_hyps", new_hyps, new_hyp_logprob)
    # (T+1, N*k), (N,)
    return new_hyps, new_hyp_logprob
    

    
tgt, logits = get_new_tgt(torch.LongTensor([[1,]]), torch.tensor([-1.]), torch.tensor([[-3, -4, -7, -2, -5]]))
print(">>>>\n", tgt, logits)
get_new_tgt(tgt, logits, torch.tensor([[100,    110,  200], 
                                       [100,    110,  200], 
                                       [100,    110,  200], 
                                       [100,    110,  200]]), topk=2)
# Out:
# >>>>
#  tensor([[1, 1, 1, 1],
#         [3, 0, 1, 4]]) tensor([-3., -4., -5., -6.])
# (tensor([[1, 1],
#          [3, 0],
#          [2, 2]]),
#  tensor([197., 196.]))

# %%
def sep_ready_tgt(tgt, logprobs, eos_id=2):
    """
    tgt - (T, N)
    logprobs - (N,)
    """
    assert tgt.shape[1] == logprobs.shape[0], (
        f"{tgt.shape=} {logprobs.shape=}"
    )
    
    is_end_mask = ((tgt == eos_id).sum(axis=0) > 0)
    # (N,)
    #print(is_end_mask)
    ready_tgt = tgt[:, is_end_mask]
    ready_logprobs = logprobs[is_end_mask]
    
    ready_list = [(l.cpu().item(), t.cpu().tolist()) for l, t in zip(ready_logprobs, ready_tgt.T)]

    not_ready_tgt = tgt[:, ~is_end_mask]
    not_ready_logprobs = logprobs[~is_end_mask]
    assert not_ready_tgt.shape[1] == not_ready_logprobs.shape[0], (
        f"{not_ready_tgt.shape[1]=} {not_ready_logprobs.shape[0]=}"
    )
    return ready_list, not_ready_tgt, not_ready_logprobs


sep_ready_tgt(torch.LongTensor([[1, 1], [2, 3]]), torch.tensor([-1., -3]))
# Out:
# ([(-1.0, [1, 2])],
#  tensor([[1],
#          [3]]),
#  tensor([-3.]))

# %%
def set_random_seed(seed):
    if seed < 0:
        seed = seed_from_time()
    random.seed(seed)
    np.random.seed(seed)
    torch.random.manual_seed(seed)
set_random_seed(42)

class SwipeTransformerRecognizer(pl.LightningModule):
    def __init__(self, backbone, learning_rate=1e-4, speed=42):
        super().__init__()
        self.save_hyperparameters(ignore=['backbone'])
        self.backbone = backbone
        self.ce_loss = nn.CrossEntropyLoss(ignore_index=0, reduction='mean')
#         self.spec_aug = torch.nn.Sequential(
#             #T.FrequencyMasking(freq_mask_param=24),
#             #T.TimeMasking(time_mask_param=30),
#             T.TimeMasking(time_mask_param=24), # last dim masking
#         )
        set_random_seed(speed)

    def forward(self, feats, **kwargs):
        # (T, N, E)
#         feats = feats.permute(1, 2, 0)
#         # (N, E, T)
#         feats = self.spec_aug(feats).permute(2, 0, 1)
#         if self.training:
#             #logging.info("Apply specaug")
#             feats = self.spec_aug(feats)
        # (T, N, E)
        return self.backbone(feats, **kwargs)
    
    def get_loss(self, batch):
        # batch - (Time, Batch, ...)
        feats = batch['feats']
        # (Time, Batch, num_feats)
        tgt = batch['targets'][:-1]
        tgt_key_padding_mask = batch['tgt_key_padding_mask'][:, 1:] 
        # (Batch, Seq-1)
        
        logits = self.forward(feats=feats, 
                              tgt=tgt, 
                              src_key_padding_mask=batch['src_key_padding_mask'], 
                              tgt_key_padding_mask=tgt_key_padding_mask) 
        # (Seq-1, Batch, C)
        S, N, C = logits.shape
        targets = batch['targets'][1:]
        # (Seq-1, Batch)
        # print("loss ", logits.shape, targets.shape)
        loss = self.ce_loss(logits.view(-1, C), targets.reshape(-1))
        
        return loss

        
    def training_step(self, batch, batch_idx):
        loss = self.get_loss(batch)
        self.log('train_loss', loss, on_epoch=True, prog_bar=True,  batch_size=len(batch['uids']))
        return loss

    def validation_step(self, batch, batch_idx):
        loss = self.get_loss(batch)
        self.log('valid_loss', loss, on_epoch=True, prog_bar=True, on_step=True,  batch_size=len(batch['uids']))

    def test_step(self, batch, batch_idx):
        loss = self.get_loss(batch)
        self.log('test_loss', loss,  batch_size=len(batch['uids']))

    def configure_optimizers(self):
        # self.hparams available because we called self.save_hyperparameters()
        return torch.optim.Adam(self.parameters(), lr=self.hparams.learning_rate)

    @staticmethod
    def add_model_specific_args(parent_parser):
        parser = ArgumentParser(parents=[parent_parser], add_help=False)
        parser.add_argument('--learning_rate', type=float, default=0.0001)
        return parser
    
    def predict_topk(self, dl, tokenizer, topk=4, bos_id=1, eos_id=2, max_out_len=26, device='cuda'):
        self.eval()
        utt2word= defaultdict(list)
        utt2logs = defaultdict(list)
        pbar = tqdm(dl)
        with torch.no_grad():
            for batch in pbar:
                batch = {k: v.to(device) if isinstance(v, torch.Tensor) else v for k, v in batch.items()}
                memory = self.backbone.forward_encoder(batch['feats'], 
                                                  src_key_padding_mask=batch['src_key_padding_mask'])
                assert memory.shape[1] == 1, f"{memory.shape=}"
                # (SrcTime, Batch, E)
                tgt = torch.full(size=(1, 1), 
                                 fill_value=bos_id, 
                                 dtype=torch.long, 
                                 device=memory.device)
                hyp_logprobs = torch.zeros((1), device=memory.device)
                tgt_ready = []
                mkpm = batch['src_key_padding_mask']
                for l in range(max_out_len):
                    #print(f"{tgt.shape=}")
                    tgt_logits = self.backbone.forward_decoder(tgt, 
                                                        memory.repeat(1, tgt.shape[1], 1), 
                                                        memory_key_padding_mask=mkpm.repeat((tgt.shape[1], 1)))
                    tgt_logits = tgt_logits.log_softmax(dim=-1)

                    new_tgt, logprobs = get_new_tgt(tgt, hyp_logprobs, tgt_logits[-1], topk=topk)
                    ready, tgt, hyp_logprobs = sep_ready_tgt(new_tgt, logprobs)
                    tgt_ready.extend(ready)
                    if len(tgt_ready) >= topk:
                        break

                uid = batch['uids'][0]
                if len(tgt_ready) == 0:
                    logging.warning(f"tgt_ready is 0 for {uid}. {tgt.shape=}. Use all hyps as ready hyps")
                    tgt_ready = [(l.cpu().item(), t.cpu().tolist()) for l, t in zip(hyp_logprobs, tgt.T)]

                out_indices = []
                for logprob, indices in sorted(tgt_ready, reverse=True):
                    joined = tokenizer.decode(indices) #.split()[0]
                    utt2word[uid].append(joined)
                    utt2logs[uid].append(logprob)
                d = '|'+'|'.join(utt2word[uid]) + "|"
                pbar.set_description(f"{d}".ljust(40, '=')[:40], refresh=False)
        return utt2word, utt2logs

# %%
model = TransformerWithSinPos(feats_dim=37, num_tokens=500, num_decoder_layers=8)
pl_module = SwipeTransformerRecognizer(model)
#pl_module = SwipeTransformerRecognizer.load_from_checkpoint('exp/models/transformer_sc/lightning_logs/version_50424998/checkpoints/last.ckpt',backbone=model, map_location='cpu' )
#pl_module = SwipeTransformerRecognizer.load_from_checkpoint('exp/models/t_finetune_with_sa/lightning_logs/version_50448424/checkpoints/last.ckpt',backbone=model, map_location='cpu' )
# Out:
# PositionalEncoding shape is torch.Size([400, 1, 512])

# %%
val_ds = FeatsIterableDatasetV2([f"ark:data_feats/valid/feats.ark"], 
                             targets_rspecifier='ark:exp/bpe500/valid-text.int', 
                                shuffle=False,
                               bos_id=1, 
                               eos_id=2,
                               batch_first=False)
val_dataloader = torch.utils.data.DataLoader(val_ds, batch_size=1, collate_fn=val_ds.collate_pad)

train_ds = FeatsIterableDatasetV2([f"ark:{f}" for f in sorted(glob("data_feats/train/feats.*.ark"))],
                                  targets_rspecifier='ark:exp/bpe500/train-text.int.ark', 
                                  shuffle=True,
                                  bos_id=1, 
                                  eos_id=2, 
                                 batch_first=False)

train_dataloader = torch.utils.data.DataLoader(train_ds, batch_size=24, collate_fn=train_ds.collate_pad, 
                                                num_workers=8)
# Out:
# 2023-11-11 15:45:10,481 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:44 - INFO - Loading targets from ark:exp/bpe500/valid-text.int
# Loading targets...: 0it [00:00, ?it/s]
# 2023-11-11 15:45:10,796 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:44 - INFO - Loading targets from ark:exp/bpe500/train-text.int.ark
# Loading targets...: 0it [00:00, ?it/s]

# %%
trainer = pl.Trainer(max_epochs=3, log_every_n_steps=400, reload_dataloaders_every_n_epochs=1,
                    default_root_dir='exp/models/t_finetune_with_sa',
                    callbacks=[pl.callbacks.TQDMProgressBar(refresh_rate=100),
                              pl.callbacks.ModelCheckpoint(every_n_train_steps=10000,
                                                          save_last=True)],
                    accumulate_grad_batches=8,
                    val_check_interval=20000)
                    #check_val_every_n_epoch=1)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
result = trainer.test(pl_module, val_dataloader)
print(result)
# 0.20462335646152496
# [{'test_loss': 2.9619081020355225}]
# v3.11.11 [{'test_loss': 0.6646422147750854}] /0.27 / 0.23
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# Testing: 0it [00:00, ?it/s]
# 2023-11-11 11:51:08,879 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │    0.20462335646152496    │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.20462335646152496}]

# %%
trainer.fit(pl_module, train_dataloader, val_dataloader)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type                  | Params
# ---------------------------------------------------
# 0 | backbone | TransformerWithSinPos | 53.1 M
# 1 | ce_loss  | CrossEntropyLoss      | 0
# ---------------------------------------------------
# 53.1 M    Trainable params
# 0         Non-trainable params
# 53.1 M    Total params
# 212.322   Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: 0it [00:00, ?it/s]
# 2023-11-11 15:46:54,930 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/utilities/data.py:120: UserWarning: Your `IterableDataset` has `__len__` defined. In combination with multi-process data loading (when num_workers > 1), `__len__` could be inaccurate if each worker is not configured independently to avoid having duplicate data.
#   rank_zero_warn(
# 2023-11-11 15:46:56,000 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.108.ark
# 2023-11-11 15:46:55,999 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.63.ark
# 2023-11-11 15:46:56,000 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.93.ark
# 2023-11-11 15:46:56,046 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.80.ark
# 2023-11-11 15:46:56,052 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.89.ark
# 2023-11-11 15:46:56,055 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.110.ark
# 2023-11-11 15:46:56,087 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.104.ark
# Training: 0it [00:00, ?it/s]
# 2023-11-11 15:46:57,180 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.1.ark
# 2023-11-11 15:46:57,180 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.42.ark
# 2023-11-11 15:46:57,180 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.14.ark
# 2023-11-11 15:46:57,233 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.123.ark
# 2023-11-11 15:46:57,258 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.45.ark
# 2023-11-11 15:46:57,260 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.105.ark
# 2023-11-11 15:46:57,259 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.46.ark
# 2023-11-11 15:46:57,259 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.111.ark
# 2023-11-11 16:12:19,239 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.78.ark
# 2023-11-11 16:12:19,360 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.114.ark
# 2023-11-11 16:12:19,463 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.108.ark
# 2023-11-11 16:12:19,593 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.88.ark
# 2023-11-11 16:12:19,674 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.96.ark
# 2023-11-11 16:12:19,763 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.97.ark
# 2023-11-11 16:12:19,846 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.76.ark
# 2023-11-11 16:12:19,930 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.7.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 16:19:31,510 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 16:39:40,876 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.27.ark
# 2023-11-11 16:39:41,004 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.20.ark
# 2023-11-11 16:39:41,095 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.87.ark
# 2023-11-11 16:39:41,207 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.101.ark
# 2023-11-11 16:39:41,297 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.89.ark
# 2023-11-11 16:39:41,380 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.60.ark
# 2023-11-11 16:39:41,465 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.32.ark
# 2023-11-11 16:39:41,577 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.91.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 16:53:55,233 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 17:06:58,711 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.63.ark
# 2023-11-11 17:06:58,788 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.13.ark
# 2023-11-11 17:06:58,893 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.43.ark
# 2023-11-11 17:06:58,979 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.44.ark
# 2023-11-11 17:06:59,081 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.81.ark
# 2023-11-11 17:06:59,162 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.75.ark
# 2023-11-11 17:06:59,254 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.98.ark
# 2023-11-11 17:06:59,383 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.112.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 17:28:27,919 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 17:34:23,350 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.128.ark
# 2023-11-11 17:34:23,476 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.79.ark
# 2023-11-11 17:34:23,586 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.122.ark
# 2023-11-11 17:34:23,690 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.15.ark
# 2023-11-11 17:34:23,791 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.124.ark
# 2023-11-11 17:34:23,876 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.118.ark
# 2023-11-11 17:34:23,944 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.47.ark
# 2023-11-11 17:34:24,064 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.26.ark
# 2023-11-11 17:59:55,209 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.56.ark
# 2023-11-11 17:59:55,301 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.35.ark
# 2023-11-11 17:59:55,400 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.21.ark
# 2023-11-11 17:59:55,505 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.116.ark
# 2023-11-11 17:59:55,598 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.30.ark
# 2023-11-11 17:59:55,711 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.68.ark
# 2023-11-11 17:59:55,834 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.126.ark
# 2023-11-11 17:59:55,955 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.12.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 18:03:04,219 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 18:27:16,691 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.34.ark
# 2023-11-11 18:27:16,775 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.64.ark
# 2023-11-11 18:27:16,874 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.36.ark
# 2023-11-11 18:27:16,971 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.95.ark
# 2023-11-11 18:27:17,048 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.16.ark
# 2023-11-11 18:27:17,162 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.24.ark
# 2023-11-11 18:27:17,264 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.90.ark
# 2023-11-11 18:27:17,374 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.33.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 18:37:27,889 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 18:54:43,010 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.120.ark
# 2023-11-11 18:54:43,096 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.28.ark
# 2023-11-11 18:54:43,168 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.29.ark
# 2023-11-11 18:54:43,311 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.22.ark
# 2023-11-11 18:54:43,433 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.52.ark
# 2023-11-11 18:54:43,541 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.110.ark
# 2023-11-11 18:54:43,619 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.18.ark
# 2023-11-11 18:54:43,709 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.84.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 19:12:01,761 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 19:22:04,691 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.2.ark
# 2023-11-11 19:22:04,787 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.57.ark
# 2023-11-11 19:22:04,912 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.94.ark
# 2023-11-11 19:22:05,002 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.59.ark
# 2023-11-11 19:22:05,092 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.6.ark
# 2023-11-11 19:22:05,201 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.39.ark
# 2023-11-11 19:22:05,306 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.54.ark
# 2023-11-11 19:22:05,393 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.62.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 19:46:36,027 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 19:49:27,020 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.70.ark
# 2023-11-11 19:49:27,099 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.107.ark
# 2023-11-11 19:49:27,180 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.65.ark
# 2023-11-11 19:49:27,285 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.66.ark
# 2023-11-11 19:49:27,367 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.38.ark
# 2023-11-11 19:49:27,453 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.31.ark
# 2023-11-11 19:49:27,561 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.25.ark
# 2023-11-11 19:49:27,651 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.99.ark
# 2023-11-11 20:15:08,222 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.85.ark
# 2023-11-11 20:15:08,309 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.71.ark
# 2023-11-11 20:15:08,421 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.115.ark
# 2023-11-11 20:15:08,512 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.73.ark
# 2023-11-11 20:15:08,582 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.117.ark
# 2023-11-11 20:15:08,665 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.53.ark
# 2023-11-11 20:15:08,743 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.61.ark
# 2023-11-11 20:15:08,826 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.19.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 20:21:24,926 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 20:42:51,060 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.113.ark
# 2023-11-11 20:42:51,142 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.86.ark
# 2023-11-11 20:42:51,256 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.72.ark
# 2023-11-11 20:42:51,355 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.37.ark
# 2023-11-11 20:42:51,443 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.74.ark
# 2023-11-11 20:42:51,540 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.103.ark
# 2023-11-11 20:42:51,626 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.104.ark
# 2023-11-11 20:42:51,716 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.48.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 20:56:29,987 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 21:10:46,824 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.49.ark
# 2023-11-11 21:10:46,936 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.5.ark
# 2023-11-11 21:10:47,008 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.58.ark
# 2023-11-11 21:10:47,127 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.3.ark
# 2023-11-11 21:10:47,206 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.102.ark
# 2023-11-11 21:10:47,316 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.125.ark
# 2023-11-11 21:10:47,415 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.83.ark
# 2023-11-11 21:10:47,504 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.55.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 21:31:17,943 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 21:38:16,192 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.92.ark
# 2023-11-11 21:38:16,281 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.93.ark
# 2023-11-11 21:38:16,359 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.50.ark
# 2023-11-11 21:38:16,495 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.80.ark
# 2023-11-11 21:38:16,574 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.23.ark
# 2023-11-11 21:38:16,679 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.82.ark
# 2023-11-11 21:38:16,747 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.4.ark
# 2023-11-11 21:38:16,832 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.127.ark
# 2023-11-11 22:03:52,211 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.41.ark
# 2023-11-11 22:03:52,316 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.121.ark
# 2023-11-11 22:03:52,445 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.8.ark
# 2023-11-11 22:03:52,516 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.51.ark
# 2023-11-11 22:03:52,621 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.67.ark
# 2023-11-11 22:03:52,725 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.9.ark
# 2023-11-11 22:03:52,792 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.69.ark
# 2023-11-11 22:03:52,896 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.40.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 22:05:58,321 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 22:31:20,059 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.106.ark
# 2023-11-11 22:31:20,142 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.10.ark
# 2023-11-11 22:31:20,232 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.100.ark
# 2023-11-11 22:31:20,310 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.109.ark
# 2023-11-11 22:31:20,374 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.11.ark
# 2023-11-11 22:31:20,461 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.17.ark
# 2023-11-11 22:31:20,573 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.119.ark
# 2023-11-11 22:31:20,722 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.77.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 22:40:40,835 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 22:59:23,799 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.3.ark
# 2023-11-11 22:59:23,798 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.106.ark
# 2023-11-11 22:59:23,799 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.45.ark
# 2023-11-11 22:59:23,798 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.20.ark
# 2023-11-11 22:59:23,799 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.14.ark
# 2023-11-11 22:59:23,802 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.31.ark
# 2023-11-11 22:59:23,852 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.69.ark
# 2023-11-11 22:59:25,169 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.35.ark
# 2023-11-11 22:59:25,169 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.87.ark
# 2023-11-11 22:59:25,172 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.45.ark
# 2023-11-11 22:59:25,169 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.128.ark
# 2023-11-11 22:59:25,169 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.88.ark
# 2023-11-11 22:59:25,209 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.60.ark
# 2023-11-11 22:59:25,213 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.76.ark
# 2023-11-11 22:59:25,284 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.12.ark
# 2023-11-11 23:24:51,216 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.106.ark
# 2023-11-11 23:24:51,281 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.5.ark
# 2023-11-11 23:24:51,364 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.65.ark
# 2023-11-11 23:24:51,450 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.66.ark
# 2023-11-11 23:24:51,541 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.89.ark
# 2023-11-11 23:24:51,634 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.118.ark
# 2023-11-11 23:24:51,725 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.4.ark
# 2023-11-11 23:24:51,836 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.33.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-11 23:32:01,782 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 23:52:26,064 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.41.ark
# 2023-11-11 23:52:26,134 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.121.ark
# 2023-11-11 23:52:26,215 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.36.ark
# 2023-11-11 23:52:26,309 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.59.ark
# 2023-11-11 23:52:26,377 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.30.ark
# 2023-11-11 23:52:26,459 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.46.ark
# 2023-11-11 23:52:26,584 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.98.ark
# 2023-11-11 23:52:26,678 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.26.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 00:06:52,815 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 00:20:07,211 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.34.ark
# 2023-11-12 00:20:07,300 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.86.ark
# 2023-11-12 00:20:07,437 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.115.ark
# 2023-11-12 00:20:07,583 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.15.ark
# 2023-11-12 00:20:07,665 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.74.ark
# 2023-11-12 00:20:07,753 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.110.ark
# 2023-11-12 00:20:07,843 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.47.ark
# 2023-11-12 00:20:07,922 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.105.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 00:41:50,947 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 00:47:51,300 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.49.ark
# 2023-11-12 00:47:51,404 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.93.ark
# 2023-11-12 00:47:51,475 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.58.ark
# 2023-11-12 00:47:51,574 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.37.ark
# 2023-11-12 00:47:51,690 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.16.ark
# 2023-11-12 00:47:51,802 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.24.ark
# 2023-11-12 00:47:51,907 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.25.ark
# 2023-11-12 00:47:52,029 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.84.ark
# 2023-11-12 01:13:31,954 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.63.ark
# 2023-11-12 01:13:32,043 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.28.ark
# 2023-11-12 01:13:32,172 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.100.ark
# 2023-11-12 01:13:32,306 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.51.ark
# 2023-11-12 01:13:32,388 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.117.ark
# 2023-11-12 01:13:32,489 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.17.ark
# 2023-11-12 01:13:32,573 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.83.ark
# 2023-11-12 01:13:32,656 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.62.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 01:16:40,729 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 01:41:06,929 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.78.ark
# 2023-11-12 01:41:07,024 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.10.ark
# 2023-11-12 01:41:07,127 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.50.ark
# 2023-11-12 01:41:07,219 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.80.ark
# 2023-11-12 01:41:07,313 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.67.ark
# 2023-11-12 01:41:07,422 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.82.ark
# 2023-11-12 01:41:07,531 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.18.ark
# 2023-11-12 01:41:07,614 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.55.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 01:51:38,629 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 02:08:58,481 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.120.ark
# 2023-11-12 02:08:58,587 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.71.ark
# 2023-11-12 02:08:58,668 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.108.ark
# 2023-11-12 02:08:58,736 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.44.ark
# 2023-11-12 02:08:58,842 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.81.ark
# 2023-11-12 02:08:58,928 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.68.ark
# 2023-11-12 02:08:58,996 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.104.ark
# 2023-11-12 02:08:59,085 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.19.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 02:26:34,124 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 02:36:51,040 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.85.ark
# 2023-11-12 02:36:51,135 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.42.ark
# 2023-11-12 02:36:51,248 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.14.ark
# 2023-11-12 02:36:51,331 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.3.ark
# 2023-11-12 02:36:51,433 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.23.ark
# 2023-11-12 02:36:51,533 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.75.ark
# 2023-11-12 02:36:51,623 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.126.ark
# 2023-11-12 02:36:51,724 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.91.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 03:01:53,212 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 03:04:50,248 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.2.ark
# 2023-11-12 03:04:50,335 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.13.ark
# 2023-11-12 03:04:50,437 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.43.ark
# 2023-11-12 03:04:50,567 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.101.ark
# ...
# 2023-11-12 04:53:42,961 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.97.ark
# 2023-11-12 04:53:43,075 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.111.ark
# 2023-11-12 04:53:43,184 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.40.ark
# 2023-11-12 05:19:08,839 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.27.ark
# 2023-11-12 05:19:08,961 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.64.ark
# 2023-11-12 05:19:09,063 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.94.ark
# 2023-11-12 05:19:09,162 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.116.ark
# 2023-11-12 05:19:09,266 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.6.ark
# 2023-11-12 05:19:09,360 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.53.ark
# 2023-11-12 05:19:09,440 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.90.ark
# 2023-11-12 05:19:09,524 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.127.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 05:21:16,175 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 05:46:55,844 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.113.ark
# 2023-11-12 05:46:55,923 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.57.ark
# 2023-11-12 05:46:55,998 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.8.ark
# 2023-11-12 05:46:56,100 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.123.ark
# 2023-11-12 05:46:56,178 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.102.ark
# 2023-11-12 05:46:56,297 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.103.ark
# 2023-11-12 05:46:56,380 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.61.ark
# 2023-11-12 05:46:56,474 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.99.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 05:56:25,695 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 06:14:47,509 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.64.ark
# 2023-11-12 06:14:47,510 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.66.ark
# 2023-11-12 06:14:47,509 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.87.ark
# 2023-11-12 06:14:47,512 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.30.ark
# 2023-11-12 06:14:47,544 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.126.ark
# 2023-11-12 06:14:47,509 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.49.ark
# 2023-11-12 06:14:47,546 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.103.ark
# 2023-11-12 06:14:48,920 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.63.ark
# 2023-11-12 06:14:48,921 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.22.ark
# 2023-11-12 06:14:48,923 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.30.ark
# 2023-11-12 06:14:48,920 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.35.ark
# 2023-11-12 06:14:48,920 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.50.ark
# 2023-11-12 06:14:48,938 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.75.ark
# 2023-11-12 06:14:48,954 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.90.ark
# 2023-11-12 06:14:49,007 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.7.ark
# 2023-11-12 06:40:25,831 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.41.ark
# 2023-11-12 06:40:25,957 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.107.ark
# 2023-11-12 06:40:26,048 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.115.ark
# 2023-11-12 06:40:26,142 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.123.ark
# 2023-11-12 06:40:26,235 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.74.ark
# 2023-11-12 06:40:26,316 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.24.ark
# 2023-11-12 06:40:26,397 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.111.ark
# 2023-11-12 06:40:26,478 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.26.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 06:47:37,144 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 07:08:07,273 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.49.ark
# 2023-11-12 07:08:07,371 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.64.ark
# 2023-11-12 07:08:07,488 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.14.ark
# 2023-11-12 07:08:07,595 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.15.ark
# 2023-11-12 07:08:07,688 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.89.ark
# 2023-11-12 07:08:07,803 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.68.ark
# 2023-11-12 07:08:07,897 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.54.ark
# 2023-11-12 07:08:07,981 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.91.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 07:22:36,407 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 07:35:50,081 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.106.ark
# 2023-11-12 07:35:50,145 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.28.ark
# 2023-11-12 07:35:50,206 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.108.ark
# 2023-11-12 07:35:50,337 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.73.ark
# 2023-11-12 07:35:50,451 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.11.ark
# 2023-11-12 07:35:50,533 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.82.ark
# 2023-11-12 07:35:50,636 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.76.ark
# 2023-11-12 07:35:50,727 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.112.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 07:57:25,948 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-12 08:03:29,035 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.70.ark
# 2023-11-12 08:03:29,107 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.93.ark
# 2023-11-12 08:03:29,216 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.65.ark
# 2023-11-12 08:03:29,327 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.95.ark
# 2023-11-12 08:03:29,418 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.67.ark
# 2023-11-12 08:03:29,509 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.17.ark
# 2023-11-12 08:03:29,576 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.119.ark
# 2023-11-12 08:03:29,690 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.77.ark
# 2023-11-12 08:29:01,379 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.56.ark
# 2023-11-12 08:29:01,478 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.13.ark
# 2023-11-12 08:29:01,609 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.122.ark
# 2023-11-12 08:29:01,712 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.66.ark
# 2023-11-12 08:29:01,832 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.6.ark
# 2023-11-12 08:29:01,920 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.46.ark
# 2023-11-12 08:29:02,029 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.104.ark
# 2023-11-12 08:29:02,116 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/train/feats.127.ark
# Validation: 0it [00:00, ?it/s]
# 2023-11-12 08:32:10,597 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/trainer/call.py:54: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
import sentencepiece as spm
import math
tokenizer = spm.SentencePieceProcessor('exp/bpe500/model.model')

# %%
utt2words, utt2logs = pl_module.cuda().predict_topk(val_dataloader, tokenizer=tokenizer, topk=10, device='cuda')
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-11-11 12:48:29,606 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:81: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:206.)
#   'feats': torch.as_tensor(feats, dtype=torch.float32),

# %%
utt2words
# Out:
# defaultdict(list,
#             {'valid-0': ['на',
#               'нас',
#               'на на',
#               'наа',
#               'нана',
#               'нам',
#               'наи',
#               'нача',
#               'напа',
#               'на-а',
#               'на-на'],
#              'valid-1': ['все',
#               'всем',
#               'вчера',
#               'усе',
#               'све',
#               'осве',
#               'се',
#               'свет',
#               'свасе',
#               'ава',
#               'аван'],
#              'valid-2': ['этом',
#               'этом',
#               'этим',
#               'это',
#               'потом',
#               'эти',
#               'эта',
#               'этому',
#               'этот',
#               'дом',
#               'этими'],
#              'valid-3': ['добрый',
#               'доброй',
#               'добрые',
#               'добрый',
#               'добрым',
#               'доброе',
#               'добой',
#               'дорогой',
#               'домой',
#               'давай',
#               'добровольный'],
#              'valid-4': ['девочка',
#               'девочкам',
#               'девочками',
#               'девочках',
#               'девочки',
#               'девчонка',
#               'дневолочка',
#               'девочке',
#               'девочкал',
#               'девочкар',
#               'девочкарск'],
#              'valid-5': ['сказала',
#               'сказал',
#               'сказали',
#               'сказало',
#               'сказать',
#               'сказала',
#               'показала',
#               'сказала',
#               'сказав',
#               'реазала',
#               'сказалась',
#               'сказался',
#               'сказал',
#               'сказали',
#               'сказало',
#               'реазали'],
#              'valid-6': ['скинь',
#               'скиньте',
#               'кинь',
#               'спинь',
#               'скиньть',
#               'скинью',
#               'скинь',
#               'скиньсь',
#               'скинься',
#               'сколько'],
#              'valid-7': ['гены',
#               'геев',
#               'гена',
#               'гев',
#               'гнев',
#               'генев',
#               'гна',
#               'гену',
#               'генера',
#               'генее'],
#              'valid-8': ['тобой',
#               'отой',
#               'отбой',
#               'только',
#               'добрый',
#               'отойду',
#               'обой',
#               'голобой',
#               'мобой',
#               'голой',
#               'гобой',
#               'молодой'],
#              'valid-9': ['быстро',
#               'басса',
#               'бача',
#               'баса',
#               'быстрая',
#               'быстрее',
#               'баса',
#               'баста',
#               'буса',
#               'быстрей',
#               'быстра',
#               'басс',
#               'бассет',
#               'бассей'],
#              'valid-10': ['есть',
#               'ест',
#               'если',
#               'месть',
#               'есте',
#               'насть',
#               'весь',
#               'естью',
#               'естю',
#               'есь',
#               'есить',
#               'естб'],
#              'valid-11': ['да',
#               'да-да',
#               'за',
#               'дар',
#               'дала',
#               'дав',
#               'два',
#               'дора',
#               'жара',
#               'дра',
#               'жада',
#               'да-а'],
#              'valid-12': ['муж',
#               'мужа',
#               'муже',
#               'мужем',
#               'мужчина',
#               'муз',
#               'мужик',
#               'мужика',
#               'муд',
#               'мух',
#               'мужчин',
#               'мужчину',
#               'мужчине',
#               'мужчины',
#               'мужиках',
#               'мужчино'],
#              'valid-13': ['щас',
#               'ща',
#               'зачем',
#               'щас',
#               'шам',
#               'щаас',
#               'щас',
#               'шум',
#               'зам',
#               'замас',
#               'щеч'],
#              'valid-14': ['она',
#               'ога',
#               'опа',
#               'они',
#               'оша',
#               'окна',
#               'на',
#               'она',
#               'он',
#               'ага'],
#              'valid-15': ['проблема',
#               'проблемы',
#               'проблемам',
#               'проблем',
#               'пробема',
#               'проблемка',
#               'проблеме',
#               'пробьема',
#               'проблему',
#               'по-любому',
#               'пробума',
#               'пробка',
#               'пробки'],
#              'valid-16': ['билайн',
#               'билан',
#               'билаце',
#               'битовые',
#               'билае',
#               'битраце',
#               'битан',
#               'битлайн',
#               'битлан',
#               'битойн',
#               'билайнс',
#               'билайнер',
#               'билайнф',
#               'билайнра'],
#              'valid-17': ['уже',
#               'уде',
#               'нужен',
#               'ужел',
#               'уже',
#               'же',
#               'уроде',
#               'уле',
#               'ужен',
#               'узде',
#               'уроже',
#               'ужас'],
#              'valid-18': ['раньше',
#               'пораньше',
#               'раньшее',
#               'раньшу',
#               'рентген',
#               'пеньше',
#               'роньше',
#               'меньше',
#               'подпишу',
#               'раньше-то',
#               'рентге',
#               'рентг'],
#              'valid-19': ['нам',
#               'нас',
#               'нами',
#               'наст',
#               'на',
#               'нем',
#               'неси',
#               'нес',
#               'нат',
#               'насть'],
#              'valid-20': ['щас',
#               'щаас',
#               'запас',
#               'шас',
#               'расас',
#               'нас',
#               'зачем',
#               'щас',
#               'шасас',
#               'пасас'],
#              'valid-21': ['купил',
#               'купила',
#               'купили',
#               'купить',
#               'курил',
#               'купим',
#               'купит',
#               'купи',
#               'купал',
#               'куплю'],
#              'valid-22': ['ты',
#               'бы',
#               'тв',
#               'тры',
#               'мы',
#               'та',
#               'ты',
#               'тай',
#               'тру',
#               'тре'],
#              'valid-23': ['зовут',
#               'зовет',
#               'завтра',
#               'заут',
#               'зайти',
#               'заур',
#               'знает',
#               'зови',
#               'зрут',
#               'зуб',
#               'заурь'],
#              'valid-24': ['короче',
#               'короч',
#               'корочку',
#               'корочка',
#               'кроче',
#               'корочке',
#               'корче',
#               'корочко',
#               'корчу',
#               'корочки'],
#              'valid-25': ['лучше',
#               'лучшее',
#               'лучшие',
#               'лучшей',
#               'лучшего',
#               'лучшем',
#               'лучшему',
#               'лучшое',
#               'лучший',
#               'душе'],
#              'valid-26': ['приедем',
#               'придем',
#               'приедет',
#               'придет',
#               'придешь',
#               'прием',
#               'приедешь',
#               'проедем',
#               'приеду',
#               'поедем'],
#              'valid-27': ['размыто',
#               'рахмыто',
#               'рахмат',
#               'размыть',
#               'размыл',
#               'размытом',
#               'рахмыт',
#               'размыта',
#               'размыла',
#               'рахмыст'],
#              'valid-28': ['давай',
#               'лавай',
#               'давай',
#               'лавой',
#               'лавай',
#               'лавочка',
#               'драйв',
#               'лавочный',
#               'драй',
#               'опавай',
#               'лавочкой',
#               'дравай',
#               'драйва'],
#              'valid-29': ['ты',
#               'тв',
#               'мы',
#               'бы',
#               'та',
#               'трав',
#               'твы',
#               'тры',
#               'ты',
#               'ивы'],
#              'valid-30': ['отдать',
#               'отжать',
#               'отдаю',
#               'отдают',
#               'отдавать',
#               'отдаться',
#               'отдам',
#               'отдали',
#               'отожать',
#               'обижать'],
#              'valid-31': ['привет',
#               'приветик',
#               'привет',
#               'привете',
#               'привести',
#               'прикинь',
#               'живет',
#               'проверить',
#               'придет',
#               'проверит',
#               'проверим',
#               'провери',
#               'приверить',
#               'привезет',
#               'привезти'],
#              'valid-32': ['не',
#               'нее',
#               'не не',
#               'не нее',
#               'не- не',
#               'не не не',
#               'неа',
#               'ней',
#               'на',
#               'на не',
#               'нее не',
#               'ну'],
#              'valid-33': ['да',
#               'да-да',
#               'дала',
#               'дав',
#               'дар',
#               'дал',
#               'даша',
#               'два',
#               'дата',
#               'давла',
#               'да-а'],
#              'valid-34': ['будете',
#               'будет',
#               'будуте',
#               'будите',
#               'будете',
#               'будуте',
#               'будеме',
#               'можете',
#               'будетеся',
#               'будетесь'],
#              'valid-35': ['связи',
#               'связите',
#               'связь',
#               'связали',
#               'связать',
#               'связан',
#               'связаться',
#               'связал',
#               'связит',
#               'маязи',
#               'свои',
#               'свози'],
#              'valid-36': ['колывань',
#               'колывают',
#               'колываню',
#               'колываю',
#               'колывает',
#               'колываешь',
#               'козырь',
#               'кодываю',
#               'кодывают',
#               'колыванью'],
#              'valid-37': ['меня',
#               'меняя',
#               'мены',
#               'песня',
#               'менял',
#               'меня',
#               'менять',
#               'мени',
#               'сегодня',
#               'меням',
#               'мена',
#               'менная'],
#              'valid-38': ['напиши',
#               'напишите',
#               'напишу',
#               'наши',
#               'напиши',
#               'напиши-то',
#               'напомни',
#               'напишись',
#               'напишешь',
#               'наташи',
#               'напишись',
#               'напиши-',
#               'напиши-ни'],
#              'valid-39': ['знаю',
#               'знаю',
#               'знают',
#               'знать',
#               'знаю',
#               'зная',
#               'знаешь',
#               'знал',
#               'знаб',
#               'знает'],
#              'valid-40': ['мамой',
#               'самой',
#               'матой',
#               'массой',
#               'маслой',
#               'мамой',
#               'мактой',
#               'милой',
#               'мой',
#               'масло',
#               'максиму'],
#              'valid-41': ['не',
#               'нее',
#               'ну',
#               'ген',
#               'ге',
#               'на',
#               'гее',
#               'г не',
#               'гене',
#               'гне',
#               'ней',
#               'не-не',
#               'гек'],
#              'valid-42': ['ты',
#               'мы',
#               'бы',
#               'ты',
#               'вы',
#               'тв',
#               'та',
#               'тры',
#               'ту',
#               'ивы'],
#              'valid-43': ['только',
#               'сколько',
#               'столько',
#               'лько',
#               'толькое',
#               'толькою',
#               'только-то',
#               'тольком',
#               'толька',
#               'только-ко',
#               'толькои'],
#              'valid-44': ['они',
#               'ори',
#               'оник',
#               'онини',
#               'онири',
#               'онир',
#               'один',
#               'орини',
#               'онин',
#               'о',
#               'она',
#               'ониги'],
#              'valid-45': ['свинг',
#               'самогон',
#               'свинга',
#               'своего',
#               'свининг',
#               'свингер',
#               'смены',
#               'смена',
#               'всего',
#               'свингас',
#               'саманг',
#               'свингам',
#               'свингви'],
#              'valid-46': ['спи',
#               'спипи',
#               'спит',
#               'спип',
#               'спим',
#               'спирт',
#               'спирпи',
#               'спипипи',
#               'спите',
#               'спипип',
#               'спина'],
#              'valid-47': ['соскучилась',
#               'соскучились',
#               'соскучился',
#               'соскучилось',
#               'самочувствие',
#               'самоскучилась',
#               'случилась',
#               'москучилась',
#               'соскучись',
#               'сомкучилась',
#               'самочувствию',
#               'самочувствии',
#               'самочувствия'],
#              'valid-48': ['целую',
#               'целуют',
#               'целуюсь',
#               'цербую',
#               'целует',
#               'целуются',
#               'целуя',
#               'целью',
#               'целую',
#               'цебую'],
#              'valid-49': ['что',
#               'что-то',
#               'сто',
#               'чтоб',
#               'чисто',
#               'просто',
#               'часто',
#               'чтобы',
#               'что-та',
#               'чтот',
#               'сито',
#               'что-ту'],
#              'valid-50': ['почему',
#               'почему-то',
#               'посему',
#               'почем',
#               'приеме',
#               'приему',
#               'приема',
#               'приемку',
#               'ничему',
#               'пойму'],
#              'valid-51': ['заказала',
#               'заказы',
#               'заказов',
#               'заказал',
#               'заказать',
#               'закалы',
#               'заказали',
#               'шакалы',
#               'заказа',
#               'заказывала',
#               'заказывал',
#               'заказываю',
#               'заказывает'],
#              'valid-52': ['мне',
#               'сна',
#               'меня',
#               'сне',
#               'не',
#               'ане',
#               'мен',
#               'на',
#               'ана',
#               'сен'],
#              'valid-53': ['свидимся',
#               'свился',
#               'садимся',
#               'свилился',
#               'свидился',
#               'свидетя',
#               'своимся',
#               'свидемся',
#               'свидался',
#               'видимся',
#               'свидетям'],
#              'valid-54': ['ходил',
#               'ходили',
#               'ходила',
#               'ходит',
#               'ходило',
#               'ходить',
#               'зажил',
#               'хадил',
#               'хожил',
#               'ходим'],
#              'valid-55': ['погоди',
#               'погода',
#               'погодим',
#               'прогоди',
#               'погодь',
#               'погодите',
#               'погодить',
#               'погодка',
#               'погодки',
#               'проголоди'],
#              'valid-56': ['подъезжать',
#               'подъезжаю',
#               'подъезжает',
#               'подъезжат',
#               'проъезжать',
#               'подъезжают',
#               'подъезжаешь',
#               'подъезжали',
#               'подъезжал',
#               'подъезжаем'],
#              'valid-57': ['делишки',
#               'делишком',
#               'железки',
#               'дедишки',
#               'желишки',
#               'делишек',
#               'детишки',
#               'делишка',
#               'дедушки',
#               'белишки'],
#              'valid-58': ['ручки',
#               'русски',
#               'ручкой',
#               'русские',
#               'русский',
#               'ручка',
#               'ручку',
#               'русским',
#               'ручками',
#               'ручкут',
#               'русском',
#               'руки'],
#              'valid-59': ['прохладно',
#               'площадно',
#               'плодно',
#               'прохладное',
#               'подождет',
#               'поздно',
#               'прохладной',
#               'площадное',
#               'проходной',
#               'прохладного',
#               'прохладном',
#               'проходно',
#               'праздни'],
#              'valid-60': ['хз',
#               'из-за',
#               'за',
#               'хахаха',
#               'хозя',
#               'я хз',
#               'хаз',
#               'хахах',
#               'ха-ха',
#               'хахахаха',
#               'хозяи',
#               'захозя'],
#              'valid-61': ['купальники',
#               'купальник',
#               'купальнике',
#               'купальника',
#               'куральники',
#               'купалники',
#               'купальникам',
#               'купальнику',
#               'купальниками',
#               'купальником',
#               'купально',
#               'купательники'],
#              'valid-62': ['вчера',
#               'вечера',
#               'всегда',
#               'асаера',
#               'учера',
#               'снов',
#               'пчера',
#               'сера',
#               'учеба',
#               'свера',
#               'вечерам'],
#              'valid-63': ['друг',
#               'другу',
#               'даун',
#               'луг',
#               'друга',
#               'душ',
#               'лучше',
#               'друго',
#               'слуг',
#               'друг-г',
#               'друг-гу',
#               'лучшего',
#               'друг-то',
#               'лучшей',
#               'даунг',
#               'друг-д'],
#              'valid-64': ['без',
#               'безз',
#               'безо',
#               'бенз',
#               'безу',
#               'безш',
#               'безлаз',
#               'безза',
#               'обез',
#               'безд',
#               'беззах',
#               'безден',
#               'бездни',
#               'бездне'],
#              'valid-65': ['ничего',
#               'нечего',
#               'ничего',
#               'отчего',
#               'ночно',
#               'ничего-то',
#               'очень',
#               'приятного',
#               'ночного',
#               'ничегом',
#               'ничего-чего',
#               'грично'],
#              'valid-66': ['александровой',
#               'александровна',
#               'александрович',
#               'александрова',
#               'александров',
#               'александровай',
#               'александровский',
#               'александровной',
#               'александровать',
#               'александровый',
#               'александрово',
#               'александровое'],
#              'valid-67': ['сейчас',
#               'мейсам',
#               'лейсам',
#               'сейчас-то',
#               'сейсам',
#               'сайсам',
#               'сейчас-сем',
#               'сейчас-сам',
#               'действии',
#               'яйцам',
#               'семейсам',
#               'действием',
#               'действия'],
#              'valid-68': ['замазала',
#               'замерзала',
#               'запихала',
#               'замазалась',
#               'замозала',
#               'замерзла',
#               'замахала',
#               'замещала',
#               'замазал',
#               'заморожала'],
#              'valid-69': ['че',
#               'чан',
#               'чае',
#               'чек',
#               'чем',
#               'че че',
#               'се',
#               'чее',
#               'чел',
#               'чечен',
#               'чечне',
#               'чаек',
#               'чечет'],
#              'valid-70': ['только',
#               'толькое',
#               'только',
#               'сколько',
#               'столько',
#               'только-то',
#               'тольком',
#               'толькоел',
#               'толькои',
#               'только-ко',
#               'толькою',
#               'толькоие'],
#              'valid-71': ['ты',
#               'мы',
#               'бы',
#               'ты',
#               'вы',
#               'хы',
#               'та',
#               'тры',
#               'тв',
#               'твы'],
#              'valid-72': ['волосы',
#               'волос',
#               'владимир',
#               'володя',
#               'видосы',
#               'вопрос',
#               'вадим',
#               'видос',
#               'валя',
#               'волосами',
#               'владимира',
#               'взломал',
#               'волосам'],
#              'valid-73': ['артем',
#               'артема',
#               'втроем',
#               'время',
#               'артес',
#               'артеме',
#               'артеми',
#               'прием',
#               'артему',
#               'втем',
#               'аттес'],
#              'valid-74': ['мама',
#               'мам',
#               'маму',
#               'мамка',
#               'мамки',
#               'маме',
#               'мама',
#               'мамам',
#               'мамы',
#               'сама',
#               'сам'],
#              'valid-75': ['уля',
#               'коля',
#               'коя',
#               'короч',
#               'короче',
#               'коря',
#               'кля',
#               'куля',
#               'улы',
#               'удаля'],
#              'valid-76': ['вообще',
#               'вообще-то',
#               'вроде',
#               'валюше',
#               'вообщее',
#               'ввообще',
#               'вообше',
#               'ввообщее',
#               'вотобще',
#               'воюще',
#               'воообще',
#               'вообще-ше',
#               'вообще-ту',
#               'вообще-та'],
#              'valid-77': ['вот',
#               'вот-то',
#               'ворот',
#               'вот-т',
#               'вопрос',
#               'вольт',
#               'волт',
#               'воот',
#               'во-то',
#               'вот'],
#              'valid-78': ['так-то',
#               'трактор',
#               'тик-ток',
#               'как-то',
#               'там-то',
#               'танк-то',
#               'такое',
#               'тату',
#               'такие',
#               'табак-то',
#               'трактора',
#               'тик-то',
#               'танкто',
#               'трактори',
#               'тракторе'],
#              'valid-79': ['шорту',
#               'шорты',
#               'шорта',
#               'лорту',
#               'шорбу',
#               'школу',
#               'щупа',
#               'шутку',
#               'щорту',
#               'шортку',
#               'шортка',
#               'шортура'],
#              'valid-80': ['баку',
#               'бабку',
#               'бук',
#               'будет',
#               'бек',
#               'букву',
#               'бака',
#               'банку',
#               'бабки',
#               'бабка',
#               'буду',
#               'брак'],
#              'valid-81': ['че',
#               'чае',
#               'чан',
#               'чаек',
#               'часа',
#               'ча',
#               'чаечка',
#               'чаем',
#               'чана',
#               'чаеве',
#               'чаев',
#               'чаевы'],
#              'valid-82': ['сегодня',
#               'сегодням',
#               'сегоднят',
#               'сегодняр',
#               'сегодняшняя',
#               'сегодня-то',
#               'негодная',
#               'сегоднями',
#               'мегодная',
#               'чегодная',
#               'чегодня',
#               'чегодня',
#               'негодня',
#               'чегодняя'],
#              'valid-83': ['остановились',
#               'остановилось',
#               'остановилась',
#               'остановился',
#               'остановили',
#               'остановись',
#               'останновились',
#               'остановлюсь',
#               'остановлю',
#               'останавливались',
#               'останавливали',
#               'останавливалась',
#               'останавливался',
#               'останавливает',
#               'останавливал',
#               'останавливалось',
#               'останавливаю'],
#              'valid-84': ['можно',
#               'можнодно',
#               'модно',
#               'может',
#               'можно можно',
#               'мдно',
#               'можножно',
#               'можно одно',
#               'можнолдно',
#               'можноложно',
#               'можнол',
#               'можнодного'],
#              'valid-85': ['буду',
#               'будут',
#               'будет',
#               'буду',
#               'будем',
#               'будешь',
#               'будку',
#               'будете',
#               'бужу',
#               'бужду',
#               'будка',
#               'будут'],
#              'valid-86': ['ты',
#               'мы',
#               'бы',
#               'ты',
#               'тры',
#               'та',
#               'тв',
#               'вы',
#               'авы',
#               'ту'],
#              'valid-87': ['все',
#               'вместе',
#               'всем',
#               'все-так',
#               'се',
#               'семе',
#               'усе',
#               'смена',
#               'аме',
#               'аместе',
#               'уместе',
#               'все-ме',
#               'уместен',
#               'уместно'],
#              'valid-88': ['ты',
#               'мы',
#               'ивы',
#               'тв',
#               'ив',
#               'та',
#               'бы',
#               'иры',
#               'трав',
#               'ива'],
#              'valid-89': ['удобно',
#               'уровень',
#               'удачно',
#               'удачного',
#               'удаленно',
#               'удобного',
#               'конечно',
#               'удалено',
#               'ударного',
#               'улан-ко',
#               'улан-о'],
#              'valid-90': ['мото',
#               'м-то',
#               'мотото',
#               'пото',
#               'может',
#               'мотор',
#               'потом',
#               'просто',
#               'метро',
#               'мрто',
#               'исто',
#               'итог'],
#              'valid-91': ['последний',
#               'последние',
#               'последней',
#               'последних',
#               'последник',
#               'последений',
#               'последним',
#               'последний',
#               'последнему',
#               'последние',
#               'последнийся',
#               'последнем'],
#              'valid-92': ['ты',
#               'тв',
#               'бы',
#               'трав',
#               'мы',
#               'твы',
#               'тры',
#               'тав',
#               'та',
#               'ты'],
#              'valid-93': ['ты',
#               'тв',
#               'мы',
#               'бы',
#               'та',
#               'ты',
#               'ту',
#               'трав',
#               'ивы',
#               'твы'],
#              'valid-94': ['вставать',
#               'встать',
#               'вставить',
#               'вставь',
#               'вставатью',
#               'вставаться',
#               'вставай',
#               'вставать',
#               'поставить',
#               'ставать',
#               'вставатьте'],
#              'valid-95': ['но но но но но но но но но но',
#               'но но но но но но но но но',
#               'но но но но но но но но',
#               'но но но но но но но',
#               'но но но но но но',
#               'но но но но но',
#               'но но но но',
#               'но но но',
#               'но но',
#               'но'],
#              'valid-96': ['другое',
#               'другой',
#               'друге',
#               'другому',
#               'другу',
#               'дружок',
#               'другие',
#               'друго',
#               'другогое',
#               'другом',
#               'другого'],
#              'valid-97': ['ясно',
#               'ясного',
#               'ясное',
#               'ясвно',
#               'ясл',
#               'явно',
#               'ясном',
#               'ясна',
#               'ясного',
#               'яснень'],
#              'valid-98': ['курс',
#               'купи',
#               'купим',
#               'купить',
#               'кури',
#               'купил',
#               'купили',
#               'купила',
#               'курам',
#               'куриц'],
#              'valid-99': ['спать',
#               'спасибо',
#               'спат',
#               'спал',
#               'араб',
#               'спаю',
#               'апаб',
#               'спаб',
#               'спаси',
#               'спатю'],
#              'valid-100': ['ресурсы',
#               'рескурсы',
#               'ремурсы',
#               'ресурмы',
#               'республика',
#               'темурсы',
#               'респурсы',
#               'ремурмы',
#               'республики',
#               'ремурсы',
#               'республик',
#               'русский',
#               'республивы'],
#              'valid-101': ['онлайн',
#               'онлайна',
#               'онлайны',
#               'онлайне',
#               'оклайн',
#               'андрей',
#               'одной',
#               'окей',
#               'она',
#               'онлайно'],
#              'valid-102': ['надумаете',
#               'надумает',
#               'недумаете',
#               'надумайте',
#               'надумываете',
#               'надумается',
#               'радуете',
#               'надумание',
#               'надумаем',
#               'надумаетесь',
#               'накдумаете',
#               'надумаетее',
#               'надумывает',
#               'надумаетеся',
#               'надумаетем'],
#              'valid-103': ['покататься',
#               'прокататься',
#               'покататься',
#               'покатается',
#               'покатался',
#               'покатаются',
#               'покипаться',
#               'подкататься',
#               'покупаться',
#               'прокатался'],
#              'valid-104': ['желательно',
#               'желатель',
#               'желательное',
#               'желательной',
#               'желательного',
#               'делательно',
#               'желательные',
#               'желательном',
#               'желательный',
#               'желательная',
#               'делатель',
#               'желательно',
#               'желательность'],
#              'valid-105': ['на',
#               'нас',
#               'на на',
#               'неа',
#               'наа',
#               'нана',
#               'нам',
#               'не',
#               'нат',
#               'на-а',
#               'на-на',
#               'на нас'],
#              'valid-106': ['мерам',
#               'мерама',
#               'мерамас',
#               'меррам',
#               'мерамет',
#               'меням',
#               'серам',
#               'мерами',
#               'мерам',
#               'мера',
#               'меня'],
#              'valid-107': ['должна',
#               'должны',
#               'должен',
#               'дождусь',
#               'дождик',
#               'дожде',
#               'дождем',
#               'дождешься',
#               'дождешь',
#               'дожди'],
#              'valid-108': ['переживай',
#               'передавай',
#               'перебивай',
#               'переживай',
#               'переливай',
#               'передивай',
#               'передливай',
#               'переживайте',
#               'передрай',
#               'передвига'],
#              'valid-109': ['из',
#               'из-за',
#               'изз',
#               'и из',
#               'из из',
#               'их',
#               'изюз',
#               'из',
#               'изх',
#               'изищ'],
#              'valid-110': ['кстати',
#               'кстатиа',
#               'кстати-',
#               'кастати',
#               'кстатите',
#               'кстатика',
#               'кстатио',
#               'костати',
#               'кстата',
#               'кстатик'],
#              'valid-111': ['брал',
#               'бад',
#               'бал',
#               'брала',
#               'балл',
#               'бард',
#               'брат',
#               'благо',
#               'браво',
#               'блаж'],
#              'valid-112': ['вот',
#               'вот-то',
#               'вот-вот',
#               'ворот',
#               'вот-т',
#               'вопрос',
#               'вот-нт',
#               'вот-та',
#               'вот-нет',
#               'вот-нот'],
#              'valid-113': ['приехала',
#               'приезжала',
#               'приехал',
#               'приехали',
#               'приезжал',
#               'приехала',
#               'приехало',
#               'приезжать',
#               'проехала',
#               'приезжай'],
#              'valid-114': ['пока',
#               'поем',
#               'прока',
#               'понес',
#               'пленка',
#               'покупаем',
#               'полка',
#               'покупка',
#               'пора',
#               'покупать',
#               'покупает',
#               'покупал',
#               'понесла',
#               'покупала'],
#              'valid-115': ['на',
#               'га',
#               'нас',
#               'неа',
#               'гаа',
#               'нам',
#               'наа',
#               'наша',
#               'нача',
#               'най'],
#              'valid-116': ['но',
#               'но но',
#               'но но но',
#               'ноно',
#               'ноо',
#               'нол',
#               'но ноно',
#               'но ноо',
#               'но нол',
#               'нол но'],
#              'valid-117': ['протокола',
#               'протоколол',
#               'протоколола',
#               'протоколоть',
#               'протоколов',
#               'протокла',
#               'протокололи',
#               'потеряла',
#               'потокла',
#               'потрудника',
#               'потрудники',
#               'потруднику'],
#              'valid-118': ['никак',
#               'ника',
#               'никака',
#               'ники',
#               'нике',
#               'никуда',
#               'никита',
#               'нина',
#               'никика',
#               'никока',
#               'никаки'],
#              'valid-119': ['надеюсь',
#               'надоесть',
#               'надрость',
#               'надросить',
#               'наложить',
#               'надпись',
#               'надоест',
#               'надростью',
#               'надрости',
#               'надлочь',
#               'налочь',
#               'надписью',
#               'налочью'],
#              'valid-120': ['привет',
#               'приветик',
#               'прикинь',
#               'привести',
#               'проверить',
#               'привете',
#               'проверим',
#               'придет',
#               'привет',
#               'проверит',
#               'привес',
#               'приверить',
#               'провери',
#               'проверил'],
#              'valid-121': ['скину',
#               'спину',
#               'спишу',
#               'чему',
#               'скинула',
#               'скигу',
#               'скинут',
#               'скинуть',
#               'скинул',
#               'скригу',
#               'скрину',
#               'скрины',
#               'скришу',
#               'скрик',
#               'скрин'],
#              'valid-122': ['говорит',
#               'говорить',
#               'говори',
#               'новости',
#               'говорил',
#               'говорят',
#               'говорим',
#               'говорю',
#               'господи',
#               'готовить',
#               'готовит',
#               'госпит',
#               'госпита',
#               'госпи'],
#              'valid-123': ['водителю',
#               'водитель',
#               'водителью',
#               'водительюю',
#               'возьмют',
#               'возьмет',
#               'возьмете',
#               'водителюм',
#               'владителю',
#               'вводителю',
#               'водителюми'],
#              'valid-124': ['понятно',
#               'понятного',
#               'понятное',
#               'понятно',
#               'понято',
#               'понятна',
#               'понятной',
#               'понятно',
#               'понятном',
#               'понятном',
#               'понятнах',
#               'понятнень'],
#              'valid-125': ['сделаю',
#               'сделают',
#               'сделать',
#               'сделаюсь',
#               'сделал',
#               'сделает',
#               'сделаешь',
#               'сделала',
#               'слушаю',
#               'сделай',
#               'слушают',
#               'слушать',
#               'слушаюсь',
#               'слушаешь',
#               'слушает',
#               'слушал',
#               'слушай',
#               'слушала',
#               'слушая'],
#              'valid-126': ['еще',
#               'езде',
#               'еле',
#               'езжу',
#               'езжай',
#               'еже',
#               'елезне',
#               'езди',
#               'еззде',
#               'езен',
#               'езге',
#               'ездите',
#               'езген'],
#              'valid-127': ['мне',
#               'мене',
#               'не',
#               'нее',
#               'меня',
#               'сне',
#               'мен',
#               'ме',
#               'не',
#               'мнее',
#               'мне-не',
#               'снее',
#               'снег'],
#              'valid-128': ['гулять',
#               'гуляю',
#               'гуляться',
#               'гуляют',
#               'гуляет',
#               'гуляешь',
#               'гуляли',
#               'грулянь',
#               'шулять',
#               'гудят'],
#              'valid-129': ['просто',
#               'прости',
#               'просто',
#               'прост',
#               'проста',
#               'посто',
#               'просил',
#               'пост',
#               'посмотри',
#               'просит'],
#              'valid-130': ['моя',
#               'моря',
#               'мая',
#               'мля',
#               'мой',
#               'миля',
#               'милая',
#               'соя',
#               'соля',
#               'мотя'],
#              'valid-131': ['покажем',
#               'покажешь',
#               'покажет',
#               'покажи',
#               'прокажем',
#               'покажем',
#               'поедем',
#               'покажемся',
#               'поколем',
#               'покажу',
#               'подкажем',
#               'покажеме'],
#              'valid-132': ['четвертая',
#               'четвертый',
#               'четвертые',
#               'четверта',
#               'четвертия',
#               'четвертое',
#               'честная',
#               'четвертой',
#               'четвертым',
#               'четвертыя'],
#              'valid-133': ['не',
#               'нее',
#               'не не',
#               'ну',
#               'г не',
#               'на',
#               'ген',
#               'не- не',
#               'ней',
#               'не-не',
#               'ге не',
#               'ге',
#               'не нее'],
#              'valid-134': ['мед',
#               'инд',
#               'индед',
#               'индел',
#               'инж',
#               'инжен',
#               'медленно',
#               'инженд',
#               'медж',
#               'индежд',
#               'индеж',
#               'меджд',
#               'мендель'],
#              'valid-135': ['на',
#               'на на',
#               'нас',
#               'наа',
#               'га',
#               'нам',
#               'нана',
#               'напа',
#               'нага',
#               'на на на',
#               'на-а',
#               'на- на'],
#              'valid-136': ['ок',
#               'оке',
#               'окей',
#               'окк',
#               'окне',
#               'окек',
#               'окно',
#               'окр',
#               'окку',
#               'окре',
#               'округ'],
#              'valid-137': ['пока',
#               'прока',
#               'полка',
#               'прокатка',
#               'прокат',
#               'пока-что',
#               'пробка',
#               'пака',
#               'пока',
#               'прокатал',
#               'прокаты',
#               'прокатит'],
#              'valid-138': ['вероятно',
#               'вероятного',
#               'вероятной',
#               'вероятное',
#               'вероятна',
#               'вероятность',
#               'вероятности',
#               'верятно',
#               'вероятно',
#               'вероятная'],
#              'valid-139': ['щас',
#               'щаас',
#               'шас',
#               'пас',
#               'ща',
#               'нас',
#               'щас',
#               'ас',
#               'зачем',
#               'пасас',
#               'дас',
#               'пасс'],
#              'valid-140': ['вечер',
#               'вечером',
#               'вечера',
#               'вечери',
#               'вечно',
#               'вечерам',
#               'вчера',
#               'вечер',
#               'вечерами',
#               'вечеров',
#               'вечерин'],
#              'valid-141': ['не',
#               'на',
#               'нее',
#               'неа',
#               'ну',
#               'га',
#               'она',
#               'нас',
#               'ген',
#               'не-а',
#               'не-не',
#               'гена',
#               'не-н',
#               'не-на',
#               'не-е'],
#              'valid-142': ['просто',
#               'прости',
#               'прост',
#               'просто',
#               'проста',
#               'посто',
#               'посмотри',
#               'просил',
#               'пост',
#               'постро'],
#              'valid-143': ['вот',
#               'вот-то',
#               'вот-т',
#               'вот-вот',
#               'ворот',
#               'вот-та',
#               'вольт',
#               'вопрос',
#               'волт',
#               'вот-нт',
#               'вот-тт'],
#              'valid-144': ['это',
#               'этот',
#               'этом',
#               'эта',
#               'эти',
#               'это-то',
#               'это',
#               'этого',
#               'ото',
#               'эту'],
#              'valid-145': ['ночи',
#               'ночь',
#               'носи',
#               'ночам',
#               'ночки',
#               'ночим',
#               'носят',
#               'ночит',
#               'ночии',
#               'норм'],
#              'valid-146': ['магазин',
#               'магазине',
#               'магазина',
#               'магазины',
#               'мегазин',
#               'магазинам',
#               'магазинов',
#               'магазину',
#               'магазином',
#               'магази',
#               'магазе'],
#              'valid-147': ['фиолетовое',
#               'фиолетовой',
#               'фигнивок',
#               'фигнетовок',
#               'фиговое',
#               'фиготовое',
#               'фигнтовок',
#               'фиговой',
#               'фигнетовой',
#               'фигнетовое',
#               'фиготовой',
#               'фиолетово'],
#              'valid-148': ['со',
#               'сол',
#               'мо',
#               'мол',
#               'что',
#               'сил',
#               'сто',
#               'мои',
#               'соо',
#               'смо'],
#              'valid-149': ['отправляю',
#               'отправлю',
#               'отправляют',
#               'отправлять',
#               'отправляет',
#               'отправлял',
#               'отравляю',
#               'отправляюсь',
#               'отправляешь',
#               'оправляю'],
#              'valid-150': ['ура',
#               'утра',
#               'уора',
#               'урора',
#               'кора',
#               'уров',
#               'ура-а',
#               'уропа',
#               'удара',
#               'ужас',
#               'ура-у',
#               'ура-ы'],
#              'valid-151': ['тогда',
#               'могла',
#               'того',
#               'тошла',
#               'года',
#               'толпа',
#               'когда',
#               'только',
#               'тогла',
#               'тоже',
#               'тогола',
#               'тогода',
#               'тогора',
#               'толго'],
#              'valid-152': ['отвлекаешь',
#               'отвлекаешься',
#               'отвлекает',
#               'отвлекать',
#               'отвлекается',
#               'отвлекаем',
#               'отвлекнешь',
#               'отвлекаю',
#               'отвлекают',
#               'отвлекатель',
#               'отвокаешь'],
#              'valid-153': ['уже',
#               'уде',
#               'нужен',
#               'ужен',
#               'узде',
#               'уже',
#               'ужин',
#               'ушел',
#               'ужас',
#               'уже',
#               'ужине'],
#              'valid-154': ['выезжать',
#               'выезжай',
#               'выезжаю',
#               'выехал',
#               'выехали',
#               'выходи',
#               'выезжаем',
#               'выезжал',
#               'выезжает',
#               'выехать',
#               'выехала'],
#              'valid-155': ['на',
#               'нас',
#               'наа',
#               'на на',
#               'нана',
#               'нам',
#               'нача',
#               'наи',
#               'начала',
#               'напа',
#               'на-а'],
#              'valid-156': ['далеко',
#               'жалко',
#               'ладно',
#               'далекое',
#               'балко',
#               'дадко',
#               'балкон',
#               'далеком',
#               'далер',
#               'ладко'],
#              'valid-157': ['один',
#               'одни',
#               'одино',
#               'одинок',
#               'одиноки',
#               'одинки',
#               'одини',
#               'однин',
#               'одинка',
#               'одина',
#               'она'],
#              'valid-158': ['возрасте',
#               'возрасту',
#               'возраста',
#               'возраст',
#               'возрастет',
#               'возрастем',
#               'возрастате',
#               'возрастан',
#               'возрасток',
#               'возрасты'],
#              'valid-159': ['выхожу',
#               'выходу',
#               'выходной',
#               'выходные',
#               'выхожут',
#               'выходи',
#               'выходку',
#               'выходное',
#               'выходных',
#               'выходе',
#               'выходный'],
#              'valid-160': ['такая',
#               'ткач',
#               'тупая',
#               'токая',
#               'труская',
#               'тыкая',
#               'трусы',
#               'ткая',
#               'твоя',
#               'танкая',
#               'трускай'],
#              'valid-161': ['выходи',
#               'выходит',
#               'выходить',
#               'выходил',
#               'выходим',
#               'выходи',
#               'выложи',
#               'выходила',
#               'выходной',
#               'выходили',
#               'выходном'],
#              'valid-162': ['мы',
#               'ивы',
#               'ты',
#               'иры',
#               'ива',
#               'ры',
#               'изы',
#               'ив',
#               'иды',
#               'иф'],
#              'valid-163': ['дарина',
#               'жарина',
#               'зарина',
#               'ларина',
#               'дарине',
#               'барина',
#               'дарины',
#               'дорина',
#               'парина',
#               'харина'],
#              'valid-164': ['выдавливай',
#               'выдоравливай',
#               'выздоравливай',
#               'выдраживай',
#               'выдвиживай',
#               'выдвигивай',
#               'выдраливай',
#               'выдравливай',
#               'выдовливай',
#               'выдоваливай'],
#              'valid-165': ['черны',
#               'черная',
#               'черный',
#               'черные',
#               'черепов',
#               'черепаша',
#               'чернов',
#               'часов',
#               'черга',
#               'черепа'],
# ...
#               'травмы'],
#              'valid-943': ['кушать',
#               'кушает',
#               'кушаю',
#               'кушат',
#               'слушать',
#               'узнать',
#               'кругать',
#               'кушать',
#               'кушаться',
#               'кушаешь'],
#              'valid-944': ['юрист',
#               'борись',
#               'брист',
#               'юпист',
#               'бесит',
#               'бориси',
#               'боись',
#               'юрь',
#               'юриста',
#               'юрьи'],
#              'valid-945': ['возможности',
#               'возможность',
#               'возможности',
#               'возможностию',
#               'возможностью',
#               'возможным',
#               'возможност',
#               'возможными',
#               'возможностей',
#               'возможно',
#               'возможностя'],
#              'valid-946': ['тему',
#               'теме',
#               'тема',
#               'темку',
#               'темы',
#               'терму',
#               'темпе',
#               'темму',
#               'темка',
#               'теми'],
#              'valid-947': ['возраст',
#               'возраста',
#               'возрасте',
#               'возрасту',
#               'возврат',
#               'возрастом',
#               'возрасти',
#               'возрасты',
#               'возрастами',
#               'возрастам'],
#              'valid-948': ['та',
#               'так',
#               'иа',
#               'ита',
#               'там',
#               'тата',
#               'ива',
#               'ты',
#               'ма',
#               'таа'],
#              'valid-949': ['можно',
#               'модно',
#               'может',
#               'можнодно',
#               'дно',
#               'сложно',
#               'можжно',
#               'можноно',
#               'можножно',
#               'можно-дно',
#               'модного',
#               'модной',
#               'можно-но'],
#              'valid-950': ['экономчек',
#               'электричек',
#               'экормчек',
#               'экоричек',
#               'экономичек',
#               'эконочек',
#               'экорочек',
#               'экономек',
#               'экономяк',
#               'экономические',
#               'экономически',
#               'экономический',
#               'экономических',
#               'электрически'],
#              'valid-951': ['сказали',
#               'сказала',
#               'сказал',
#               'сказать',
#               'сказало',
#               'сказалось',
#               'сказали',
#               'скажи',
#               'скажешь',
#               'скажите'],
#              'valid-952': ['касса',
#               'кассат',
#               'камасса',
#               'красава',
#               'касса-са',
#               'кассак',
#               'кассар',
#               'камчатка',
#               'кассара',
#               'кассаж',
#               'касса-к'],
#              'valid-953': ['саша',
#               'чаша',
#               'сага',
#               'сеша',
#               'спеша',
#               'сша',
#               'маша',
#               'спша',
#               'сашка',
#               'спроша'],
#              'valid-954': ['росто',
#               'рост',
#               'ростом',
#               'ростов',
#               'почти',
#               'ростот',
#               'росси',
#               'роято',
#               'рости',
#               'просто',
#               'роста'],
#              'valid-955': ['проспект',
#               'просект',
#               'почему',
#               'пропект',
#               'проспекта',
#               'проспеки',
#               'роспект',
#               'проспекте',
#               'поспект',
#               'поспеки',
#               'проспекту',
#               'посеки',
#               'проспекто'],
#              'valid-956': ['вот',
#               'вот-то',
#               'вот-т',
#               'ворот',
#               'вопрос',
#               'фото',
#               'вольт',
#               'воот',
#               'волт',
#               'ворт'],
#              'valid-957': ['привет',
#               'приветик',
#               'привести',
#               'привет',
#               'привете',
#               'прикинь',
#               'живет',
#               'привес',
#               'привери',
#               'провери'],
#              'valid-958': ['что',
#               'что-то',
#               'сто',
#               'часто',
#               'чисто',
#               'чтоб',
#               'что',
#               'со',
#               'чтот',
#               'чмок',
#               'чито',
#               'чмо',
#               'что-та'],
#              'valid-959': ['вам',
#               'вас',
#               'вами',
#               'вам',
#               'вм',
#               'всем',
#               'вамп',
#               'вама',
#               'вари',
#               'вмя',
#               'вмест',
#               'вариа'],
#              'valid-960': ['лан',
#               'дан',
#               'ланан',
#               'лана',
#               'план',
#               'ланн',
#               'жан',
#               'лопан',
#               'лян',
#               'бан'],
#              'valid-961': ['ней',
#               'ну',
#               'ей',
#               'гей',
#               'най',
#               'нец',
#               'нц',
#               'неуй',
#               'ой',
#               'ний',
#               'нейку'],
#              'valid-962': ['сделаю',
#               'сделать',
#               'сделают',
#               'сделал',
#               'сделаешь',
#               'сделает',
#               'сделаюсь',
#               'сделала',
#               'сделали',
#               'следую',
#               'следуют'],
#              'valid-963': ['рулить',
#               'рулит',
#               'рулиться',
#               'рубить',
#               'решить',
#               'пулить',
#               'релить',
#               'рушить',
#               'рулись',
#               'рулитель'],
#              'valid-964': ['негодяев',
#               'негодчев',
#               'неголяев',
#               'негляев',
#               'негодчера',
#               'негодчеев',
#               'негодиев',
#               'негодяем',
#               'неколяев',
#               'негодяева'],
#              'valid-965': ['танцевал',
#               'танцевать',
#               'танцевала',
#               'танцево',
#               'танцул',
#               'транцевал',
#               'танцевало',
#               'танцевали',
#               'танцол',
#               'транцево',
#               'транцевол',
#               'транцевала'],
#              'valid-966': ['напоминал',
#               'напоминала',
#               'напомнил',
#               'напомнила',
#               'напостонал',
#               'напоминали',
#               'настроение',
#               'напоминаю',
#               'напоминало',
#               'напоминать',
#               'написал'],
#              'valid-967': ['знаю',
#               'знаю',
#               'знают',
#               'зная',
#               'знаю',
#               'знать',
#               'заю',
#               'знал',
#               'зю',
#               'знаб',
#               'жаю'],
#              'valid-968': ['кулониту',
#               'кулонирую',
#               'кулонитум',
#               'кулонитур',
#               'куда-нибудь',
#               'кулонитура',
#               'клонитум',
#               'кулониру',
#               'кулонибу',
#               'кулоница',
#               'кулонирующе',
#               'куда-нибуди'],
#              'valid-969': ['оттуда',
#               'отойдет',
#               'откуда',
#               'отойди',
#               'отойду',
#               'потому',
#               'отойда',
#               'ототужа',
#               'оттуда-то',
#               'отождать',
#               'отождал',
#               'отождаю',
#               'отождала'],
#              'valid-970': ['можно',
#               'мозго',
#               'создно',
#               'мозг',
#               'мозгов',
#               'мозги',
#               'создного',
#               'модно',
#               'много',
#               'мозгон',
#               'создон',
#               'мощно',
#               'мозгом'],
#              'valid-971': ['по',
#               'про',
#               'пор',
#               'пол',
#               'просто',
#               'по по',
#               'по про',
#               'полно',
#               'пол по',
#               'поо',
#               'попроси'],
#              'valid-972': ['фотка',
#               'фотки',
#               'фотку',
#               'фотке',
#               'фотока',
#               'фоткать',
#               'флотка',
#               'фоткам',
#               'фотика',
#               'фоткал'],
#              'valid-973': ['вах',
#               'ваз',
#               'вазах',
#               'вахтах',
#               'вахты',
#               'раз',
#               'вазам',
#               'вазе',
#               'выходных',
#               'вахта',
#               'вах-х'],
#              'valid-974': ['особой',
#               'особо',
#               'особый',
#               'особое',
#               'особом',
#               'особу',
#               'особной',
#               'особов',
#               'особого',
#               'очень'],
#              'valid-975': ['катя',
#               'кататься',
#               'катится',
#               'каться',
#               'катька',
#               'катиться',
#               'камия',
#               'какая',
#               'каты',
#               'катия'],
#              'valid-976': ['да',
#               'за',
#               'дар',
#               'ща',
#               'дала',
#               'да-да',
#               'дора',
#               'до',
#               'дал',
#               'для',
#               'да-за',
#               'да-па',
#               'да-ла',
#               'да-а',
#               'да-ра'],
#              'valid-977': ['же',
#               'желе',
#               'жее',
#               'же же',
#               'женее',
#               'жека',
#               'жеен',
#               'жен',
#               'жене',
#               'жене'],
#              'valid-978': ['ну',
#               'не',
#               'гу',
#               'ней',
#               'гру',
#               'гугу',
#               'гей',
#               'гуку',
#               'гуй',
#               'ну-ну',
#               'гук',
#               'ну-у'],
#              'valid-979': ['сегодня',
#               'сегоднят',
#               'сегодням',
#               'сегодняшняя',
#               'сегодняр',
#               'сегодня-то',
#               'сгодная',
#               'негодная',
#               'сегодняня',
#               'игодная',
#               'сгодняя',
#               'негодня',
#               'сгодня'],
#              'valid-980': ['те',
#               'тее',
#               'теле',
#               'те те',
#               'тек',
#               'тел',
#               'теее',
#               'телее',
#               'телек',
#               'те тее',
#               'теек'],
#              'valid-981': ['все',
#               'всем',
#               'аме',
#               'мама',
#               'совет',
#               'сосе',
#               'маме',
#               'уме',
#               'мам',
#               'амест',
#               'вмест'],
#              'valid-982': ['его',
#               'него',
#               'его',
#               'ешь',
#               'ного',
#               'но',
#               'ено',
#               'чего',
#               'ноги',
#               'его-го',
#               'его-то',
#               'его-ни'],
#              'valid-983': ['др',
#               'дор',
#               'до',
#               'дрр',
#               'дар',
#               'дорого',
#               'дорр',
#               'дорог',
#               'лор',
#               'дол',
#               'доро',
#               'да',
#               'дорор',
#               'для'],
#              'valid-984': ['читает',
#               'читаем',
#               'читается',
#               'читать',
#               'читаешь',
#               'ситает',
#               'читают',
#               'считает',
#               'чмоки',
#               'читайте',
#               'стает'],
#              'valid-985': ['добрый',
#               'доброй',
#               'добрые',
#               'добрым',
#               'добрый',
#               'домой',
#               'давай',
#               'добровый',
#               'доброе',
#               'добры'],
#              'valid-986': ['сидела',
#               'сидела',
#               'сделал',
#               'сделала',
#               'сделаю',
#               'сделать',
#               'сидков',
#               'видела',
#               'сидел',
#               'силдер',
#               'сидкова',
#               'силдра'],
#              'valid-987': ['чин',
#               'чирн',
#               'синие',
#               'син',
#               'чини',
#               'чирин',
#               'чирни',
#               'читин',
#               'чинин',
#               'чип',
#               'читер',
#               'чирки'],
#              'valid-988': ['каким',
#               'какими',
#               'какие',
#               'каком',
#               'какая',
#               'каким',
#               'какиму',
#               'таким',
#               'как-то',
#               'как'],
#              'valid-989': ['чтоб',
#               'чтобь',
#               'чтобы',
#               'чтобень',
#               'чтобно',
#               'стою',
#               'чтобю',
#               'чтобб',
#               'чтоблю',
#               'чтобного',
#               'что'],
#              'valid-990': ['даки',
#               'драки',
#               'дырки',
#               'двери',
#               'днем',
#               'лаки',
#               'девки',
#               'двум',
#               'двойки',
#               'драки'],
#              'valid-991': ['дамы',
#               'драмы',
#               'дорамы',
#               'давай',
#               'дома',
#               'дымы',
#               'демы',
#               'дамв',
#               'дама',
#               'дамы',
#               'даму',
#               'дым'],
#              'valid-992': ['другое',
#               'друге',
#               'другой',
#               'друго',
#               'другу',
#               'друган',
#               'другогое',
#               'другого',
#               'другому',
#               'другом',
#               'дружок'],
#              'valid-993': ['да',
#               'для',
#               'дс',
#               'дня',
#               'за',
#               'ля',
#               'ща',
#               'доча',
#               'дочь',
#               'дядь',
#               'дя',
#               'дяди',
#               'дочки',
#               'дяд'],
#              'valid-994': ['ложишься',
#               'лодошься',
#               'лодолья',
#               'ложиться',
#               'ордишься',
#               'ложься',
#               'лодбишься',
#               'ложился',
#               'ордория',
#               'ордония',
#               'лодольям',
#               'ордонию'],
#              'valid-995': ['будем',
#               'будет',
#               'будут',
#               'буду',
#               'будемся',
#               'будущем',
#               'будешь',
#               'будете',
#               'будем',
#               'будни',
#               'рулем'],
#              'valid-996': ['малохой',
#               'малхов',
#               'малохов',
#               'малхой',
#               'малоховый',
#               'маохов',
#               'малховый',
#               'мажоры',
#               'мархов',
#               'малховы'],
#              'valid-997': ['отец',
#               'отой',
#               'отцу',
#               'откуда',
#               'ору',
#               'отц',
#               'той',
#               'отку',
#               'отца',
#               'от',
#               'ото'],
#              'valid-998': ['думал',
#               'думала',
#               'думаю',
#               'думали',
#               'думать',
#               'думал',
#               'думало',
#               'думаешь',
#               'думар',
#               'двумво',
#               'думард',
#               'двумпо'],
#              'valid-999': ['районе',
#               'район',
#               'райное',
#               'района',
#               'району',
#               'район',
#               'районное',
#               'районы',
#               'райере',
#               'рай'],
#              ...})

# %%
def accuracy(ref_u2w, hyp_u2w):
    corr = 0
    err = 0
    total = len(ref_u2w)
    for u, ref in tqdm(ref_u2w.items()):
        hyp = hyp_u2w[u].strip('-')
        if ref != hyp:
            print(ref, hyp)
            err +=1
        else:
            corr +=1
    a = corr/total
    print(f"{total=} {corr=} {err=}, accuracy: {a}")
    return a

with open('data_feats/valid/text') as f:
    valid_ref_u2w = {u:w for u, w in   map(str.split, f.readlines())}

# %%
accuracy(valid_ref_u2w, {k:v[0] for k, v in utt2words.items()})
# v2.topk2 total=10000 corr=8429 err=1571, accuracy: 0.8429
# v2.topk5 total=10000 corr=8434 err=1566, accuracy: 0.8434
# v2.topk10 total=10000 corr=8388 err=1612, accuracy: 0.8388
# v3.topk10 total=10000 corr=8519 err=1481, accuracy: 0.8519  <--
# v3.11.11.topk10 total=10000 corr=8340 err=1660, accuracy: 0.834
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# геев гены
# была быстро
# рам нам
# шакалов заказала
# воля волосы
# ура уля
# шорты шорту
# корень удобно
# но но но но но но но но но но но
# купи курс
# говорить говорит
# водитель водителю
# вечером вечер
# фиолетовой фиолетовое
# выехал выезжать
# выздоравливай выдавливай
# черна черны
# выгуливать выгулить
# вызовов вызвала
# пробовал попробовать
# стать стараюсь
# отвечал отвечать
# ха за
# русскому русском
# мазок мазлолетка
# не на
# обувь обед
# завтра заработать
# он лорн
# никогда никого
# баба бабу
# но но но но но но но но но но но
# пойми пофиг
# кн еген
# виде видео
# пахлава пахова
# уезжай езжай
# прошу проще
# дура духов
# агапкина агркина
# ниже нижнее
# верон вероника
# анадырь аналогию
# лада ладно
# заберем забери
# завтра звоню
# тыс там
# стоит строит
# выбил фибир
# прошел пошел
# романович романтичная
# ирбит ирбить
# глав главное
# работы работаю
# доллар дождусь
# занимаешься заречь
# жень день
# приветик привет
# мм ммм
# выглядят выглядит
# крот корот
# потому плитки
# привете привет
# ест есть
# лежит делись
# но но но но но но но но но но но
# пойдут пойдет
# дека днем
# екб куб
# прожить пожить
# марин марии
# подпрыгнул подровнул
# лай дай
# был было
# проспект постельно
# считал считай
# заполнено заднено
# нами наси
# ну не
# система систем
# проснулась проснулся
# но нот
# заварили звонили
# понятно понятного
# но но но но но
# наказаний наказуй
# выход выходи
# нарисовал написал
# мине минера
# здорова здорово
# мерк мере
# забей заберу
# лэйбл любой
# саша сашас
# но но но но но
# билет билеты
# поверить поворот
# виза ариза
# скользко сколько
# бать брат
# спасителя спасибо
# все вместе
# души луши
# зажимают задерживаю
# бугун бегуер
# вот вот-то
# эволюцию эволюция
# уговорить уговорил
# реабилитироваться реабилитировать
# пеши решим
# ишачий играй
# не на
# попил платил
# работать работает
# др дорого
# подложку подожду
# полнейшей полнейший
# бел бед
# анаста анастасия
# дела делала
# норм ели
# лесов лесову
# вернуть вернут
# девиз делать
# ка как
# мм ип
# моей мой
# др дорого
# береги берем
# так та
# электричек экономчек
# россию росто
# ну ней
# рулит рулить
# куда-нибудь кулониту
# мозгов можно
# ваз вах
# до др
# двум даки
# будет будем
# махровый малохой
# бан баг
# такое твер
# каток каталась
# хотин хотик
# попасть плачь
# парк правок
# не нее
# лох плохо
# привожу приводу
# вам вас
# по про
# сопьюсь сопьются
# муму сумму
# сахар саша
# давай двойка
# иди или
# зарплату характер
# сиди сидим
# восстановить вистановать
# убила удобно
# ха-ха захар
# вон волн
# чехова чехол
# ну не
# кулису куличу
# ся мяся
# антоном анторе
# не нее
# состав составы
# вы вый
# нас нам
# ромку ромок
# или июри
# сожалению сожелению
# запись записываюсь
# говоря говорят
# шорты горты
# нравиться нравится
# выбивается выбирается
# мерей перец
# мама маму
# сообщили соболезно
# наименований наименование
# он один
# кинула кинуло
# приливов прилипы
# отдыхаешь отдыхать
# из их
# входная взрослая
# не ну
# древняя деревня
# сигну смогу
# ага анна
# снов серв
# называется назначения
# глазам глаза
# скачать скучать
# чей чай
# готовить готовиться
# удава удар
# про по
# стикер сбер
# блин болин
# супер скорее
# ахах ахахах
# блестит блестить
# ахаха ахахах
# побои побом
# по про
# не нее
# насыпала насыпка
# луж дед
# любую глеб
# домофона димомыона
# зарабатывали заработал
# присел примерно
# замечательное замечательно
# чет черт
# срочно солян
# радиатор работает
# жак дак
# баланс балан
# укрепляются крепляются
# сетку сестру
# приходит приходи
# калл кадро
# нк нее
# яр яро
# намного настроение
# хай зай
# поспи поспал
# давным дыня
# кайфовать камуди
# уже удобно
# большее больше
# произведение произвели
# се спе
# попадаются попадают
# идеей идей
# проверять проверяю
# пупка пупсика
# папа пара
# встретимся встретиться
# конца конечно
# здарова здорово
# если ели
# качестве кассиве
# гудят гулять
# белы белов
# вшивая ашотая
# умеет кинет
# заявкам зачем
# ном нос
# из-за моза
# не неа
# ахах ахахах
# то только
# разрешил разрешили
# брюшной брюшер
# той отой
# разная развелся
# будут будет
# случае случайно
# кп кпп
# но но но но но но но но но но но
# уж ужас
# вот аль
# звонил занимаешься
# мыслями мысля
# понедельник поедет
# призывников праздником
# жесть знаю
# колдуешь колгуешь
# покупку покуру
# тобой ильей
# мда мода
# мин мне
# каре карка
# выбил выбить
# созвучия созвучимся
# две доче
# ок оке
# смотала смотрела
# классный касный
# вот вот-то
# гости госта
# плов пора
# обезболивающие обезболивающее
# удалила кидали
# крошка кошка
# походом похожи
# читов чтобы
# мам мама
# меня пея
# или иди
# представляю представлю
# напала напал
# ахах ахахах
# зашить хочешь
# научится научиться
# школьники школьном
# кто-то кто
# виталия вирталия
# пс пасс
# шторм штором
# няней начней
# не нее
# одни один
# дилшод жизнь
# ветчина внимание
# балл бал
# домой зимой
# подали продали
# эдит жить
# купить купи
# толик только
# гнут гугл
# лежишь решишь
# ладно может
# фу вуфу
# игре игру
# девушка девушку
# лен ленен
# встретимся встретим
# сердечко сердце
# любовь люблю
# ка как
# кто утро
# ул ужас
# ма иа
# он ок
# убрать уезжать
# теперь будет
# не ну
# или иди
# брать боять
# приехали приезжай
# это жизнь
# авито авто
# перестанет перестал
# клан классно
# лице омун
# рф раф
# дорогостоящие догостоящие
# девкам девки
# ха за
# не нее
# не нее
# нет него
# стене стена
# что что-то
# то итог
# пороге порогу
# хороших хорошо
# будут буду
# же деле
# хахах хахаха
# знакомых занимаешься
# фрик факту
# объяснений объясни
# появилась появился
# ок окей
# спасибо спать
# не нее
# россии россия
# таки тупи
# далеко даже
# опал орал
# есть кси
# но но но но но но но но
# аккорды аккорда
# сказать чехол
# горит готовить
# щенка зеленка
# моющим млющим
# ду душу
# ну ней
# ахаха ахахах
# читаю стирал
# тетя тебя
# им ммм
# выключи выключить
# делала делаешь
# дело деньги
# фролов фолов
# машину машины
# авито авто
# может идет
# еда нда
# помогу потому
# проскочили поскочили
# цезарь узнать
# мигрируй мигируй
# забиваю заработать
# надо над
# счастьем счастье
# замерим заменим
# сч свя
# печорина песорина
# сказали скажи
# не нее
# бахает базарки
# самсонова самогона
# мен медленно
# данилом данила
# оскорблениями осколениями
# вор во
# дочь дост
# старая старым
# энди этом
# нормальное нормальнее
# работу работе
# считается считает
# водонагреватель водонагревательно
# братцы батуты
# да дыры
# ухе узе
# забыл забирать
# оно одно
# абу абе
# эту это
# почитай поставят
# пеги пени
# отошел отвечаешь
# про по
# ха за
# гас щас
# или иди
# ил или
# но нот
# нами нам
# делай лей
# козырь козырью
# не нее
# на га
# крутяк крутях
# ее елене
# чушь чувствуешь
# максимальном максимально
# угу внугу
# математика материчка
# есть ест
# но нот
# до да
# хм хи
# поселок командировку
# германии гермении
# нечего ничего
# сделать сдать
# вы вый
# надеж надежда
# ахаха ахахах
# доброй добрый
# маг маз
# за ха
# кофточку крысичку
# значки заявки
# пешим решим
# ввиду вижу
# та тв
# исключим искренний
# температур температура
# самара самый
# без тез
# вы авы
# нормативы нормальный
# ловит орать
# ответственно ответство
# красне краснее
# нета нету
# дворе двое
# просила послала
# спорт сорт
# горы года
# трест тест
# служило сделал
# да для
# план потан
# сидел силе
# фотку форму
# аванс пароль
# альба алиба
# что что-то
# снюс себя
# была было
# знаешь здесь
# наступающим насколько
# школу шелу
# кармане картинка
# менее мене
# ей ну
# съездить сбежать
# не нее
# спокойнее справляйся
# мен мене
# не на
# вставил вставать
# ждать жрать
# менде медленная
# ахах ахахах
# брюнетку брюнест
# имя ия
# приехать приехал
# ан анн
# жесть одевать
# овен равно
# чем вес
# стоят стоя
# не нее
# му мк
# земельный землей
# завтрак забрала
# но но но но но но но но но но но
# детройт дельфин
# продавал подруга
# специалиста специальство
# рита пита
# требований требовает
# димуль дискорд
# но ел
# кузьмина евгений
# см ммм
# климент кливить
# мама маму
# манхва манза
# ребятишки ребишки
# показывают показать
# космо кесто
# положить положу
# превысил превыми
# по под
# хахахаха хахаха
# придешь приедешь
# варик вариант
# овощей окей
# уазик казик
# деле лебеде
# случится случиться
# денег легко
# от ооо
# альбом адрес
# отличник отличное
# хорошо хорошая
# промо просто
# денег деген
# чемпионом чемпион
# успех успехи
# пан папа
# мной монор
# ванечка вашечка
# тц ту
# назвали название
# заметила замена
# изо из-за
# осталась осталось
# задержка забуду
# документы другие
# озера озеру
# вк вкве
# го огромного
# до да
# мне мен
# встать вставать
# пожалуйста продайте
# ален аленене
# подзатыльник пожалуйста
# или иди
# завершающий звершающий
# уф уфу
# про по
# капец каречка
# туч трус
# му су
# не на
# ранг ранга
# раза разве
# минут минутки
# крута крутая
# на рев
# че ян
# магната маргарита
# довела давно
# корейцы корейца
# ша ща
# назвала название
# успеваю скрыть
# дочь даст
# вернусь вернуть
# хотя родится
# дота дома
# ку куку
# но но но но но но но но но но но
# авы авуф
# не нее
# но но но но но но но но но но но
# не нее
# иринка инка
# хочет хочешь
# вакуумные вакумные
# царство цастава
# тосно точно
# хоро хорошо
# но но но но но но но
# эм эс
# однокурсницы одноклассница
# получится волочки
# ампутация амутация
# года голова
# школьником зельником
# сектор скинь
# сложно сдохла
# негр нечего
# ато аил
# воды алы
# или иди
# ранняя раняя
# се себе
# ей ейк
# камень-на-оби каменьками
# смолу смогу
# сама масса
# имея иская
# искала исказала
# нега негр
# пойдем пойдет
# речи речь
# закончили заклеевич
# но но но но
# вашим видим
# итоге итогу
# лариска ларика
# не нее
# котят удобят
# кричи кричит
# написала нарисовала
# муза муха
# не на
# прийти прийди
# но но но но но но но но но но
# сум сумка
# мягко мягких
# прилетаете прилетает
# готово группе
# нудна нужна
# салам салом
# люди ляба
# если ест
# хочу худой
# про по
# но но но но но но но но но
# цыпленок цыленок
# разорвало разрывало
# конец колей
# ну не
# направлении наработаешь
# красному красноту
# ах ахах
# оттепель отрепель
# начало начал
# покажи понял
# света все-таки
# хуже хеделе
# таджикистан таджики
# видео видел
# казино козино
# сколько супер
# топ том
# дома доме
# требуется треугольник
# тут тупи
# было был
# на га
# снов сена
# сверхъестественного сверхностество
# пожарить подпись
# ив ива
# череп черепа
# внимания внимание
# наконец-то национ
# уж удобно
# кроссовки красивки
# камере камеле
# галочкой галяйд
# наорала направлять
# единственное ездили
# поменять поменяешь
# наверно наверное
# не нее
# пойдешь пойдет
# па папа
# не нее
# хеппи знаю
# душ друг
# зал зао
# холод холодно
# го ого
# трио тритории
# ковтун кладун
# кипр кипо
# уж ужас
# аз аза
# маленьких маленький
# обидел обидно
# но но но но но но
# павильоне автоге
# алисы плив
# памяти памиси
# похож подход
# комп компе
# присяги приятного
# сентября сестра
# брад бад
# фу леные
# заряжается заражается
# топ топа
# бургер бегер
# менее мнение
# наггетсы нашетая
# но но но но но но но но но но но
# клиент едет
# призвание пришел
# вена вагна
# элена элега
# нас на
# про по
# подругой подруга
# участок участке
# ух узнаешь
# банд баню
# ух узнаешь
# там таким
# объекте обед
# своим своими
# двухстороннем двухсторонни
# таких твоих
# но но но но
# что что-то
# катта ката
# над народ
# любом любим
# ипотеку ипотеке
# по ал
# человек чела
# аллохол плохо
# есть ест
# он один
# буду буд
# такое твое
# медкарте медкарие
# кук куку
# мной игру
# скок скорее
# не нее
# выходит выходить
# хот хоть
# почитаю прочитаю
# ярмак ярма
# придете прилете
# оплате оплата
# района район
# не нее
# ом омс
# ими имми
# удлинитель водитель
# стс ситис
# ставок старые
# его угол
# про по
# об о об об
# лодки ордки
# впереди вереди
# отвезли отвези
# по пол
# посмотрим пособии
# но но но но но но но но но но но
# норидж норд
# все-таки васетки
# единорога единок
# инк мне
# ура уда
# не нее
# гей шоу
# лык лые
# русской рублей
# инсайд инсайды
# бабуина бабушки
# буду будут
# возьми возьму
# курят кунчер
# прослушал послушал
# предлагает предлагал
# сто что
# поль побью
# стоял стоят
# ели едет
# миф мой
# машинку машинцы
# встретиться вспомнить
# дошло дорого
# кошмаров комаров
# расставлены растаона
# попала пропадала
# стад стаж
# блюд люблю
# уж ужас
# разыграю развлегаю
# тряпки тряпке
# предал предатель
# твои твоим
# есть ест
# политикам плиткам
# опять отправят
# отвлекайте рисункой
# го ого
# можно может
# брат трата
# веселее вселе
# балан баргана
# церкви цена
# там так
# лан лага
# спряталась считалось
# папу пару
# взаимно азамно
# сжато сдать-то
# схожу схоже
# постоянно последняя
# город голод
# оденьте одному
# знаю наю
# машине магните
# чем сем
# юля бюда
# го ооо
# трезв тореза
# но но но но но но но но
# аптека аппетита
# удобно убери
# дома драм
# так тара
# ок оке
# катала кстати
# лови дат
# свершилось свершилась
# присылай привык
# банан бананан
# приват привет
# ахах ахахах
# кун кунгун
# сегодня себя
# узнаешь узнает
# жен жененен
# хахаха хахахаха
# не нее
# разочарован разочаровала
# ко кол
# которой которые
# во вол
# почти прят
# бяка бьяка
# заходишь захочешь
# межрайонным международная
# моей мой
# или иди
# дури дурак
# до да
# желаю делаю
# не нее
# манга мега
# фольсваген формагер
# эй жуй
# оформляем оформляет
# выглядите выглядит
# твитом твиртом
# мам мама
# хз хахахаха
# за ща
# да дак
# так тк
# ты тв
# канала канаблю
# дают делают
# не не не не не
# выиграл август
# звуковой заковой
# мак су
# спекулятивной спекулятор
# вывелись вывестить
# мироточить миротость
# кв ев
# отгадали отглядит
# скорее скоро
# кори корми
# работы работай
# отсталый отсталой
# нашел нашего
# александр александра
# крыльцо крыльца
# поел плед
# иди или
# смыла смысл
# ванн ванван
# похвастаться позвать
# не на
# не не не не не не не не
# что что-то
# аксен аксе
# облегчить обменами
# выспаться выспался
# оставить оставь
# не нее
# смысла святой
# четверг сметанг
# иле иду
# уходит уходить
# отвертки ответки
# анют анюта
# интересно интересе
# печаль поняла
# фо форд
# адрес адресе
# не нее
# мин син
# не нее
# токо тонко
# корм короче
# ничем очень
# навигаторе неправильно
# черкасская черковская
# ку куку
# дл дим
# сыну мыгу
# не нечего
# продаю продуб
# обойдусь обойду
# съезди страшно
# мерь мерт
# спросила спросите
# страшного страшно
# но ноо
# пап папа
# мертвая серия
# больница больнице
# кишиневе кизиневе
# но но но но но но но но но но но
# садике садики
# ссориться смотря
# культ культура
# наше нашел
# воскресенье воспитатели
# ты та
# конечной конченый
# половины половина
# галер гроер
# заварка харка
# еловой едовой
# дорой дорогой
# планировала планировал
# генеральный негеновольный
# но но но
# выборе выйдет
# увы цавы
# боятся бесятся
# но но но но но но но
# завотделением завоттеление
# вас вам
# скороходов скорохода
# братск братс
# да дарова
# аргонавтов аргонавира
# свечи свечить
# спокойной спокойно
# доставке доставе
# обзор общаться
# хз хахаха
# скетч суета
# шло шоло
# под пол
# вождения водолели
# не ну
# ножом ножи
# выдержу вылежу
# неприятно неприрянет
# александр александра
# ездил ездили
# вспомни вспомнить
# поэтому аэтому
# все всем
# но но но но но но но но но но но
# вернут вернуть
# но но но но но но
# выдано выдан
# перерыл перевод
# силу сижу
# данила дашила
# терпеливее терпеливе
# робот оборот
# пике пикник
# заявления заявление
# но но но но
# франция франья
# но но но но но но но
# живем живет
# рим ним
# сосуды соскучился
# спасибо спрашивал
# отпрашивалась отправшивалась
# умею амед
# пил пилил
# момент москва
# уже кэн
# видел видео
# неделе нужен
# изменчивости изменствовать
# урожай кодой
# мамбо масло
# во вол
# удалила удала
# знакомств зеркала
# ок оке
# не нее
# ас асс
# го ого
# но но но но но но но но но но но
# больше большое
# буру буду
# рукам руки
# другое другие
# вместе аместр
# моя идиос
# следила сделал
# ха за
# тебе ребенок
# па папа
# сф ссы
# штекера штукера
# катридж кирилл
# директор живете
# занятия занимаешься
# заработал заработать
# дружбу дружба
# димой дмитрий
# раздевала раздевалась
# пойдет пойдут
# говорить говорит
# дора давы
# гог ого
# копится копиться
# перезаписала переездом
# пк пака
# стою сб
# не нее
# именно много
# такое твое
# хочется хватит
# кисель кисел
# нурлан нурал
# классные класные
# когда кеды
# дума думаю
# не нее
# глаза гараже
# вольтаж водитель
# не нее
# хорош хорошо
# нами наст
# мурано муравер
# то ооо
# аренда поела
# как кан
# леша леш
# то ооо
# себе честно
# русский русская
# появляется проявляется
# пугай пугой
# тайна тайга
# лада орала
# он один
# увезет увезти
# милаш позвоню
# октмо окимо
# прекращай переращай
# сделана сделает
# вызвать вызови
# запчасти запятия
# цена уга
# мартовские мартов
# шаманил шаманис
# напарница напаница
# нужно нужна
# ночи ночь
# не нее
# ростовом ростова
# испортить историю
# случайно саручке
# мяч мяся
# расскажу рассказу
# не нее
# не не не
# откроется откровения
# из их
# тандыра танцевал
# алис полис
# проиграть приготовила
# огромное ограничение
# катают кстати
# сколько склад
# хиро хитро
# игра игру
# буду буд
# апелляции апельсин
# подразделение подошление
# еду еде
# про по
# понятно понятном
# думаю детскую
# тебе третье
# им ммм
# все-таки все
# не нее
# кривда кричала
# подарки продает
# офигеть двигать
# гм гиги
# про по
# дешевое дешевле
# придти пришли
# нее не
# молочка слочка
# колер козни
# кирилл кил
# тима типа
# вон вроде
# стояк старые
# лена легче
# перед передел
# александров александр
# ка как
# пополняют пополняются
# воскреснет воскресенье
# кровных кроватных
# се себе
# внимания внимание
# овощами рахмат
# но но но но но но но но но но но
# успею успеваю
# мы иры
# случилось случаело
# ау ппц
# было был
# пап папа
# не на
# баран барана
# цементом цементкой
# будет будем
# фархад форзал
# подсолнечное подсолнечно
# обеда обещала
# разговаривать раздавать
# он они
# мне моне
# сони мони
# выпало выпала
# по пил
# где глюк
# вдруг волосы
# пообедать пробежать
# посмотреть посидеть
# мам мама
# сообщений союзный
# парень паню
# де деле
# пожалуйста пожалуйся
# звони заполни
# го ого
# но но но но но но но но
# про по
# прости пробить
# дей дней
# еду еще
# ассоциируюсь ассоцость
# по пошла
# то тон
# народу наберу
# обтираться обираться
# не нее
# не нее
# гране грана
# стала стало
# просто нормально
# вечер вечно
# интересуется интернемся
# пока попу
# нс нас
# проводов провод
# упругие кругие
# иди или
# графике график
# ваще важен
# сделала сделал
# кто кир
# быть басть
# просто прости
# проезжал проезжаешь
# будешь будет
# было был
# гашека гашка
# болеют болью
# нами нам
# технология технолог
# врача воян
# дают-бери дадибери
# прям прят
# промыл помыл
# баб бабки
# ок оке
# следующий сделаю
# интересно инсте
# говорю говолю
# читеры стеры
# записал занимаешься
# леш лещ
# режиссер режет
# работы работа
# сообщу пользу
# нег неге
# сделаю можно
# прилетела придется
# но нового
# прощаю подъезжаю
# люблю любовь
# обещаю общаюсь
# скин скинь
# гулять гуляю
# пошлое прошлое
# халтуры хартуры
# ель едь
# узбекский вишний
# посмотри простом
# он один
# приятно приятного
# фиат фита
# нравится новости
# сестренка сестра
# эффект эфект
# та ты
# отношениях отношених
# хату зовету
# ворчать врачать
# нее не
# оке окну
# зоя зря
# крестить крутить
# не нее
# инсульт инскоп
# твоя тадя
# люби любит
# существительные существованные
# ок оке
# не не не
# влезет влезешь
# не нее
# тепло терпеть
# телевизор троллевизор
# давид данил
# отжимает отживет
# пластмассовые пластиковые
# роспотребнадзор россортина
# мс мссс
# калеки каролки
# дилер жилер
# ник никак
# ай ппц
# ку куку
# застонала застонара
# вылил формо
# валерьевич волькович
# пойдешь пойду
# здравствуйте здаровать
# то ото
# мелочи мелочь
# класса касса
# будет бедко
# мне минера
# ну не
# менеджеру мандеру
# ватт вампит
# холод холодо
# да за
# прошла пошла
# не нее
# понравились понравилось
# мечты сестры
# города годом
# видео видел
# было был
# булкой будкой
# алма алиса
# денете ленте
# мексика местка
# общения общаешься
# серым снесет
# тан банке
# одежда одного
# обеих обнимах
# не ну
# обращайся обращай
# поста посмотрим
# застолье застолько
# качки какие
# во вал
# опаздывай опаздываю
# устроил кирилл
# отдал отдать
# ооо оператор
# полковником проковником
# домик дмитак
# долго один
# сказал сказать
# вот вот-то
# налетят надеяться
# рассмеялся рассеялся
# ерундой ерундар
# не нее
# возьмем возьмет
# муз мух
# ниже нижнее
# аст всю
# звонит звонить
# кеча кечатка
# пропадут пропадет
# ха за
# факел факрон
# антон антоп
# кака как
# шрам шам
# про по
# встаю встать
# да дак
# ножовка ножка
# куп кур
# бед обед
# ясно что
# чернобыль черностью
# этим этимис
# защищаться заниматься
# мента метанта
# беларуси беларису
# более болел
# венецианский верейский
# украинский украински
# термоса термоста
# возим водили
# учи умит
# согласна согласно
# не нее
# заходить защит
# расстраивайся расставайся
# поорет пораньше
# ля для
# завистливый зависимый
# ирина мирсина
# не нее
# про по
# люк любое
# ян яня
# расстались реально
# двигается двигаться
# понравилось поговорю
# задать задам
# дед дел
# аз ахах
# ну не
# бывало было
# быстрей быстрее
# солидному слидному
# груш груз
# подстригаться подстроился
# ваш виш
# плевал плево
# пойдет пойду
# султанша султанга
# январь января
# рекорд реколол
# жор это
# го ого
# хорошего хорошее
# хз хахах
# аза ахаха
# жкх женух
# весить весь
# ехать уехать
# понедельник поедем
# эд эл
# пф айф
# дизель жизнь
# чон сон
# под подло
# начнет насте
# самую самволю
# военное военно
# турист турить
# морковкой моковкой
# вариантов вариант
# го ого
# помню помогаю
# не нее
# картриджем картошем
# поискать поиски
# висит вита
# тубик трубик
# бессонница бессонницы
# нее не
# вопросу волосы
# лол доллар
# иметь ита
# переломе переживай
# что что-то
# не нее
# германа геомна
# на га
# своих сах
# досвидос появился
# выскакивает высказу
# но но но но но но но но но но но
# нас нет
# выходим выходи
# стену стану
# удачного классного
# арктик артем
# до додо
# де деле
# нет лет
# своей свое
# вот вот-то
# варик вариант
# скажу скажешь
# не нее
# работать работаю
# продан план
# на нас
# газ газа
# ну ней
# дул дуд
# твой трав
# повод провод
# приехал приезжай
# вика все
# его ешь
# виктор вместо
# выключен выкладывает
# дочь дичь
# великолукский великолепный
# опоздаю раздаю
# потерпи потерпишь
# неа на
# про по
# местом место
# легко леша
# пола план
# секрет через
# проблемы проблем
# кто круто
# сказки сказали
# чет чем
# мы ива
# маленькие магенькие
# же эле
# был было
# сто что
# дочь дат
# тв ты
# хаз хахаха
# поняла понравится
# худам худом
# этому эту
# наклейки наклейку
# эффект эфект
# входящие входите
# total=10000 corr=8519 err=1481, accuracy: 0.8519
# 0.8519

# %%
with open('./data/voc.txt') as f:
    vocab = frozenset(s for s in map(str.strip, f.readlines()))

# %%
lv = {}
for k, v in utt2words.items():
    corr_w = None
    for w in v:
        if w in vocab:
            corr_w = w
            break
    if corr_w is None: 
        logging.warning(f"{k=} doesn't have any vocab hyp. {v=}")
        corr_w = '-'
    lv[k] = corr_w
accuracy(valid_ref_u2w, lv)
# v2.topk10 total=10000 corr=8542 err=1458, accuracy: 0.8542
# v3.topk10 total=10000 corr=8665 err=1335, accuracy: 0.8665
# v3.11.11.topk10 total=10000 corr=8429 err=1571, accuracy: 0.8429
# Out:
# 2023-11-11 12:53:18,788 root /tmp/ipykernel_1214228/618118840.py:9 - WARNING - k='valid-300' doesn't have any vocab hyp. v=['пахова', 'пахода', 'разова', 'пахолава', 'пахолова', 'пахлова', 'паховка', 'пазова', 'пахолва', 'паходва']
# 2023-11-11 12:53:18,789 root /tmp/ipykernel_1214228/618118840.py:9 - WARNING - k='valid-1131' doesn't have any vocab hyp. v=['вистановать', 'вистановат', 'висимовать', 'вистановить', 'висторговать', 'вистиновать', 'вистановато', 'висторонность', 'вьютиновать', 'вистроноват', 'вистроновато', 'висторонновать']
# 2023-11-11 12:53:18,792 root /tmp/ipykernel_1214228/618118840.py:9 - WARNING - k='valid-4318' doesn't have any vocab hyp. v=['каменьками', 'каменьки', 'камению', 'каменька', 'каменькарти', 'каменькарск', 'каменьшая', 'каменьюща', 'каменькартов', 'каменькартом', 'каменькартова', 'каменькартин', 'каменькарт', 'каменька-ню']
# 2023-11-11 12:53:18,794 root /tmp/ipykernel_1214228/618118840.py:9 - WARNING - k='valid-6637' doesn't have any vocab hyp. v=['завоттеление', 'заворотление', 'завотледение', 'завотлетние', 'завотеление', 'завотлетение', 'завотделение', 'заворотеление', 'завотреление', 'завотлешение']
# 2023-11-11 12:53:18,795 root /tmp/ipykernel_1214228/618118840.py:9 - WARNING - k='valid-7412' doesn't have any vocab hyp. v=['саручке', 'сарусе', 'сарусейн', 'саручек', 'сарусцев', 'сарусей', 'сарусель', 'маручен', 'свойке', 'сарусце', 'саруске', 'марусейн']
# 2023-11-11 12:53:18,796 root /tmp/ipykernel_1214228/618118840.py:9 - WARNING - k='valid-8569' doesn't have any vocab hyp. v=['россортина', 'россортинажная', 'россионадная', 'россионажная', 'россионадна', 'россионажна', 'россортинажна', 'россионад', 'россортинажный', 'россортинальная', 'россортинадная', 'россортинальд']
#   0%|          | 0/10000 [00:00<?, ?it/s]
# геев гены
# была быстро
# рам нам
# шакалов заказала
# воля волосы
# ура уля
# корень удобно
# купи курс
# говорить говорит
# водитель водителю
# вечером вечер
# фиолетовой фиолетовое
# выехал выезжать
# выздоравливай выдавливай
# черна черны
# выгуливать выгулять
# вызовов вызвала
# пробовал попробовать
# стать стараюсь
# отвечал отвечать
# ха за
# русскому русском
# мазок мажора
# не на
# обувь обед
# завтра заработать
# он борн
# никогда никого
# баба бабу
# пойми пофиг
# кн угу
# виде видео
# пахлава
# уезжай езжай
# прошу проще
# дура духов
# агапкина агрессии
# ниже нижнее
# верон вероника
# анадырь аналогию
# лада ладно
# заберем забери
# завтра звоню
# тыс там
# стоит строит
# выбил футболка
# прошел пошел
# романович романтичная
# глав главное
# работы работаю
# доллар дождусь
# занимаешься закончилась
# жень день
# приветик привет
# мм ммм
# выглядят выглядит
# крот корот
# потому плитки
# привете привет
# ест есть
# лежит делись
# пойдут пойдет
# дека днем
# екб куб
# прожить пожить
# марин марии
# лай дай
# был было
# проспект приятного
# считал считай
# нами наст
# ну не
# система систем
# проснулась проснулся
# но нот
# заварили звонили
# понятно понятного
# наказаний наказывай
# выход выходи
# нарисовал написал
# мине минера
# здорова здорово
# мерк мере
# забей заберу
# лэйбл любой
# билет билеты
# поверить поворот
# виза ариша
# скользко сколько
# бать брат
# спасителя спасибо
# все вместе
# души луги
# зажимают задерживаю
# бугун бегут
# эволюцию эволюция
# уговорить уговорил
# реабилитироваться реабилитировать
# пеши решим
# ишачий играй
# не на
# попил платил
# работать работает
# др дорого
# подложку подожду
# полнейшей полнейший
# бел бед
# анаста анастасия
# дела делала
# норм ели
# вернуть вернут
# девиз делать
# ка как
# мм ип
# моей мой
# др дорого
# береги берем
# так та
# россию росто
# ну ней
# рулит рулить
# мозгов можно
# ваз вах
# до др
# двум даки
# будет будем
# махровый мажоры
# бан баг
# такое точно
# каток каталась
# хотин хотите
# попасть плачь
# парк правок
# не нее
# лох плохо
# привожу приводу
# вам вас
# по про
# сопьюсь сопьются
# муму сумму
# сахар саша
# давай двойка
# иди или
# зарплату характер
# сиди сидим
# восстановить
# убила удобно
# ха-ха захар
# вон волн
# чехова чехол
# ну не
# ся мя
# антоном антон
# не нее
# состав составы
# вы вый
# нас нам
# ромку росте
# или июля
# сожалению сожелению
# запись записываюсь
# говоря говорят
# шорты готовы
# нравиться нравится
# выбивается выбирается
# мерей перец
# мама маму
# сообщили собираешься
# наименований наименование
# он один
# кинула кинуло
# приливов прилив
# отдыхаешь отдыхать
# из их
# входная взрослая
# не ну
# древняя деревня
# сигну смогу
# ага анна
# снов серв
# называется назначения
# глазам глаза
# скачать скучать
# чей чай
# готовить готовиться
# удава удар
# про по
# стикер сбер
# блин болин
# супер скорее
# ахах ахахах
# ахаха ахахах
# по про
# не нее
# насыпала насыпка
# луж дед
# любую глеб
# зарабатывали заработал
# присел примерно
# замечательное замечательно
# чет черт
# срочно советы
# радиатор работает
# жак дак
# баланс балан
# сетку сестру
# приходит приходи
# калл кала
# нк нее
# яр яро
# намного настроение
# хай зай
# поспи поспал
# давным дыня
# кайфовать камуфляж
# уже удобно
# большее больше
# произведение произвели
# се себе
# попадаются попадают
# идеей идей
# проверять проверяю
# пупка пупсика
# папа пара
# встретимся встретиться
# конца конечно
# здарова здорово
# если ели
# качестве кассире
# гудят гулять
# белы белов
# вшивая вторая
# умеет кинет
# заявкам зачем
# ном нос
# не неа
# ахах ахахах
# то только
# разрешил разрешили
# брюшной большое
# разная развелся
# будут будет
# случае случайно
# кп кпп
# уж ужас
# вот аль
# звонил занимаешься
# мыслями мысля
# понедельник поедет
# призывников праздником
# жесть знаю
# колдуешь концерт
# покупку покупай
# тобой ильей
# мда мода
# мин мне
# каре какое
# выбил выбить
# созвучия созвонимся
# две даче
# ок оке
# смотала смотрела
# классный кассовый
# гости госта
# плов пора
# обезболивающие обезболивающее
# удалила кидали
# крошка кошка
# походом похожи
# читов чтобы
# мам мама
# меня песня
# или иди
# представляю представлю
# напала напал
# ахах ахахах
# зашить хочешь
# научится научиться
# школьники школьном
# кто-то кто
# виталия виртуальная
# пс пасс
# не нее
# одни один
# дилшод жизнь
# ветчина внимание
# балл бал
# домой зимой
# подали продали
# эдит жить
# купить купи
# толик только
# гнут гугл
# лежишь решишь
# ладно может
# фу фу-фу
# игре игру
# девушка девушку
# встретимся встретим
# сердечко сердце
# любовь люблю
# ка как
# кто утро
# ул ужас
# ма иа
# он ок
# убрать уезжать
# теперь будет
# не ну
# или иди
# брать бояться
# приехали приезжай
# это жизнь
# авито авто
# перестанет перестал
# клан классно
# лице ответ
# рф раф
# девкам девки
# ха за
# не нее
# не нее
# нет него
# стене стена
# что что-то
# то итог
# пороге порогу
# хороших хорошо
# будут буду
# же деле
# хахах хахаха
# знакомых занимаешься
# фрик факту
# объяснений объясни
# появилась появился
# ок окей
# спасибо спать
# не нее
# россии россия
# таки тупи
# далеко даже
# опал орал
# есть кси
# аккорды аккорда
# сказать чехол
# горит готовить
# щенка зеленка
# ду душу
# ну ней
# ахаха ахахах
# читаю стирал
# тетя тебя
# им ммм
# выключи выключить
# делала делаешь
# дело деньги
# фролов фолов
# машину машины
# авито авто
# может идет
# еда нда
# помогу потому
# цезарь узнать
# забиваю заработать
# надо над
# счастьем счастье
# замерим заменим
# сч ся
# печорина ресторана
# сказали скажи
# не нее
# бахает базарит
# самсонова самогона
# мен медленно
# данилом данила
# вор во
# дочь достать
# старая старым
# энди этом
# нормальное нормальнее
# работу работе
# считается считает
# братцы батуты
# да дыры
# ухе узе
# забыл забирать
# оно одно
# абу абе
# эту это
# почитай поставят
# пеги пени
# отошел отвечаешь
# про по
# ха за
# гас щас
# или иди
# ил или
# но нот
# нами нам
# делай лей
# не нее
# на га
# ее елене
# чушь чувствуешь
# максимальном максимально
# угу агу
# математика материка
# есть ест
# но нот
# до да
# хм хи
# поселок командировку
# германии герои
# нечего ничего
# сделать сдать
# вы вый
# надеж надежда
# ахаха ахахах
# доброй добрый
# маг маз
# за ха
# кофточку кофту
# значки заявки
# пешим решим
# ввиду вижу
# та тв
# исключим искренний
# температур температура
# самара самый
# без тез
# вы авы
# нормативы нормальный
# ловит орать
# ответственно ответствен
# красне краснее
# нета нету
# дворе двое
# просила послала
# спорт сорт
# горы года
# трест тест
# служило сделал
# да для
# сидел силе
# фотку форму
# аванс пароль
# альба адидас
# что что-то
# снюс себя
# была было
# знаешь здесь
# наступающим насколько
# кармане картинка
# менее мене
# ей ну
# съездить сбежать
# не нее
# спокойнее справляйся
# мен мене
# не на
# вставил вставать
# ждать жрать
# менде медленная
# ахах ахахах
# брюнетку брюками
# имя ия
# приехать приехал
# ан анн
# жесть одевать
# овен равно
# чем вес
# стоят стоя
# не нее
# му мк
# земельный землей
# завтрак забрала
# детройт дельфин
# продавал подруга
# специалиста специально
# рита пита
# требований требование
# димуль дискорд
# но ел
# кузьмина евгений
# см ммм
# климент удивить
# мама маму
# показывают показать
# космо кем-то
# положить положу
# превысил первыми
# по под
# хахахаха хахаха
# придешь приедешь
# варик вариант
# овощей окей
# деле лебеде
# случится случиться
# денег легко
# от ооо
# альбом адрес
# отличник отличное
# хорошо хорошая
# промо просто
# денег деген
# чемпионом чемпион
# успех успехи
# пан папа
# мной много
# тц ту
# назвали название
# заметила замена
# изо из-за
# осталась осталось
# задержка забуду
# документы другие
# озера озеру
# вк вечер
# го огромного
# до да
# мне мен
# встать вставать
# пожалуйста продайте
# ален алене
# подзатыльник пожалуйста
# или иди
# про по
# капец карев
# туч трус
# му су
# не на
# ранг ранга
# раза разве
# минут минутки
# крута крутая
# на рев
# че ян
# магната маргарита
# довела давно
# корейцы корейца
# ша ща
# назвала название
# успеваю скрыть
# дочь даст
# вернусь вернуть
# хотя родится
# дота дома
# ку куку
# авы аву
# не нее
# не нее
# иринка инка
# хочет хочешь
# вакуумные вкусные
# царство царства
# тосно точно
# хоро хорошо
# эм эс
# однокурсницы одноклассница
# получится волчки
# года голова
# сектор скинь
# сложно сдохла
# негр нечего
# ато аил
# воды алы
# или иди
# ранняя раня
# се себе
# камень-на-оби
# смолу смогу
# сама масса
# имея иску
# нега негр
# пойдем пойдет
# речи речь
# закончили закончился
# вашим видим
# итоге итогу
# не нее
# котят удалять
# кричи кричит
# написала нарисовала
# муза муха
# не на
# сум сумка
# мягко мягких
# прилетаете прилетает
# готово группе
# нудна нужна
# салам салом
# люди люба
# если ест
# хочу худой
# про по
# цыпленок йогурт
# разорвало разрывало
# конец колей
# ну не
# направлении наработаешь
# красному красноту
# ах ахах
# оттепель откроешь
# начало начал
# покажи понял
# света все-таки
# таджикистан таджики
# видео видел
# казино козино
# сколько супер
# топ том
# дома доме
# требуется треугольник
# тут тупи
# было был
# на га
# снов сена
# сверхъестественного серьезно
# пожарить подпись
# ив ива
# череп черепа
# внимания внимание
# наконец-то наконец
# уж удобно
# кроссовки красавки
# галочкой наличкой
# наорала направлять
# единственное ездили
# поменять поменяешь
# наверно наверное
# не нее
# пойдешь пойдет
# па папа
# не нее
# хеппи знаю
# душ друг
# зал зао
# холод холодно
# го ого
# трио три-то
# ковтун клубе
# уж ужас
# аз аза
# маленьких маленький
# обидел обидно
# павильоне пароле
# алисы полив
# памяти пассив
# похож подход
# комп компе
# присяги приятного
# сентября сестра
# брад бад
# фу пенные
# заряжается заражается
# топ топа
# бургер будет
# менее мнение
# наггетсы нашелся
# клиент едет
# призвание пришел
# вена вагона
# нас на
# про по
# подругой подруга
# участок участке
# ух узнаешь
# банд баню
# ух узнаешь
# там таким
# объекте обед
# своим своими
# двухстороннем двухсторонний
# таких твоих
# что что-то
# катта ката
# над народ
# любом любим
# ипотеку ипотеке
# по ал
# человек чела
# аллохол плохо
# есть ест
# он один
# буду буд
# такое твое
# кук куку
# мной игру
# скок скорее
# не нее
# выходит выходить
# хот хоть
# почитаю прочитаю
# ярмак ярма
# придете прилете
# оплате оплата
# района район
# не нее
# ом ос
# удлинитель водитель
# ставок старые
# его угол
# про по
# лодки одет
# впереди вернешь
# отвезли отвези
# по пол
# посмотрим пособии
# норидж норд
# все-таки все
# единорога единое
# инк мне
# ура уда
# не нее
# гей шоу
# русской рублей
# инсайд инсайды
# бабуина бабушки
# буду будут
# возьми возьму
# курят кусал
# прослушал послушал
# предлагает предлагал
# сто что
# поль побью
# стоял стоят
# ели едет
# миф мой
# встретиться вспомнить
# дошло дорого
# кошмаров комаров
# расставлены расстановка
# попала пропадала
# стад стаж
# блюд люблю
# уж ужас
# тряпки тряпке
# предал предатель
# твои твоим
# есть ест
# политикам плиткам
# опять отправят
# отвлекайте отвлекай
# го ого
# можно может
# брат трата
# веселее вселен
# балан бригада
# церкви цена
# там так
# лан лага
# спряталась считалось
# папу пару
# взаимно админом
# сжато михаил
# схожу схоже
# постоянно последняя
# город голод
# оденьте одному
# знаю наю
# машине магните
# чем сем
# юля бюджет
# го ооо
# трезв тореза
# аптека аппетита
# удобно убери
# дома драм
# так тара
# ок оке
# катала кстати
# лови дат
# свершилось свершилась
# присылай привык
# банан бананан
# приват привет
# ахах ахахах
# кун кунг
# сегодня себя
# узнаешь узнает
# жен женен
# хахаха хахахаха
# не нее
# разочарован разочаровала
# ко кол
# которой которые
# во вол
# почти прям
# бяка быка
# заходишь захочешь
# межрайонным международная
# моей мой
# или иди
# дури дурак
# до да
# желаю делаю
# не нее
# манга мега
# фольсваген фольксваген
# эй жуй
# оформляем оформляет
# выглядите выглядит
# мам мама
# хз хахахаха
# за ща
# да дак
# так тк
# ты тв
# канала канада
# дают делают
# выиграл август
# мак су
# спекулятивной специальный
# вывелись вывесить
# мироточить миртом
# кв ев
# отгадали отдали
# скорее скоро
# кори корми
# работы работай
# отсталый отсталой
# нашел нашего
# александр александра
# крыльцо крыльца
# поел плед
# иди или
# смыла смысл
# ванн ван
# похвастаться позвать
# не на
# что что-то
# облегчить обменами
# выспаться выспался
# оставить оставь
# не нее
# смысла святой
# четверг сметан
# иле иду
# уходит уходить
# анют анюта
# интересно интересе
# печаль поняла
# фо форд
# адрес адресе
# не нее
# не нее
# токо тонко
# корм короче
# ничем очень
# навигаторе неправильно
# ку куку
# дл дим
# не нечего
# продаю продут
# обойдусь обойду
# съезди страшно
# мерь мет
# спросила спросите
# страшного страшно
# но ноо
# пап папа
# мертвая серия
# больница больнице
# садике садики
# ссориться смотря
# культ культура
# наше нашел
# воскресенье воспитатели
# ты та
# конечной конченый
# половины половина
# заварка заправка
# еловой новой
# дорой дорогой
# планировала планировал
# выборе выйдет
# боятся бесятся
# завотделением
# вас вам
# скороходов скорохода
# да дарова
# аргонавтов аппаратов
# спокойной спокойно
# обзор общаться
# хз хахаха
# скетч суета
# шло шол
# под пол
# вождения вождение
# не ну
# ножом ножи
# выдержу вылезу
# александр александра
# ездил ездили
# вспомни вспомнить
# все всем
# вернут вернуть
# выдано выдан
# перерыл перевод
# силу сижу
# данила дарила
# терпеливее терпелива
# робот оборот
# пике пикник
# заявления заявление
# франция франты
# живем живет
# рим ним
# сосуды соскучился
# спасибо спрашивал
# умею видел
# пил пилил
# момент москва
# видел видео
# неделе нужен
# изменчивости изменению
# урожай кодой
# мамбо масло
# во вол
# удалила удала
# знакомств зеркала
# ок оке
# не нее
# ас асс
# го ого
# больше большое
# буру буду
# рукам руки
# другое другие
# моя или
# следила сделал
# ха за
# тебе ребенок
# па папа
# сф мы
# штекера штукатура
# катридж кирилл
# директор живете
# занятия занимаешься
# заработал заработать
# дружбу дружба
# димой дмитрий
# раздевала раздевалась
# пойдет пойдут
# говорить говорит
# дора давай
# гог ого
# копится копиться
# перезаписала переездом
# пк пака
# стою сб
# не нее
# именно много
# такое твое
# хочется хватит
# кисель кисел
# нурлан купал
# когда кеды
# дума думаю
# не нее
# глаза гараже
# вольтаж водитель
# не нее
# хорош хорошо
# нами наст
# то ооо
# аренда поела
# как кан
# леша леш
# то ооо
# себе честно
# русский русская
# появляется проявляется
# тайна тайга
# лада орала
# он один
# увезет увезти
# милаш позвоню
# октмо ответил
# сделана сделает
# вызвать вызови
# запчасти запятым
# мартовские мартов
# шаманил шаманим
# нужно нужна
# ночи ночь
# не нее
# ростовом ростова
# испортить историю
# случайно
# расскажу рассказу
# не нее
# откроется откровения
# из их
# тандыра танцевал
# алис полис
# проиграть приготовила
# огромное ограничение
# катают кстати
# сколько склад
# хиро хитро
# игра игру
# буду буд
# апелляции апельсин
# подразделение подавление
# еду еде
# про по
# понятно понятном
# думаю детскую
# тебе третье
# им ммм
# все-таки все
# не нее
# кривда кричала
# подарки продает
# офигеть двигать
# гм гиги
# про по
# дешевое дешевле
# придти пришли
# нее не
# колер козни
# кирилл кил
# тима типа
# вон вроде
# стояк старые
# лена легче
# перед передел
# александров александр
# ка как
# пополняют пополняются
# воскреснет воскресенье
# кровных кроватных
# се себе
# внимания внимание
# овощами рахмат
# успею успеваю
# мы иры
# ау ппц
# было был
# пап папа
# не на
# баран барана
# цементом цементной
# будет будем
# обеда обещала
# разговаривать раздавать
# он они
# мне моне
# сони пони
# выпало выпала
# по пил
# где глюк
# вдруг волосы
# пообедать пробежать
# посмотреть посидеть
# мам мама
# сообщений союзный
# де деле
# пожалуйста пожалуйся
# звони заполни
# го ого
# про по
# прости пробить
# дей дней
# еду еще
# ассоциируюсь ассоциацию
# по пошла
# то тон
# народу наберу
# обтираться обираться
# не нее
# не нее
# гране грана
# стала стало
# просто нормально
# вечер вечно
# интересуется интересная
# пока попу
# нс нас
# проводов провод
# иди или
# графике график
# ваще важен
# сделала сделал
# кто кир
# просто прости
# проезжал проезжаешь
# будешь будет
# было был
# гашека шашка
# болеют болью
# нами нам
# технология технолог
# врача вовремя
# дают-бери дадут
# промыл помыл
# баб бабки
# ок оке
# следующий сделаю
# интересно инсте
# говорю говори
# записал занимаешься
# леш лещ
# режиссер режет
# работы работа
# сообщу пользу
# нег неге
# сделаю можно
# прилетела придется
# но нового
# прощаю подъезжаю
# люблю любовь
# обещаю общаюсь
# скин скинь
# гулять гуляю
# пошлое прошлое
# ель едь
# узбекский вишневый
# посмотри простом
# он один
# приятно приятного
# фиат фита
# нравится новости
# сестренка сестра
# та ты
# хату зови
# нее не
# оке окну
# зоя зря
# крестить крутить
# не нее
# люби любит
# существительные существенные
# ок оке
# влезет влезешь
# не нее
# тепло терпеть
# давид данил
# отжимает отлично
# пластмассовые пластиковые
# роспотребнадзор
# мс мсс
# калеки калки
# дилер жидко
# ник никак
# ай ппц
# ку куку
# вылил форма
# валерьевич влюбленности
# пойдешь пойду
# здравствуйте здарова
# то ото
# мелочи мелочь
# класса касса
# будет бедер
# мне минера
# ну не
# менеджеру менеджера
# ватт варить
# холод холодом
# да за
# прошла пошла
# не нее
# понравились понравилось
# мечты сестры
# города годом
# видео видел
# было был
# булкой будкой
# алма алиса
# денете ленте
# общения общаешься
# серым снесет
# тан банке
# одежда одного
# не ну
# обращайся обращай
# поста посмотрим
# качки какие
# во вал
# опаздывай опаздываю
# устроил кирилл
# отдал отдать
# ооо оператор
# полковником практическом
# долго один
# сказал сказать
# налетят надеяться
# рассмеялся рассеялся
# ерундой ерунда
# не нее
# возьмем возьмет
# муз мух
# ниже нижнее
# аст всю
# звонит звонить
# кеча участие
# пропадут пропадет
# ха за
# факел фактор
# кака как
# шрам грам
# про по
# встаю встать
# да дак
# ножовка ножка
# куп кур
# бед обед
# ясно что
# этим житься
# защищаться заниматься
# беларуси беларусь
# более болел
# венецианский верейский
# украинский украински
# возим водили
# учи уст
# согласна согласно
# не нее
# заходить защит
# расстраивайся расставайся
# поорет пораньше
# ля для
# завистливый зависимый
# ирина момент
# не нее
# про по
# люк любое
# расстались реально
# двигается двигаться
# понравилось поговорю
# задать задам
# дед дел
# аз ахах
# ну не
# бывало было
# быстрей быстрее
# груш груз
# подстригаться подстроился
# ваш виз
# плевал плево
# пойдет пойду
# султанша султана
# январь января
# жор это
# го ого
# хорошего хорошее
# хз хахах
# аза ахаха
# жкх желез
# весить весь
# ехать уехать
# понедельник поедем
# эд эл
# пф рф
# дизель жизнь
# чон сон
# под подло
# начнет насте
# самую самолет
# военное военно
# турист турить
# морковкой московской
# вариантов вариант
# го ого
# помню помогаю
# не нее
# картриджем картошки
# поискать поиски
# висит вита
# бессонница бессонницы
# нее не
# вопросу волосы
# лол доллар
# иметь ита
# переломе переживай
# что что-то
# не нее
# германа геометри
# на га
# своих сах
# досвидос появился
# выскакивает высказал
# нас нет
# выходим выходи
# стену стану
# удачного классного
# арктик артем
# до додо
# де деле
# нет лет
# своей свое
# варик вариант
# скажу скажешь
# не нее
# работать работаю
# продан план
# на нас
# газ газа
# ну ней
# дул дуд
# твой трав
# повод провод
# приехал приезжай
# вика все
# его ешь
# виктор вместо
# выключен выкладывает
# дочь дичь
# великолукский великолепный
# опоздаю раздаю
# потерпи потерпишь
# неа на
# про по
# местом место
# легко леша
# пола план
# секрет через
# проблемы проблем
# кто круто
# сказки сказали
# чет чем
# мы ива
# же эле
# был было
# сто что
# дочь дат
# тв ты
# хаз хахаха
# поняла понравится
# худам худом
# этому эту
# наклейки наклейку
# входящие входите
# total=10000 corr=8665 err=1335, accuracy: 0.8665
# 0.8665

# %%
with open('data_feats/valid/grid_name') as f:
    u2g = {u:g for u,g in map(str.split, f.readlines())}

# %%
valid_ref_u2w_d = {k:v for k,v in valid_ref_u2w.items() if u2g[k] == 'default'}
valid_ref_u2w_e = {k:v for k,v in valid_ref_u2w.items() if u2g[k] == 'extra'}
print(len(valid_ref_u2w_d), len(valid_ref_u2w_e))
lv_d = {k:v for k,v in lv.items() if u2g[k] == 'default'}
lv_e = {k:v for k,v in lv.items() if u2g[k] == 'extra'}
print(len(lv_d), len(lv_e))

print(accuracy(valid_ref_u2w_d, lv_d))
print(accuracy(valid_ref_u2w_e, lv_e))
# Out:
# 9416 584
# 9416 584
#   0%|          | 0/9416 [00:00<?, ?it/s]
# геев гены
# была быстро
# рам нам
# шакалов заказала
# воля волосы
# ура уля
# корень удобно
# купи курс
# говорить говорит
# водитель водителю
# вечером вечер
# фиолетовой фиолетовое
# выехал выезжать
# выздоравливай выдавливай
# черна черны
# выгуливать выгулять
# вызовов вызвала
# пробовал попробовать
# стать стараюсь
# отвечал отвечать
# ха за
# русскому русском
# мазок мажора
# не на
# обувь обед
# завтра заработать
# он борн
# никогда никого
# баба бабу
# пойми пофиг
# кн угу
# виде видео
# пахлава
# уезжай езжай
# прошу проще
# дура духов
# агапкина агрессии
# ниже нижнее
# верон вероника
# анадырь аналогию
# лада ладно
# заберем забери
# завтра звоню
# тыс там
# стоит строит
# прошел пошел
# романович романтичная
# глав главное
# работы работаю
# доллар дождусь
# занимаешься закончилась
# жень день
# приветик привет
# мм ммм
# выглядят выглядит
# крот корот
# потому плитки
# привете привет
# ест есть
# лежит делись
# пойдут пойдет
# дека днем
# екб куб
# прожить пожить
# марин марии
# лай дай
# был было
# считал считай
# нами наст
# ну не
# система систем
# проснулась проснулся
# но нот
# заварили звонили
# понятно понятного
# выход выходи
# нарисовал написал
# мине минера
# здорова здорово
# забей заберу
# лэйбл любой
# билет билеты
# виза ариша
# скользко сколько
# бать брат
# спасителя спасибо
# все вместе
# души луги
# зажимают задерживаю
# бугун бегут
# эволюцию эволюция
# уговорить уговорил
# реабилитироваться реабилитировать
# пеши решим
# ишачий играй
# попил платил
# работать работает
# др дорого
# подложку подожду
# полнейшей полнейший
# бел бед
# анаста анастасия
# дела делала
# вернуть вернут
# девиз делать
# ка как
# мм ип
# моей мой
# др дорого
# береги берем
# так та
# россию росто
# ну ней
# рулит рулить
# мозгов можно
# ваз вах
# до др
# двум даки
# будет будем
# махровый мажоры
# бан баг
# такое точно
# каток каталась
# хотин хотите
# попасть плачь
# парк правок
# не нее
# лох плохо
# привожу приводу
# вам вас
# по про
# сопьюсь сопьются
# муму сумму
# сахар саша
# давай двойка
# иди или
# зарплату характер
# сиди сидим
# восстановить
# убила удобно
# ха-ха захар
# вон волн
# чехова чехол
# ну не
# ся мя
# антоном антон
# не нее
# состав составы
# вы вый
# нас нам
# ромку росте
# или июля
# сожалению сожелению
# запись записываюсь
# говоря говорят
# шорты готовы
# нравиться нравится
# мерей перец
# мама маму
# наименований наименование
# он один
# кинула кинуло
# приливов прилив
# отдыхаешь отдыхать
# из их
# входная взрослая
# не ну
# сигну смогу
# ага анна
# снов серв
# называется назначения
# глазам глаза
# скачать скучать
# чей чай
# готовить готовиться
# удава удар
# про по
# стикер сбер
# блин болин
# супер скорее
# ахах ахахах
# ахаха ахахах
# по про
# не нее
# насыпала насыпка
# луж дед
# любую глеб
# зарабатывали заработал
# присел примерно
# замечательное замечательно
# чет черт
# срочно советы
# радиатор работает
# жак дак
# баланс балан
# сетку сестру
# калл кала
# нк нее
# яр яро
# намного настроение
# поспи поспал
# давным дыня
# кайфовать камуфляж
# уже удобно
# большее больше
# произведение произвели
# се себе
# попадаются попадают
# идеей идей
# проверять проверяю
# пупка пупсика
# папа пара
# встретимся встретиться
# конца конечно
# здарова здорово
# если ели
# качестве кассире
# гудят гулять
# белы белов
# вшивая вторая
# умеет кинет
# заявкам зачем
# ном нос
# не неа
# ахах ахахах
# то только
# разрешил разрешили
# брюшной большое
# разная развелся
# будут будет
# случае случайно
# кп кпп
# уж ужас
# вот аль
# звонил занимаешься
# мыслями мысля
# понедельник поедет
# жесть знаю
# колдуешь концерт
# покупку покупай
# тобой ильей
# мда мода
# мин мне
# каре какое
# выбил выбить
# созвучия созвонимся
# две даче
# ок оке
# смотала смотрела
# классный кассовый
# гости госта
# обезболивающие обезболивающее
# удалила кидали
# крошка кошка
# походом похожи
# читов чтобы
# мам мама
# меня песня
# или иди
# представляю представлю
# напала напал
# ахах ахахах
# зашить хочешь
# научится научиться
# школьники школьном
# кто-то кто
# пс пасс
# не нее
# одни один
# дилшод жизнь
# ветчина внимание
# балл бал
# домой зимой
# подали продали
# эдит жить
# купить купи
# толик только
# гнут гугл
# лежишь решишь
# ладно может
# фу фу-фу
# игре игру
# девушка девушку
# встретимся встретим
# сердечко сердце
# ка как
# кто утро
# ул ужас
# ма иа
# он ок
# убрать уезжать
# теперь будет
# не ну
# или иди
# брать бояться
# приехали приезжай
# это жизнь
# авито авто
# перестанет перестал
# клан классно
# лице ответ
# рф раф
# девкам девки
# ха за
# не нее
# не нее
# стене стена
# что что-то
# то итог
# пороге порогу
# хороших хорошо
# будут буду
# же деле
# хахах хахаха
# знакомых занимаешься
# фрик факту
# объяснений объясни
# появилась появился
# ок окей
# спасибо спать
# россии россия
# таки тупи
# далеко даже
# опал орал
# есть кси
# сказать чехол
# горит готовить
# ду душу
# ну ней
# ахаха ахахах
# читаю стирал
# тетя тебя
# им ммм
# выключи выключить
# делала делаешь
# дело деньги
# фролов фолов
# машину машины
# авито авто
# может идет
# еда нда
# помогу потому
# цезарь узнать
# забиваю заработать
# счастьем счастье
# замерим заменим
# сч ся
# печорина ресторана
# сказали скажи
# не нее
# бахает базарит
# самсонова самогона
# мен медленно
# данилом данила
# вор во
# дочь достать
# старая старым
# энди этом
# нормальное нормальнее
# работу работе
# считается считает
# братцы батуты
# да дыры
# ухе узе
# забыл забирать
# оно одно
# абу абе
# эту это
# почитай поставят
# пеги пени
# отошел отвечаешь
# про по
# ха за
# гас щас
# или иди
# ил или
# нами нам
# делай лей
# не нее
# на га
# ее елене
# чушь чувствуешь
# максимальном максимально
# угу агу
# математика материка
# есть ест
# но нот
# до да
# хм хи
# поселок командировку
# германии герои
# сделать сдать
# вы вый
# надеж надежда
# ахаха ахахах
# доброй добрый
# маг маз
# за ха
# кофточку кофту
# значки заявки
# пешим решим
# ввиду вижу
# та тв
# исключим искренний
# температур температура
# самара самый
# без тез
# вы авы
# нормативы нормальный
# ловит орать
# ответственно ответствен
# красне краснее
# нета нету
# просила послала
# горы года
# трест тест
# служило сделал
# сидел силе
# фотку форму
# аванс пароль
# альба адидас
# что что-то
# снюс себя
# была было
# знаешь здесь
# наступающим насколько
# кармане картинка
# менее мене
# ей ну
# съездить сбежать
# не нее
# спокойнее справляйся
# мен мене
# не на
# вставил вставать
# ждать жрать
# менде медленная
# ахах ахахах
# брюнетку брюками
# имя ия
# ан анн
# жесть одевать
# овен равно
# чем вес
# не нее
# земельный землей
# завтрак забрала
# детройт дельфин
# продавал подруга
# специалиста специально
# рита пита
# требований требование
# димуль дискорд
# но ел
# кузьмина евгений
# см ммм
# климент удивить
# мама маму
# показывают показать
# космо кем-то
# положить положу
# превысил первыми
# по под
# хахахаха хахаха
# придешь приедешь
# варик вариант
# овощей окей
# деле лебеде
# случится случиться
# денег легко
# от ооо
# альбом адрес
# отличник отличное
# хорошо хорошая
# промо просто
# денег деген
# чемпионом чемпион
# успех успехи
# пан папа
# мной много
# тц ту
# назвали название
# заметила замена
# изо из-за
# осталась осталось
# задержка забуду
# документы другие
# озера озеру
# вк вечер
# го огромного
# до да
# мне мен
# встать вставать
# пожалуйста продайте
# ален алене
# подзатыльник пожалуйста
# или иди
# про по
# капец карев
# туч трус
# му су
# не на
# ранг ранга
# раза разве
# минут минутки
# крута крутая
# на рев
# че ян
# магната маргарита
# довела давно
# корейцы корейца
# назвала название
# успеваю скрыть
# вернусь вернуть
# хотя родится
# дота дома
# ку куку
# авы аву
# не нее
# не нее
# иринка инка
# хочет хочешь
# вакуумные вкусные
# царство царства
# тосно точно
# хоро хорошо
# эм эс
# однокурсницы одноклассница
# получится волчки
# года голова
# сектор скинь
# сложно сдохла
# негр нечего
# ато аил
# воды алы
# или иди
# се себе
# камень-на-оби
# смолу смогу
# имея иску
# нега негр
# пойдем пойдет
# речи речь
# закончили закончился
# вашим видим
# итоге итогу
# не нее
# котят удалять
# кричи кричит
# написала нарисовала
# муза муха
# не на
# сум сумка
# мягко мягких
# прилетаете прилетает
# готово группе
# нудна нужна
# салам салом
# если ест
# хочу худой
# про по
# цыпленок йогурт
# разорвало разрывало
# конец колей
# ну не
# направлении наработаешь
# красному красноту
# ах ахах
# покажи понял
# света все-таки
# таджикистан таджики
# видео видел
# казино козино
# сколько супер
# топ том
# дома доме
# требуется треугольник
# тут тупи
# было был
# на га
# снов сена
# сверхъестественного серьезно
# пожарить подпись
# ив ива
# череп черепа
# внимания внимание
# наконец-то наконец
# уж удобно
# кроссовки красавки
# галочкой наличкой
# наорала направлять
# единственное ездили
# поменять поменяешь
# наверно наверное
# не нее
# пойдешь пойдет
# па папа
# не нее
# хеппи знаю
# душ друг
# зал зао
# холод холодно
# го ого
# трио три-то
# ковтун клубе
# уж ужас
# аз аза
# маленьких маленький
# обидел обидно
# павильоне пароле
# алисы полив
# памяти пассив
# похож подход
# комп компе
# присяги приятного
# сентября сестра
# фу пенные
# заряжается заражается
# топ топа
# бургер будет
# менее мнение
# наггетсы нашелся
# клиент едет
# призвание пришел
# вена вагона
# нас на
# про по
# подругой подруга
# участок участке
# ух узнаешь
# банд баню
# ух узнаешь
# там таким
# объекте обед
# своим своими
# двухстороннем двухсторонний
# таких твоих
# что что-то
# катта ката
# над народ
# любом любим
# ипотеку ипотеке
# по ал
# человек чела
# аллохол плохо
# есть ест
# он один
# буду буд
# такое твое
# кук куку
# мной игру
# скок скорее
# не нее
# выходит выходить
# хот хоть
# почитаю прочитаю
# придете прилете
# района район
# не нее
# ом ос
# удлинитель водитель
# ставок старые
# его угол
# лодки одет
# впереди вернешь
# отвезли отвези
# по пол
# посмотрим пособии
# все-таки все
# единорога единое
# инк мне
# ура уда
# не нее
# гей шоу
# русской рублей
# инсайд инсайды
# бабуина бабушки
# буду будут
# возьми возьму
# курят кусал
# прослушал послушал
# предлагает предлагал
# сто что
# поль побью
# стоял стоят
# ели едет
# миф мой
# встретиться вспомнить
# дошло дорого
# кошмаров комаров
# расставлены расстановка
# попала пропадала
# стад стаж
# блюд люблю
# уж ужас
# тряпки тряпке
# предал предатель
# твои твоим
# есть ест
# политикам плиткам
# опять отправят
# отвлекайте отвлекай
# го ого
# можно может
# брат трата
# веселее вселен
# балан бригада
# церкви цена
# там так
# лан лага
# спряталась считалось
# папу пару
# взаимно админом
# сжато михаил
# постоянно последняя
# город голод
# оденьте одному
# знаю наю
# машине магните
# чем сем
# юля бюджет
# трезв тореза
# аптека аппетита
# удобно убери
# дома драм
# так тара
# ок оке
# катала кстати
# лови дат
# свершилось свершилась
# присылай привык
# банан бананан
# приват привет
# ахах ахахах
# кун кунг
# сегодня себя
# узнаешь узнает
# жен женен
# не нее
# разочарован разочаровала
# ко кол
# которой которые
# во вол
# почти прям
# бяка быка
# заходишь захочешь
# межрайонным международная
# моей мой
# или иди
# дури дурак
# до да
# желаю делаю
# манга мега
# фольсваген фольксваген
# эй жуй
# оформляем оформляет
# выглядите выглядит
# мам мама
# хз хахахаха
# за ща
# да дак
# так тк
# ты тв
# канала канада
# дают делают
# выиграл август
# мак су
# спекулятивной специальный
# вывелись вывесить
# мироточить миртом
# кв ев
# отгадали отдали
# скорее скоро
# кори корми
# работы работай
# отсталый отсталой
# нашел нашего
# александр александра
# крыльцо крыльца
# поел плед
# иди или
# смыла смысл
# ванн ван
# похвастаться позвать
# не на
# что что-то
# облегчить обменами
# выспаться выспался
# не нее
# смысла святой
# четверг сметан
# иле иду
# уходит уходить
# анют анюта
# интересно интересе
# печаль поняла
# фо форд
# адрес адресе
# не нее
# не нее
# токо тонко
# корм короче
# ничем очень
# навигаторе неправильно
# ку куку
# дл дим
# не нечего
# продаю продут
# съезди страшно
# мерь мет
# спросила спросите
# страшного страшно
# но ноо
# пап папа
# мертвая серия
# больница больнице
# ссориться смотря
# культ культура
# наше нашел
# воскресенье воспитатели
# ты та
# конечной конченый
# половины половина
# заварка заправка
# еловой новой
# дорой дорогой
# планировала планировал
# выборе выйдет
# боятся бесятся
# вас вам
# скороходов скорохода
# да дарова
# аргонавтов аппаратов
# спокойной спокойно
# обзор общаться
# хз хахаха
# скетч суета
# шло шол
# под пол
# вождения вождение
# не ну
# ножом ножи
# выдержу вылезу
# александр александра
# ездил ездили
# вспомни вспомнить
# все всем
# вернут вернуть
# выдано выдан
# перерыл перевод
# силу сижу
# данила дарила
# терпеливее терпелива
# робот оборот
# пике пикник
# заявления заявление
# франция франты
# живем живет
# рим ним
# сосуды соскучился
# спасибо спрашивал
# умею видел
# пил пилил
# момент москва
# видел видео
# неделе нужен
# изменчивости изменению
# урожай кодой
# мамбо масло
# во вол
# знакомств зеркала
# ок оке
# не нее
# ас асс
# го ого
# больше большое
# буру буду
# рукам руки
# другое другие
# моя или
# следила сделал
# ха за
# тебе ребенок
# па папа
# сф мы
# штекера штукатура
# катридж кирилл
# директор живете
# занятия занимаешься
# заработал заработать
# дружбу дружба
# димой дмитрий
# пойдет пойдут
# говорить говорит
# дора давай
# гог ого
# копится копиться
# перезаписала переездом
# пк пака
# стою сб
# не нее
# именно много
# такое твое
# хочется хватит
# кисель кисел
# нурлан купал
# когда кеды
# дума думаю
# не нее
# глаза гараже
# вольтаж водитель
# хорош хорошо
# нами наст
# то ооо
# аренда поела
# как кан
# леша леш
# себе честно
# русский русская
# появляется проявляется
# тайна тайга
# лада орала
# он один
# увезет увезти
# милаш позвоню
# октмо ответил
# сделана сделает
# вызвать вызови
# запчасти запятым
# мартовские мартов
# шаманил шаманим
# нужно нужна
# ночи ночь
# не нее
# ростовом ростова
# испортить историю
# случайно
# расскажу рассказу
# не нее
# откроется откровения
# из их
# тандыра танцевал
# алис полис
# проиграть приготовила
# огромное ограничение
# катают кстати
# сколько склад
# хиро хитро
# игра игру
# буду буд
# апелляции апельсин
# подразделение подавление
# еду еде
# про по
# понятно понятном
# думаю детскую
# тебе третье
# им ммм
# все-таки все
# не нее
# кривда кричала
# подарки продает
# офигеть двигать
# гм гиги
# про по
# дешевое дешевле
# придти пришли
# нее не
# колер козни
# кирилл кил
# тима типа
# стояк старые
# лена легче
# перед передел
# александров александр
# ка как
# пополняют пополняются
# воскреснет воскресенье
# кровных кроватных
# се себе
# внимания внимание
# мы иры
# ау ппц
# было был
# пап папа
# не на
# баран барана
# цементом цементной
# будет будем
# обеда обещала
# он они
# мне моне
# сони пони
# выпало выпала
# по пил
# где глюк
# вдруг волосы
# пообедать пробежать
# посмотреть посидеть
# мам мама
# сообщений союзный
# де деле
# пожалуйста пожалуйся
# звони заполни
# го ого
# про по
# прости пробить
# дей дней
# еду еще
# по пошла
# то тон
# народу наберу
# обтираться обираться
# не нее
# не нее
# гране грана
# стала стало
# просто нормально
# вечер вечно
# интересуется интересная
# пока попу
# нс нас
# иди или
# графике график
# ваще важен
# сделала сделал
# кто кир
# проезжал проезжаешь
# будешь будет
# было был
# гашека шашка
# болеют болью
# нами нам
# технология технолог
# врача вовремя
# дают-бери дадут
# промыл помыл
# баб бабки
# ок оке
# следующий сделаю
# интересно инсте
# говорю говори
# записал занимаешься
# леш лещ
# режиссер режет
# работы работа
# сообщу пользу
# нег неге
# сделаю можно
# прилетела придется
# но нового
# прощаю подъезжаю
# люблю любовь
# обещаю общаюсь
# скин скинь
# гулять гуляю
# пошлое прошлое
# узбекский вишневый
# посмотри простом
# он один
# приятно приятного
# фиат фита
# нравится новости
# сестренка сестра
# та ты
# хату зови
# зоя зря
# крестить крутить
# не нее
# люби любит
# существительные существенные
# ок оке
# влезет влезешь
# не нее
# тепло терпеть
# давид данил
# отжимает отлично
# пластмассовые пластиковые
# роспотребнадзор
# мс мсс
# калеки калки
# дилер жидко
# ник никак
# ай ппц
# ку куку
# вылил форма
# пойдешь пойду
# здравствуйте здарова
# то ото
# мелочи мелочь
# класса касса
# будет бедер
# мне минера
# ну не
# менеджеру менеджера
# ватт варить
# холод холодом
# да за
# прошла пошла
# не нее
# понравились понравилось
# мечты сестры
# видео видел
# было был
# булкой будкой
# алма алиса
# денете ленте
# общения общаешься
# серым снесет
# тан банке
# одежда одного
# не ну
# обращайся обращай
# качки какие
# во вал
# опаздывай опаздываю
# отдал отдать
# ооо оператор
# полковником практическом
# долго один
# сказал сказать
# налетят надеяться
# рассмеялся рассеялся
# ерундой ерунда
# не нее
# возьмем возьмет
# муз мух
# ниже нижнее
# аст всю
# звонит звонить
# кеча участие
# пропадут пропадет
# ха за
# факел фактор
# кака как
# шрам грам
# встаю встать
# да дак
# ножовка ножка
# куп кур
# бед обед
# ясно что
# этим житься
# защищаться заниматься
# беларуси беларусь
# более болел
# венецианский верейский
# украинский украински
# возим водили
# учи уст
# согласна согласно
# не нее
# заходить защит
# расстраивайся расставайся
# поорет пораньше
# ля для
# завистливый зависимый
# ирина момент
# не нее
# про по
# люк любое
# расстались реально
# двигается двигаться
# понравилось поговорю
# задать задам
# дед дел
# аз ахах
# ну не
# бывало было
# быстрей быстрее
# груш груз
# подстригаться подстроился
# ваш виз
# плевал плево
# пойдет пойду
# жор это
# го ого
# хорошего хорошее
# хз хахах
# аза ахаха
# жкх желез
# весить весь
# ехать уехать
# понедельник поедем
# пф рф
# дизель жизнь
# чон сон
# под подло
# самую самолет
# военное военно
# турист турить
# морковкой московской
# вариантов вариант
# го ого
# помню помогаю
# не нее
# картриджем картошки
# поискать поиски
# висит вита
# бессонница бессонницы
# нее не
# вопросу волосы
# лол доллар
# иметь ита
# переломе переживай
# что что-то
# не нее
# германа геометри
# на га
# своих сах
# досвидос появился
# выскакивает высказал
# нас нет
# выходим выходи
# стену стану
# арктик артем
# до додо
# де деле
# нет лет
# своей свое
# варик вариант
# скажу скажешь
# работать работаю
# продан план
# на нас
# газ газа
# ну ней
# дул дуд
# твой трав
# повод провод
# приехал приезжай
# вика все
# его ешь
# виктор вместо
# выключен выкладывает
# дочь дичь
# великолукский великолепный
# опоздаю раздаю
# потерпи потерпишь
# неа на
# про по
# местом место
# легко леша
# пола план
# секрет через
# проблемы проблем
# кто круто
# сказки сказали
# чет чем
# мы ива
# же эле
# был было
# сто что
# дочь дат
# тв ты
# хаз хахаха
# поняла понравится
# худам худом
# этому эту
# наклейки наклейку
# входящие входите
# total=9416 corr=8155 err=1261, accuracy: 0.8660790144435004
# 0.8660790144435004
#   0%|          | 0/584 [00:00<?, ?it/s]
# выбил футболка
# проспект приятного
# наказаний наказывай
# мерк мере
# поверить поворот
# не на
# норм ели
# выбивается выбирается
# сообщили собираешься
# древняя деревня
# приходит приходи
# хай зай
# призывников праздником
# плов пора
# виталия виртуальная
# любовь люблю
# нет него
# не нее
# аккорды аккорда
# щенка зеленка
# надо над
# но нот
# нечего ничего
# дворе двое
# спорт сорт
# да для
# приехать приехал
# стоят стоя
# му мк
# ша ща
# дочь даст
# ранняя раня
# сама масса
# люди люба
# оттепель откроешь
# начало начал
# брад бад
# ярмак ярма
# оплате оплата
# про по
# норидж норд
# схожу схоже
# го ооо
# хахаха хахахаха
# не нее
# оставить оставь
# обойдусь обойду
# садике садики
# завотделением
# удалила удала
# раздевала раздевалась
# не нее
# то ооо
# вон вроде
# овощами рахмат
# успею успеваю
# разговаривать раздавать
# ассоциируюсь ассоциацию
# проводов провод
# просто прости
# ель едь
# нее не
# оке окну
# валерьевич влюбленности
# города годом
# поста посмотрим
# устроил кирилл
# про по
# султанша султана
# январь января
# эд эл
# начнет насте
# удачного классного
# не нее
# total=584 corr=510 err=74, accuracy: 0.8732876712328768
# 0.8732876712328768

# %%
test_ds =  FeatsIterableDatasetV2([f"ark:data_feats/test/feats.ark"], shuffle=False, 
                                 bos_id=1, 
                                 eos_id=2, 
                                 batch_first=False)
test_dataloader = torch.utils.data.DataLoader(test_ds, batch_size=1, collate_fn=test_ds.collate_pad)
#test_u2w = predict(pl_module.backbone, test_dataloader)
test_u2w, test_u2l = pl_module.cuda().predict_topk(test_dataloader, tokenizer=tokenizer, topk=8)
# Out:
# 0it [00:00, ?it/s]
# 2023-11-11 14:13:32,549 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/test/feats.ark

# %%
def limit_vocab(u2w, vocab=vocab):
    lv = {}
    for k, v in u2w.items():
        corr_w = []
        for w in v:
            if w in vocab:
                corr_w.append(w)
        if len(corr_w) == 0: 
            logging.warning(f"{k=} doesn't have any vocab hyp. {v=}")
            corr_w = []
        lv[k] = corr_w
    return lv
test_lv = limit_vocab(test_u2w)
# Out:
# 2023-11-11 14:18:25,296 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1037' doesn't have any vocab hyp. v=['ву в', 'вув', 'вувы', 'вквы', 'вуву', 'вк в', 'ву чув', 'вувк', 'ву чу', 'вук в']
# 2023-11-11 14:18:25,298 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1319' doesn't have any vocab hyp. v=['-', 'шмотка', 'лестника', 'гастрика', 'остроением', '-ка', 'гостерика', 'остринка', 'остринска']
# 2023-11-11 14:18:25,299 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1905' doesn't have any vocab hyp. v=['-', 'генененене', 'гененененене', 'генененененене', 'гененененененене', 'генененененененене', 'гененененененененене', 'генененененененененене']
# 2023-11-11 14:18:25,300 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-2005' doesn't have any vocab hyp. v=['-', 'питеровой', 'питервой', 'питеравой', 'миревой', 'атервой', 'пьевой', 'питерай']
# 2023-11-11 14:18:25,305 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-4095' doesn't have any vocab hyp. v=['-', 'цызкола', 'цышкола', 'цыхнула', 'цызерла', '', 'цизкола', 'цышкарла', 'цышкала']
# 2023-11-11 14:18:25,309 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-5806' doesn't have any vocab hyp. v=['-', 'гезерный', 'гензетный', 'лезетный', 'гезетный', 'шезерный', 'гертный', '-нерный']
# 2023-11-11 14:18:25,310 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-6141' doesn't have any vocab hyp. v=['функционная', 'функционно', 'выкушал', 'фугунал', 'фугутал', 'фугутонал', 'футунал', 'функционный', 'фугутная', 'функционной']
# 2023-11-11 14:18:25,311 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-6600' doesn't have any vocab hyp. v=['-', 'лечело', 'плечело', '-нер', '-н-', '', '-е-', 'олечело']
# 2023-11-11 14:18:25,315 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-7769' doesn't have any vocab hyp. v=['-', 'первоказе', 'первоказа', '--', 'перевокше', 'первокрузка', 'первоказка', 'перевокружен', 'первокружен', 'перевокруще', 'перевокружение']
# 2023-11-11 14:18:25,319 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-9717' doesn't have any vocab hyp. v=['-', 'зекотовая', 'щекотовая', '-ля', '--', '-атовая', '-а-', 'шекотовая', '']

# %%
baseline_result = pd.read_csv('./keyboard_start/result/baseline.csv', sep=',', names=['main', 'second', 'third', 'trash'])
#baseline_result = pd.read_csv('exp/models/ctc_trans/lightning_logs/version_50422251/test_submit.v1.csv', sep=',', names=['main', 'second', 'third', 'trash'])
#baseline_result = 
baseline_result['uid'] = [f'test-{i}' for i in range(len(baseline_result))]
baseline_result.head()

baseline_result['predict'] = baseline_result.uid.apply(lambda x: test_lv[x])
baseline_result.head()
rows = []
for i, row in baseline_result.iterrows():
    ps = row['predict']
    for p in [row['main'], row['second'], row['third'], row['trash']]:
        if p not in ps:
            ps.append(p)
    rows.append(ps[:4])
        
submission = pd.DataFrame(rows, columns=['main', 'second', 'third', 'trash'])
submission.to_csv("exp/models/t_finetune_test/lightning_logs/version_50454149/test_submit.v8.csv", 
                  sep=',', header=False, index=False)
submission.head()
# Out:
#         main     second      third       trash
# 0         на       нана        нас          га
# 1        что     что-то        сто       часто
# 2  опоздания  опоздание  опозданий  опозданиям
# 3    сколько    скольки    столько     сколько
# 4    дремать     думать    снимать    дописать

# %%
s5_df = pd.read_csv('exp/models/t_finetune_test/lightning_logs/version_50454149/test_submit.v10.csv', sep=',', names=['main', 'second', 'third', 'trash'])
s5_df['uid'] = [f'test-{i}' for i in range(len(s5_df))]
s5_df.head()

weak_sup_test = {row['uid']: row['main'] if row['main']!= '-' else row['second'] for i, row in s5_df.iterrows()}

with open('exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.text', 'w') as f:
          f.write(''.join(f"{u} {t}\n" for u, t in weak_sup_test.items()))

# %%
mask =s5_df['main'].isna()
s5_df['main'][mask] #= s5_df['second'][mask]
# Out:
# Series([], Name: main, dtype: object)

# %%
s5_df.head()
# Out:
#         main     second       third      trash     uid
# 0         на        нас        нана        нам  test-0
# 1        что     что-то         сто       чтоб  test-1
# 2  опоздания  опоздание  опозданиям  опозданий  test-2
# 3    сколько    скольки     сколько    столько  test-3
# 4    дремать   донимать      думать   дописать  test-4

# %%
# s5_df[["main", 'second', 'third', 'trash']].to_csv("exp/models/transformer_sc/lightning_logs/version_50424998/test_submit.v6.csv", 
#                   sep=',', header=False, index=False)

# %%
#!head "exp/models/transformer_sc/lightning_logs/version_50424998/test_submit.v6.csv"
# Out:
# на,неа,на,ненка
# что,часто,частого,чисто
# опоздания,опозданиям,оприходования,опозданиями
# сколько,сокольского,свердловского,скроено
# дремать,дописать,донимать,дюрренматт
# не,неук,нк,ненка
# как,капак,капе,капуе
# садовод,спародировал,садовод,сурдоперевод
# заметил,знаменито,знаменитого,замерил
# ваги,ваенги,венгрии,ванги

# %%
# !head 'exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.text'
# Out:
# test-0 на
# test-1 что
# test-2 опоздания
# test-3 сколько
# test-4 дремать
# test-5 не
# test-6 как
# test-7 садовод
# test-8 заметил
# test-9 ваги

# %%
weak_sup_test
# Out:
# {'test-0': 'на',
#  'test-1': 'что',
#  'test-2': 'опоздания',
#  'test-3': 'сколько',
#  'test-4': 'дремать',
#  'test-5': 'не',
#  'test-6': 'как',
#  'test-7': 'садовод',
#  'test-8': 'заметил',
#  'test-9': 'ваги',
#  'test-10': 'ок',
#  'test-11': 'плинтус',
#  'test-12': 'ай',
#  'test-13': 'ищем',
#  'test-14': 'лет',
#  'test-15': 'могу',
#  'test-16': 'может',
#  'test-17': 'спокойной',
#  'test-18': 'рядом',
#  'test-19': 'вспоминать',
#  'test-20': 'максим',
#  'test-21': 'веселое',
#  'test-22': 'невинные',
#  'test-23': 'туда',
#  'test-24': 'тебя',
#  'test-25': 'ре',
#  'test-26': 'точно',
#  'test-27': 'чего',
#  'test-28': 'помою',
#  'test-29': 'хорошо',
#  'test-30': 'укладки',
#  'test-31': 'нужны',
#  'test-32': 'ты',
#  'test-33': 'почему',
#  'test-34': 'не',
#  'test-35': 'поеду',
#  'test-36': 'то',
#  'test-37': 'быть',
#  'test-38': 'не',
#  'test-39': 'завтраки',
#  'test-40': 'будем',
#  'test-41': 'дома',
#  'test-42': 'со',
#  'test-43': 'свою',
#  'test-44': 'он',
#  'test-45': 'было',
#  'test-46': 'человек',
#  'test-47': 'погоди',
#  'test-48': 'нравится',
#  'test-49': 'оператор',
#  'test-50': 'что',
#  'test-51': 'шумят',
#  'test-52': 'летом',
#  'test-53': 'ищу',
#  'test-54': 'мотя',
#  'test-55': 'тот',
#  'test-56': 'ну',
#  'test-57': 'когда',
#  'test-58': 'ну',
#  'test-59': 'инструкции',
#  'test-60': 'хорошо',
#  'test-61': 'кстати',
#  'test-62': 'это',
#  'test-63': 'общаться',
#  'test-64': 'ты',
#  'test-65': 'что',
#  'test-66': 'деньги',
#  'test-67': 'ну',
#  'test-68': 'ладно',
#  'test-69': 'воздуха',
#  'test-70': 'это',
#  'test-71': 'снежана',
#  'test-72': 'ваще',
#  'test-73': 'вот',
#  'test-74': 'не',
#  'test-75': 'дома',
#  'test-76': 'кдж',
#  'test-77': 'норм',
#  'test-78': 'например',
#  'test-79': 'модем',
#  'test-80': 'такая',
#  'test-81': 'приехала',
#  'test-82': 'отношение',
#  'test-83': 'наверное',
#  'test-84': 'люблю',
#  'test-85': 'киа',
#  'test-86': 'есть',
#  'test-87': 'их',
#  'test-88': 'кто',
#  'test-89': 'ура',
#  'test-90': 'не',
#  'test-91': 'захар',
#  'test-92': 'про',
#  'test-93': 'жалею',
#  'test-94': 'сделал',
#  'test-95': 'что',
#  'test-96': 'ты',
#  'test-97': 'во',
#  'test-98': 'клубе',
#  'test-99': 'цепочки',
#  'test-100': 'ясно',
#  'test-101': 'на',
#  'test-102': 'ага',
#  'test-103': 'собираетесь',
#  'test-104': 'открыть',
#  'test-105': 'сидит',
#  'test-106': 'ваном',
#  'test-107': 'кроме',
#  'test-108': 'ту',
#  'test-109': 'расслабляет',
#  'test-110': 'ехать',
#  'test-111': 'гуляет',
#  'test-112': 'пиши',
#  'test-113': 'певец',
#  'test-114': 'уметь',
#  'test-115': 'ты',
#  'test-116': 'чего',
#  'test-117': 'скоро',
#  'test-118': 'ты',
#  'test-119': 'сани',
#  'test-120': 'как',
#  'test-121': 'во',
#  'test-122': 'это',
#  'test-123': 'среду',
#  'test-124': 'нет',
#  'test-125': 'так',
#  'test-126': 'артем',
#  'test-127': 'не',
#  'test-128': 'да',
#  'test-129': 'да',
#  'test-130': 'там',
#  'test-131': 'только',
#  'test-132': 'выберу',
#  'test-133': 'круто',
#  'test-134': 'ты',
#  'test-135': 'не',
#  'test-136': 'тоже',
#  'test-137': 'ее',
#  'test-138': 'или',
#  'test-139': 'ото',
#  'test-140': 'до',
#  'test-141': 'зовут',
#  'test-142': 'поезда',
#  'test-143': 'не',
#  'test-144': 'чего',
#  'test-145': 'был',
#  'test-146': 'алексей',
#  'test-147': 'не',
#  'test-148': 'позже',
#  'test-149': 'колхозник',
#  'test-150': 'шрифт',
#  'test-151': 'скидывал',
#  'test-152': 'здесь',
#  'test-153': 'время',
#  'test-154': 'пошли',
#  'test-155': 'сегодня',
#  'test-156': 'откуда',
#  'test-157': 'платье',
#  'test-158': 'восток',
#  'test-159': 'где',
#  'test-160': 'инструкция',
#  'test-161': 'помогает',
#  'test-162': 'заполнила',
#  'test-163': 'сторис',
#  'test-164': 'мне',
#  'test-165': 'хз',
#  'test-166': 'раньше',
#  'test-167': 'ты',
#  'test-168': 'них',
#  'test-169': 'дай',
#  'test-170': 'стоматологу',
#  'test-171': 'время',
#  'test-172': 'боюсь',
#  'test-173': 'как',
#  'test-174': 'спать',
#  'test-175': 'тошнит',
#  'test-176': 'не',
#  'test-177': 'вайбере',
#  'test-178': 'ты',
#  'test-179': 'коп',
#  'test-180': 'ты',
#  'test-181': 'субботу',
#  'test-182': 'не',
#  'test-183': 'занята',
#  'test-184': 'чего',
#  'test-185': 'ну',
#  'test-186': 'говорит',
#  'test-187': 'он',
#  'test-188': 'всего',
#  'test-189': 'ладно',
#  'test-190': 'большое',
#  'test-191': 'то',
#  'test-192': 'минутки',
#  'test-193': 'алейкум',
#  'test-194': 'отвечают',
#  'test-195': 'всегда',
#  'test-196': 'че',
#  'test-197': 'вернуть',
#  'test-198': 'поехали',
#  'test-199': 'маринова',
#  'test-200': 'пинг',
#  'test-201': 'поговорим',
#  'test-202': 'меня',
#  'test-203': 'тоже',
#  'test-204': 'лох',
#  'test-205': 'фоточку',
#  'test-206': 'будем',
#  'test-207': 'велосипед',
#  'test-208': 'вайбер',
#  'test-209': 'тебя',
#  'test-210': 'виноват',
#  'test-211': 'хорошее',
#  'test-212': 'хорошо',
#  'test-213': 'ты',
#  'test-214': 'годиков',
#  'test-215': 'развела',
#  'test-216': 'не',
#  'test-217': 'га',
#  'test-218': 'не',
#  'test-219': 'респектов',
#  'test-220': 'вот',
#  'test-221': 'реж',
#  'test-222': 'садик',
#  'test-223': 'потому',
#  'test-224': 'знаю',
#  'test-225': 'как',
#  'test-226': 'нет',
#  'test-227': 'июле',
#  'test-228': 'арт',
#  'test-229': 'есть',
#  'test-230': 'твой',
#  'test-231': 'буду',
#  'test-232': 'пинск',
#  'test-233': 'призвал',
#  'test-234': 'участка',
#  'test-235': 'говорила',
#  'test-236': 'щас',
#  'test-237': 'нет',
#  'test-238': 'пилю',
#  'test-239': 'топи',
#  'test-240': 'кин',
#  'test-241': 'то',
#  'test-242': 'сейчас',
#  'test-243': 'на',
#  'test-244': 'волн',
#  'test-245': 'суббота',
#  'test-246': 'мвд',
#  'test-247': 'готовить',
#  'test-248': 'просьба',
#  'test-249': 'кстати',
#  'test-250': 'кариной',
#  'test-251': 'до',
#  'test-252': 'привет',
#  'test-253': 'оле',
#  'test-254': 'отец',
#  'test-255': 'работе',
#  'test-256': 'ты',
#  'test-257': 'рамка',
#  'test-258': 'какой',
#  'test-259': 'на',
#  'test-260': 'ну',
#  'test-261': 'проходить',
#  'test-262': 'могу',
#  'test-263': 'ото',
#  'test-264': 'придет',
#  'test-265': 'уроке',
#  'test-266': 'пойду',
#  'test-267': 'номер',
#  'test-268': 'дилеров',
#  'test-269': 'хорошо',
#  'test-270': 'рисовала',
#  'test-271': 'заказать',
#  'test-272': 'говорит',
#  'test-273': 'создатель',
#  'test-274': 'вам',
#  'test-275': 'уверен',
#  'test-276': 'пищи',
#  'test-277': 'кушала',
#  'test-278': 'купаться',
#  'test-279': 'помойка',
#  'test-280': 'знал',
#  'test-281': 'поздно',
#  'test-282': 'то',
#  'test-283': 'ну',
#  'test-284': 'зап',
#  'test-285': 'лат',
#  'test-286': 'окей',
#  'test-287': 'что',
#  'test-288': 'плачь',
#  'test-289': 'передам',
#  'test-290': 'ты',
#  'test-291': 'тут',
#  'test-292': 'выходные',
#  'test-293': 'ну',
#  'test-294': 'не',
#  'test-295': 'всегда',
#  'test-296': 'присаживайтесь',
#  'test-297': 'где',
#  'test-298': 'теперь',
#  'test-299': 'увы',
#  'test-300': 'еле',
#  'test-301': 'поклонники',
#  'test-302': 'знаешь',
#  'test-303': 'бога',
#  'test-304': 'меня',
#  'test-305': 'занял',
#  'test-306': 'пиццу',
#  'test-307': 'пойдет',
#  'test-308': 'сделал',
#  'test-309': 'наши',
#  'test-310': 'куда',
#  'test-311': 'добрая',
#  'test-312': 'отказалась',
#  'test-313': 'халатик',
#  'test-314': 'ты',
#  'test-315': 'герпес',
#  'test-316': 'по',
#  'test-317': 'ахахах',
#  'test-318': 'может',
#  'test-319': 'рил',
#  'test-320': 'ехать',
#  'test-321': 'или',
#  'test-322': 'бы',
#  'test-323': 'вывод',
#  'test-324': 'как',
#  'test-325': 'можно',
#  'test-326': 'бронировать',
#  'test-327': 'ты',
#  'test-328': 'даун',
#  'test-329': 'выходной',
#  'test-330': 'делать',
#  'test-331': 'кто',
#  'test-332': 'это',
#  'test-333': 'нет',
#  'test-334': 'устрою',
#  'test-335': 'работе',
#  'test-336': 'еще',
#  'test-337': 'по',
#  'test-338': 'именно',
#  'test-339': 'моя',
#  'test-340': 'макар',
#  'test-341': 'не',
#  'test-342': 'ввиду',
#  'test-343': 'нет',
#  'test-344': 'ток',
#  'test-345': 'напишу',
#  'test-346': 'тихо',
#  'test-347': 'могут',
#  'test-348': 'да',
#  'test-349': 'добить',
#  'test-350': 'аркадий',
#  'test-351': 'пасх',
#  'test-352': 'что',
#  'test-353': 'за',
#  'test-354': 'это',
#  'test-355': 'да',
#  'test-356': 'бра',
#  'test-357': 'яна',
#  'test-358': 'мозги',
#  'test-359': 'кошелева',
#  'test-360': 'вопрос',
#  'test-361': 'любовь',
#  'test-362': 'записки',
#  'test-363': 'была',
#  'test-364': 'парт',
#  'test-365': 'германии',
#  'test-366': 'то',
#  'test-367': 'иногда',
#  'test-368': 'был',
#  'test-369': 'сформировались',
#  'test-370': 'да',
#  'test-371': 'числа',
#  'test-372': 'грудка',
#  'test-373': 'окно',
#  'test-374': 'нее',
#  'test-375': 'ли',
#  'test-376': 'пример',
#  'test-377': 'пол',
#  'test-378': 'зачем',
#  'test-379': 'вообще',
#  'test-380': 'злить',
#  'test-381': 'лизнуть',
#  'test-382': 'камушком',
#  'test-383': 'прикинь',
#  'test-384': 'буду',
#  'test-385': 'ток',
#  'test-386': 'живу',
#  'test-387': 'оль',
#  'test-388': 'война',
#  'test-389': 'любовь',
#  'test-390': 'поделить',
#  'test-391': 'понял',
#  'test-392': 'давай',
#  'test-393': 'мы',
#  'test-394': 'чего',
#  'test-395': 'вы',
#  'test-396': 'нас',
#  'test-397': 'но',
#  'test-398': 'осталась',
#  'test-399': 'пошел',
#  'test-400': 'сделать',
#  'test-401': 'номер',
#  'test-402': 'тут',
#  'test-403': 'значит',
#  'test-404': 'спи',
#  'test-405': 'дней',
#  'test-406': 'звонок',
#  'test-407': 'возможно',
#  'test-408': 'сиз',
#  'test-409': 'вообще',
#  'test-410': 'выпишут',
#  'test-411': 'константин',
#  'test-412': 'это',
#  'test-413': 'профессии',
#  'test-414': 'еду',
#  'test-415': 'прожил',
#  'test-416': 'села',
#  'test-417': 'евросоюза',
#  'test-418': 'сейчас',
#  'test-419': 'кого-то',
#  'test-420': 'люблю',
#  'test-421': 'как',
#  'test-422': 'то',
#  'test-423': 'ткани',
#  'test-424': 'на',
#  'test-425': 'зайка',
#  'test-426': 'завтра',
#  'test-427': 'треш',
#  'test-428': 'нашла',
#  'test-429': 'быстро',
#  'test-430': 'пет',
#  'test-431': 'слова',
#  'test-432': 'тебе',
#  'test-433': 'хорошо',
#  'test-434': 'ну',
#  'test-435': 'поняла',
#  'test-436': 'умерла',
#  'test-437': 'не',
#  'test-438': 'пришлю',
#  'test-439': 'витрину',
#  'test-440': 'твой',
#  'test-441': 'все',
#  'test-442': 'туда',
#  'test-443': 'вакансия',
#  'test-444': 'ошибки',
#  'test-445': 'же',
#  'test-446': 'отчет',
#  'test-447': 'хочешь',
#  'test-448': 'сурика',
#  'test-449': 'так',
#  'test-450': 'так',
#  'test-451': 'утра',
#  'test-452': 'изи',
#  'test-453': 'что',
#  'test-454': 'спс',
#  'test-455': 'хочу',
#  'test-456': 'только',
#  'test-457': 'на',
#  'test-458': 'мастера',
#  'test-459': 'да',
#  'test-460': 'вам',
#  'test-461': 'конечно',
#  'test-462': 'получали',
#  'test-463': 'как',
#  'test-464': 'наверно',
#  'test-465': 'привет',
#  'test-466': 'выходные',
#  'test-467': 'она',
#  'test-468': 'ну',
#  'test-469': 'оборот',
#  'test-470': 'ай',
#  'test-471': 'характеристика',
#  'test-472': 'хорошо',
#  'test-473': 'день',
#  'test-474': 'не',
#  'test-475': 'даун',
#  'test-476': 'зеркало',
#  'test-477': 'нет',
#  'test-478': 'этом',
#  'test-479': 'не',
#  'test-480': 'как',
#  'test-481': 'сказал',
#  'test-482': 'без',
#  'test-483': 'разами',
#  'test-484': 'сек',
#  'test-485': 'ярцево',
#  'test-486': 'как',
#  'test-487': 'оке',
#  'test-488': 'нее',
#  'test-489': 'мне',
#  'test-490': 'цена',
#  'test-491': 'расписание',
#  'test-492': 'идет',
#  'test-493': 'они',
#  'test-494': 'не',
#  'test-495': 'девушками',
#  'test-496': 'дать',
#  'test-497': 'ее',
#  'test-498': 'что',
#  'test-499': 'погрузчик',
#  'test-500': 'коко',
#  'test-501': 'все',
#  'test-502': 'удобно',
#  'test-503': 'этом',
#  'test-504': 'кажется',
#  'test-505': 'лариса',
#  'test-506': 'на',
#  'test-507': 'нет',
#  'test-508': 'родителями',
#  'test-509': 'микс',
#  'test-510': 'такие',
#  'test-511': 'привет',
#  'test-512': 'ком',
#  'test-513': 'мне',
#  'test-514': 'меня',
#  'test-515': 'фиксики',
#  'test-516': 'думаю',
#  'test-517': 'потом',
#  'test-518': 'как',
#  'test-519': 'утерян',
#  'test-520': 'не',
#  'test-521': 'даже',
#  'test-522': 'такое',
#  'test-523': 'залила',
#  'test-524': 'покупкой',
#  'test-525': 'давай',
#  'test-526': 'ооо',
#  'test-527': 'мне',
#  'test-528': 'дим',
#  'test-529': 'такая',
#  'test-530': 'потому',
#  'test-531': 'хрень',
#  'test-532': 'наверно',
#  'test-533': 'магазин',
#  'test-534': 'просто',
#  'test-535': 'он',
#  'test-536': 'заеду',
#  'test-537': 'работать',
#  'test-538': 'данил',
#  'test-539': 'скажет',
#  'test-540': 'справлюсь',
#  'test-541': 'формы',
#  'test-542': 'съем',
#  'test-543': 'кем',
#  'test-544': 'счастья',
#  'test-545': 'уроки',
#  'test-546': 'сказано',
#  'test-547': 'на',
#  'test-548': 'расстроят',
#  'test-549': 'да',
#  'test-550': 'соберу',
#  'test-551': 'кроме',
#  'test-552': 'крюки',
#  'test-553': 'ща',
#  'test-554': 'ну',
#  'test-555': 'дашкой',
#  'test-556': 'ты',
#  'test-557': 'наверное',
#  'test-558': 'ли',
#  'test-559': 'тебя',
#  'test-560': 'ехать',
#  'test-561': 'найти',
#  'test-562': 'зеленая',
#  'test-563': 'виноватой',
#  'test-564': 'мне',
#  'test-565': 'конкурс',
#  'test-566': 'расписание',
#  'test-567': 'помою',
#  'test-568': 'имеет',
#  'test-569': 'твою',
#  'test-570': 'деньги',
#  'test-571': 'днем',
#  'test-572': 'не',
#  'test-573': 'еще',
#  'test-574': 'это',
#  'test-575': 'то',
#  'test-576': 'тата',
#  'test-577': 'доступным',
#  'test-578': 'дорогу',
#  'test-579': 'мне',
#  'test-580': 'все',
#  'test-581': 'оно',
#  'test-582': 'панда',
#  'test-583': 'городе',
#  'test-584': 'порчу',
#  'test-585': 'не',
#  'test-586': 'узнает',
#  'test-587': 'нет',
#  'test-588': 'же',
#  'test-589': 'кстати',
#  'test-590': 'давно',
#  'test-591': 'милая',
#  'test-592': 'говорить',
#  'test-593': 'кипяченую',
#  'test-594': 'рахмат',
#  'test-595': 'не',
#  'test-596': 'блин',
#  'test-597': 'почему',
#  'test-598': 'самочувствие',
#  'test-599': 'не',
#  'test-600': 'ни',
#  'test-601': 'на',
#  'test-602': 'же',
#  'test-603': 'трещит',
#  'test-604': 'меня',
#  'test-605': 'ясно',
#  'test-606': 'шуруповерт',
#  'test-607': 'выйдет',
#  'test-608': 'вижу',
#  'test-609': 'узнаю',
#  'test-610': 'тел',
#  'test-611': 'дозвонилась',
#  'test-612': 'ем',
#  'test-613': 'подпишись',
#  'test-614': 'понятно',
#  'test-615': 'тебя',
#  'test-616': 'надо',
#  'test-617': 'уже',
#  'test-618': 'сказать',
#  'test-619': 'общении',
#  'test-620': 'нервничать',
#  'test-621': 'устал',
#  'test-622': 'токо',
#  'test-623': 'так',
#  'test-624': 'можно',
#  'test-625': 'намного',
#  'test-626': 'потом',
#  'test-627': 'на',
#  'test-628': 'ожидаем',
#  'test-629': 'тебя',
#  'test-630': 'как',
#  'test-631': 'привет',
#  'test-632': 'не',
#  'test-633': 'все',
#  'test-634': 'кажется',
#  'test-635': 'там',
#  'test-636': 'армии',
#  'test-637': 'эту',
#  'test-638': 'зашла',
#  'test-639': 'дворец',
#  'test-640': 'вот',
#  'test-641': 'не',
#  'test-642': 'это',
#  'test-643': 'бы',
#  'test-644': 'свой',
#  'test-645': 'что',
#  'test-646': 'мам',
#  'test-647': 'как-то',
#  'test-648': 'ленд',
#  'test-649': 'часа',
#  'test-650': 'то',
#  'test-651': 'вот',
#  'test-652': 'посадили',
#  'test-653': 'не',
#  'test-654': 'капец',
#  'test-655': 'работы',
#  'test-656': 'магазины',
#  'test-657': 'собираться',
#  'test-658': 'понятно',
#  'test-659': 'купить',
#  'test-660': 'мед',
#  'test-661': 'нормально',
#  'test-662': 'оттуда',
#  'test-663': 'массаж',
#  'test-664': 'все',
#  'test-665': 'бы',
#  'test-666': 'большое',
#  'test-667': 'так',
#  'test-668': 'опаздываю',
#  'test-669': 'можешь',
#  'test-670': 'нет',
#  'test-671': 'какие',
#  'test-672': 'какими',
#  'test-673': 'жить',
#  'test-674': 'видел',
#  'test-675': 'ли',
#  'test-676': 'пачек',
#  'test-677': 'домой',
#  'test-678': 'не',
#  'test-679': 'мыться',
#  'test-680': 'нормально',
#  'test-681': 'мы',
#  'test-682': 'есть',
#  'test-683': 'молоко',
#  'test-684': 'рахмет',
#  'test-685': 'бывший',
#  'test-686': 'встрече',
#  'test-687': 'кули',
#  'test-688': 'водолей',
#  'test-689': 'собой',
#  'test-690': 'цветок',
#  'test-691': 'узнать',
#  'test-692': 'не',
#  'test-693': 'вечером',
#  'test-694': 'что',
#  'test-695': 'как',
#  'test-696': 'антона',
#  'test-697': 'такой',
#  'test-698': 'манга',
#  'test-699': 'короче',
#  'test-700': 'пока',
#  'test-701': 'идти',
#  'test-702': 'из',
#  'test-703': 'комментариями',
#  'test-704': 'да',
#  'test-705': 'созвонимся',
#  'test-706': 'думала',
#  'test-707': 'вас',
#  'test-708': 'котик',
#  'test-709': 'посмотрим',
#  'test-710': 'знаю',
#  'test-711': 'катя',
#  'test-712': 'фиксированный',
#  'test-713': 'проснулись',
#  'test-714': 'ппц',
#  'test-715': 'бы',
#  'test-716': 'экономный',
#  'test-717': 'почему',
#  'test-718': 'привет',
#  'test-719': 'ну',
#  'test-720': 'будишь',
#  'test-721': 'любимая',
#  'test-722': 'фото',
#  'test-723': 'мне',
#  'test-724': 'оставляла',
#  'test-725': 'своего',
#  'test-726': 'пульт',
#  'test-727': 'раз',
#  'test-728': 'из',
#  'test-729': 'так',
#  'test-730': 'не',
#  'test-731': 'но',
#  'test-732': 'равно',
#  'test-733': 'мы',
#  'test-734': 'мои',
#  'test-735': 'как',
#  'test-736': 'надо',
#  'test-737': 'сб',
#  'test-738': 'хорошо',
#  'test-739': 'как',
#  'test-740': 'утра',
#  'test-741': 'дети',
#  'test-742': 'маленько',
#  'test-743': 'нет',
#  'test-744': 'работу',
#  'test-745': 'жак',
#  'test-746': 'не',
#  'test-747': 'подушки',
#  'test-748': 'пиши',
#  'test-749': 'личной',
#  'test-750': 'уже',
#  'test-751': 'инфа',
#  'test-752': 'поедем',
#  'test-753': 'тяжело',
#  'test-754': 'ну',
#  'test-755': 'ну',
#  'test-756': 'сейчас',
#  'test-757': 'не',
#  'test-758': 'рассчитать',
#  'test-759': 'страшного',
#  'test-760': 'можно',
#  'test-761': 'понравилось',
#  'test-762': 'фото',
#  'test-763': 'из',
#  'test-764': 'спасибо',
#  'test-765': 'часа',
#  'test-766': 'будете',
#  'test-767': 'норма',
#  'test-768': 'самого',
#  'test-769': 'найдешь',
#  'test-770': 'на',
#  'test-771': 'отправить',
#  'test-772': 'ссылку',
#  'test-773': 'нет',
#  'test-774': 'отлично',
#  'test-775': 'когда',
#  'test-776': 'что',
#  'test-777': 'быстрому',
#  'test-778': 'по',
#  'test-779': 'же',
#  'test-780': 'головной',
#  'test-781': 'сегодня',
#  'test-782': 'сразу',
#  'test-783': 'спорт',
#  'test-784': 'дома',
#  'test-785': 'вроде',
#  'test-786': 'не',
#  'test-787': 'она',
#  'test-788': 'дома',
#  'test-789': 'было',
#  'test-790': 'волнуюсь',
#  'test-791': 'мишу',
#  'test-792': 'пушкино',
#  'test-793': 'чем',
#  'test-794': 'марксистская',
#  'test-795': 'твоего',
#  'test-796': 'коша',
#  'test-797': 'почему',
#  'test-798': 'чутка',
#  'test-799': 'пошли',
#  'test-800': 'сильно',
#  'test-801': 'за',
#  'test-802': 'это',
#  'test-803': 'дорогу',
#  'test-804': 'что',
#  'test-805': 'хочу',
#  'test-806': 'закажем',
#  'test-807': 'страдаю',
#  'test-808': 'нормально',
#  'test-809': 'нам',
#  'test-810': 'сегодня',
#  'test-811': 'ты',
#  'test-812': 'видео',
#  'test-813': 'если',
#  'test-814': 'ушла',
#  'test-815': 'потом',
#  'test-816': 'больше',
#  'test-817': 'хорошо',
#  'test-818': 'ну',
#  'test-819': 'об',
#  'test-820': 'покажу',
#  'test-821': 'знала',
#  'test-822': 'круто',
#  'test-823': 'черная',
#  'test-824': 'пью',
#  'test-825': 'него',
#  'test-826': 'только',
#  'test-827': 'на',
#  'test-828': 'там',
#  'test-829': 'вика',
#  'test-830': 'что',
#  'test-831': 'пока',
#  'test-832': 'старта',
#  'test-833': 'двери',
#  'test-834': 'есть',
#  'test-835': 'пожарить',
#  'test-836': 'за',
#  'test-837': 'зам',
#  'test-838': 'не',
#  'test-839': 'что',
#  'test-840': 'этот',
#  'test-841': 'только',
#  'test-842': 'пошел',
#  'test-843': 'где',
#  'test-844': 'давайте',
#  'test-845': 'помню',
#  'test-846': 'ей',
#  'test-847': 'спорю',
#  'test-848': 'модемов',
#  'test-849': 'принести',
#  'test-850': 'минуты',
#  'test-851': 'знаю',
#  'test-852': 'но',
#  'test-853': 'просто',
#  'test-854': 'просто',
#  'test-855': 'может',
#  'test-856': 'хочешь',
#  'test-857': 'не',
#  'test-858': 'быстрее',
#  'test-859': 'кейс',
#  'test-860': 'все',
#  'test-861': 'что',
#  'test-862': 'тони',
#  'test-863': 'знаете',
#  'test-864': 'понятно',
#  'test-865': 'проходят',
#  'test-866': 'ок',
#  'test-867': 'нечто',
#  'test-868': 'очень',
#  'test-869': 'полностью',
#  'test-870': 'та',
#  'test-871': 'работает',
#  'test-872': 'систему',
#  'test-873': 'участнику',
#  'test-874': 'это',
#  'test-875': 'над',
#  'test-876': 'потом',
#  'test-877': 'мы',
#  'test-878': 'ладно',
#  'test-879': 'думал',
#  'test-880': 'потом',
#  'test-881': 'легенда',
#  'test-882': 'маленькая',
#  'test-883': 'хватит',
#  'test-884': 'он',
#  'test-885': 'стало',
#  'test-886': 'знаем',
#  'test-887': 'смену',
#  'test-888': 'вы',
#  'test-889': 'кого',
#  'test-890': 'тебя',
#  'test-891': 'хахаха',
#  'test-892': 'она',
#  'test-893': 'уже',
#  'test-894': 'уснул',
#  'test-895': 'время',
#  'test-896': 'нет',
#  'test-897': 'чтобы',
#  'test-898': 'была',
#  'test-899': 'ок',
#  'test-900': 'бальзам',
#  'test-901': 'привет',
#  'test-902': 'при',
#  'test-903': 'че',
#  'test-904': 'всех',
#  'test-905': 'закончил',
#  'test-906': 'сможет',
#  'test-907': 'привет',
#  'test-908': 'здравствуйте',
#  'test-909': 'мой',
#  'test-910': 'дому',
#  'test-911': 'ок',
#  'test-912': 'первые',
#  'test-913': 'нет',
#  'test-914': 'потому',
#  'test-915': 'сделал',
#  'test-916': 'пентаграмма',
#  'test-917': 'вот',
#  'test-918': 'он',
#  'test-919': 'почему',
#  'test-920': 'видео',
#  'test-921': 'нет',
#  'test-922': 'ты',
#  'test-923': 'работал',
#  'test-924': 'спросить',
#  'test-925': 'не',
#  'test-926': 'мне',
#  'test-927': 'договорились',
#  'test-928': 'делаешь',
#  'test-929': 'да',
#  'test-930': 'хочешь',
#  'test-931': 'отказали',
#  'test-932': 'спайдер',
#  'test-933': 'про',
#  'test-934': 'ехать',
#  'test-935': 'вы',
#  'test-936': 'не',
#  'test-937': 'им',
#  'test-938': 'пацаны',
#  'test-939': 'идут',
#  'test-940': 'если',
#  'test-941': 'вот',
#  'test-942': 'меньше',
#  'test-943': 'шари',
#  'test-944': 'слава',
#  'test-945': 'дам',
#  'test-946': 'оказывается',
#  'test-947': 'через',
#  'test-948': 'объект',
#  'test-949': 'книжки',
#  'test-950': 'дим',
#  'test-951': 'кажется',
#  'test-952': 'не',
#  'test-953': 'тебя',
#  'test-954': 'все',
#  'test-955': 'забудь',
#  'test-956': 'ирина',
#  'test-957': 'какое',
#  'test-958': 'никаких',
#  'test-959': 'бедности',
#  'test-960': 'ян',
#  'test-961': 'просить',
#  'test-962': 'до',
#  'test-963': 'узнай',
#  'test-964': 'просто',
#  'test-965': 'скинь',
#  'test-966': 'не',
#  'test-967': 'нет',
#  'test-968': 'кусту',
#  'test-969': 'сейчас',
#  'test-970': 'ты',
#  'test-971': 'хрень',
#  'test-972': 'только',
#  'test-973': 'должен',
#  'test-974': 'же',
#  'test-975': 'соня',
#  'test-976': 'стало',
#  'test-977': 'читало',
#  'test-978': 'придет',
#  'test-979': 'ой',
#  'test-980': 'та',
#  'test-981': 'подгузники',
#  'test-982': 'сергеевич',
#  'test-983': 'не',
#  'test-984': 'ником',
#  'test-985': 'телефон',
#  'test-986': 'придется',
#  'test-987': 'пиво',
#  'test-988': 'какой',
#  'test-989': 'ну',
#  'test-990': 'которая',
#  'test-991': 'был',
#  'test-992': 'куку',
#  'test-993': 'что',
#  'test-994': 'на',
#  'test-995': 'покажи',
#  'test-996': 'но',
#  'test-997': 'это',
#  'test-998': 'живу',
#  'test-999': 'нее',
#  ...}

# %%
encoded = {u: tokenizer.encode(v, out_type="immutable_proto") for u, v in weak_sup_test.items()}

# %%
with open(f"exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.piece", "w") as f:
    f.write(''.join([f"{u} " + " ".join(e.piece for e in line.pieces) + '\n' for u, line in encoded.items()]))
with open(f"exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.int", "w") as f:
    f.write(''.join([f"{u} " + " ".join(str(e.id) for e in line.pieces) + '\n' for u, line in encoded.items()]))

# %%
# !head exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.piece
# !head exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.int
# Out:
# test-0 ▁на
# test-1 ▁что
# test-2 ▁о по з да ни я
# test-3 ▁сколько
# test-4 ▁д рем а ть
# test-5 ▁не
# test-6 ▁как
# test-7 ▁са до во д
# test-8 ▁за м ет и л
# test-9 ▁ва ги
# test-0 33
# test-1 69
# test-2 11 179 484 53 48 487
# test-3 400
# test-4 9 360 468 23
# test-5 17
# test-6 27
# test-7 236 107 55 477
# test-8 37 480 30 472 476
# test-9 218 211

# %%
#!cat exp/bpe500/valid-text.int exp/models/transformer_sc/lightning_logs/version_50424998/test.int >  exp/models/transformer_sc/lightning_logs/version_50424998/valid_test.int

# %%
finetune_ds = FeatsIterableDatasetV2([f"ark:data_feats/test/feats.ark"], 
                                targets_rspecifier='ark:exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.int', 
                                shuffle=False,
                                bos_id=1, 
                                eos_id=2,
                                batch_first=False)
finetune_dataloader = torch.utils.data.DataLoader(finetune_ds, 
                                             batch_size=24,
                                             #num_workers=2, 
                                             collate_fn=finetune_ds.collate_pad)
# Out:
# 2023-11-11 15:24:19,952 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:44 - INFO - Loading targets from ark:exp/models/t_finetune_test/lightning_logs/version_50454149/v10.test.int
# Loading targets...: 0it [00:00, ?it/s]

# %%
model = TransformerWithSinPos(feats_dim=37, num_tokens=500)
pl_module = SwipeTransformerRecognizer.load_from_checkpoint('exp/models/transformer_sc/lightning_logs/version_50424998/checkpoints/last.ckpt',backbone=model, map_location='cpu' )
#pl_module = SwipeTransformerRecognizer.load_from_checkpoint('exp/models/t_finetune_with_sa/lightning_logs/version_50448424/checkpoints/last.ckpt',backbone=model, map_location='cpu' )
pl_module.hparams.learning_rate = 1e-5
# Out:
# PositionalEncoding shape is torch.Size([400, 1, 512])

# %%
trainer = pl.Trainer(max_epochs=2, log_every_n_steps=100, reload_dataloaders_every_n_epochs=1,
                    default_root_dir='exp/models/t_finetune_test',
                    callbacks=[pl.callbacks.TQDMProgressBar(refresh_rate=100),
                              pl.callbacks.ModelCheckpoint(#every_n_train_steps=10000,
                                                          save_last=True)],
                    accumulate_grad_batches=8, # )
                    #val_check_interval=20000)
                    check_val_every_n_epoch=10)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(pl_module, finetune_dataloader, val_dataloader)
# Out:
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:612: UserWarning: Checkpoint directory exp/models/t_finetune_test/lightning_logs/version_50454149/checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type                  | Params
# ---------------------------------------------------
# 0 | backbone | TransformerWithSinPos | 44.7 M
# 1 | ce_loss  | CrossEntropyLoss      | 0
# ---------------------------------------------------
# 44.7 M    Trainable params
# 0         Non-trainable params
# 44.7 M    Total params
# 178.690   Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: 0it [00:00, ?it/s]
# 2023-11-11 15:27:16,929 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/utilities/data.py:120: UserWarning: Your `IterableDataset` has `__len__` defined. In combination with multi-process data loading (when num_workers > 1), `__len__` could be inaccurate if each worker is not configured independently to avoid having duplicate data.
#   rank_zero_warn(
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# 2023-11-11 15:27:16,973 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/test/feats.ark
# 2023-11-11 15:27:53,393 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/test/feats.ark
# `Trainer.fit` stopped: `max_epochs=2` reached.

# %%
trainer.test(pl_module, val_dataloader)
# [{'test_loss': 0.12403599917888641}]
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# SLURM auto-requeueing enabled. Setting signal handlers.
# /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/anaconda/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, test_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing: 0it [00:00, ?it/s]
# 2023-11-11 15:28:33,450 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │    0.29372653365135193    │
# └───────────────────────────┴───────────────────────────┘
# [{'test_loss': 0.29372653365135193}]

# %%
valid_u2w, valid_u2l = pl_module.cuda().predict_topk(val_dataloader, tokenizer=tokenizer, topk=8)
valid_lv = limit_vocab(valid_u2w)
accuracy(valid_ref_u2w, {u: v[0] if len(v) else '' for u, v in valid_lv.items()})
# v9 total=10000 corr=8750 err=1250, accuracy: 0.875
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 2023-11-11 15:29:48,703 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/valid/feats.ark
# 2023-11-11 15:31:42,524 root /tmp/ipykernel_1214228/1821149600.py:112 - WARNING - tgt_ready is 0 for valid-3855. tgt.shape=torch.Size([27, 8]). Use all hyps as ready hyps
# 2023-11-11 15:33:33,478 root /tmp/ipykernel_1214228/1821149600.py:112 - WARNING - tgt_ready is 0 for valid-7606. tgt.shape=torch.Size([27, 8]). Use all hyps as ready hyps
# 2023-11-11 15:34:43,803 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-320' doesn't have any vocab hyp. v=['агркина', 'агрокина', 'агрина', 'агретна', 'агрекина', 'агкина', 'агруппина', 'агрутна', 'агркинал', 'агркинан']
# 2023-11-11 15:34:43,804 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-433' doesn't have any vocab hyp. v=['заречь', 'зарегать', 'зареченность', 'зареченами', 'заречет', 'заречетать', 'зареченными', 'зареченным']
# 2023-11-11 15:34:43,806 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-773' doesn't have any vocab hyp. v=['бегуер', 'бегур', 'бегурово', 'бегурок', 'бегер', 'бегурует', 'бегуром', 'безупре']
# 2023-11-11 15:34:43,809 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-1131' doesn't have any vocab hyp. v=['вистановать', 'вистиновать', 'висимовать', 'вистановить', 'висторговать', 'вистановат', 'висторонность', 'вью-новать', 'висторонновать', 'вью-ново']
# 2023-11-11 15:34:43,813 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-1606' doesn't have any vocab hyp. v=['камуди', 'камулист', 'камулять', 'камуляж', 'камудия', 'камудись', 'камуляр', 'камудин']
# 2023-11-11 15:34:43,815 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-2106' doesn't have any vocab hyp. v=['вирталия', 'вирталями', 'вирталья', 'вирталиям', 'вирталям', 'виртальями', 'виртальям', 'вирталиями', 'виталями']
# 2023-11-11 15:34:43,817 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-2330' doesn't have any vocab hyp. v=['омун', 'лицен', 'лицену', 'омуг', 'лицена', 'лицент', 'лицев', 'омугур']
# 2023-11-11 15:34:43,819 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-2830' doesn't have any vocab hyp. v=['водонагревательно', 'волганировательно', 'волганивательно', 'водонагнально', 'вологагревально', 'водонагнального', 'вологант', 'волгангевально', 'вологантер', 'волгангеватель']
# 2023-11-11 15:34:43,822 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-3800' doesn't have any vocab hyp. v=['вк вк', 'век вк', 'вк вк вк', 'вк вк вк вк', 'вк вк вк вк вк', 'вк вк вкаку', 'вк вк вк вк вк вк', 'вк вк вк вкаку', 'вк вк вк вк вкак']
# 2023-11-11 15:34:43,823 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-3855' doesn't have any vocab hyp. v=['ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве ве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве ве ве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве ве ве ве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве ве ве ве ве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве ве ве ве ве ве', 'ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве ве веве ве ве ве ве ве ве']
# 2023-11-11 15:34:43,825 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-4091' doesn't have any vocab hyp. v=['но но но но но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но', 'но но но но но но но но но но но но']
# 2023-11-11 15:34:43,826 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-4318' doesn't have any vocab hyp. v=['каменьками', 'камению', 'каменька', 'каменькарти', 'каменьки', 'каменьшая', 'каменькарск', 'каменькартом', 'каменькартов', 'каменькартин', 'каменькартова', 'каменька-ню']
# 2023-11-11 15:34:43,828 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-4764' doesn't have any vocab hyp. v=['галяйд', 'галяцию', 'галяция', 'галяцел', 'галяцион', 'галяйл', 'налянул', 'галяцев']
# 2023-11-11 15:34:43,831 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-5830' doesn't have any vocab hyp. v=['жененененененененененененен', 'женененененененененененененен', 'жененененененененененененененен', 'женененененененененененененененен', 'жененененененененененененененененен', 'женененененененененененененененененен', 'жененененененененененененененененененен', 'женененененененененененененененененененен']
# 2023-11-11 15:34:43,834 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-6511' doesn't have any vocab hyp. v=['но но но но но но но но но но но но но', 'но но но но но но но но но но но но', 'но но но но но но но но но но но', 'но но но но но но но но но но', 'но но но но но но но но но', 'но но но но но но но но', 'но но но но но но но', 'но но но но но но']
# 2023-11-11 15:34:43,835 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-6637' doesn't have any vocab hyp. v=['завоттеление', 'заворотление', 'завотлетние', 'завотеление', 'завотледение', 'завотлешение', 'завотделение', 'завотлетение']
# 2023-11-11 15:34:43,837 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-7412' doesn't have any vocab hyp. v=['сарусейн', 'сарусей', 'сарусцев', 'сарусе', 'саручке', 'сарусель', 'саручек', 'маручен', 'сарусце']
# 2023-11-11 15:34:43,838 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-7606' doesn't have any vocab hyp. v=['не не не не не не не не не не не не не не не не не не не не не не не не не не', 'не не не не не не- не не не не не не не не не не не не не не не не не не не', 'не не не не не не не- не не не не не не не не не не не не не не не не не не', 'не не не не не- не не не не не не не не не не не не не не не не не не не не', 'не не не не- не не не не не не не не не не не не не не не не не не не не не', 'не не не- не не не не не не не не не не не не не не не не не не не не не не', 'не не- не не не не не не не не не не не не не не не не не не не не не не не', 'не- не не не не не не не не не не не не не не не не не не не не не не не не']
# 2023-11-11 15:34:43,840 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-8569' doesn't have any vocab hyp. v=['россортина', 'россортинажная', 'россионажна', 'россионажная', 'россионадная', 'россионадна', 'россортинажна', 'россионад', 'россортинажный', 'россортнад']
# 2023-11-11 15:34:43,841 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-8621' doesn't have any vocab hyp. v=['волькович', 'вольковаться', 'волькнович', 'валькович', 'вольковая', 'вадикович', 'алькервич', 'алькервия']
# 2023-11-11 15:34:43,843 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='valid-9293' doesn't have any vocab hyp. v=['реколол', 'реколо', 'рекололо', 'рекололол', 'реколола', 'рекололь', 'реколололо', 'реколодо', 'реколоо']
#   0%|          | 0/10000 [00:00<?, ?it/s]
# геев гены
# была басса
# рам нам
# да да-да
# что что-то
# шакалов заказы
# воля волосы
# ура уля
# корень удачного
# купи курс
# из из-за
# говорить говорит
# водитель водителю
# мед инд
# вечером вечер
# фиолетовой фиолетовое
# со сол
# выехал выезжать
# мы ивы
# выздоравливай выдавливай
# черна черны
# выгуливать выгулять
# сорян славян
# вызовов вызвала
# пробовал побор
# же желе
# стать стараюсь
# ха за
# русскому русском
# ок оке
# мазок мажора
# то ото
# не на
# обувь обед
# завтра заработать
# он лон
# никогда никого
# не неа
# был было
# баба батута
# пойми пофиг
# не нее
# не нее
# кто кто-то
# кн нечего
# виде видел
# не нее
# андреевна анжела
# прошу проще
# дура дулов
# ск скак
# агапкина
# ниже нижнее
# верон вероника
# анадырь аналогию
# лада ладно
# заберем забери
# завтра звоню
# не нее
# тыс там
# стоит строит
# выбил футболка
# не нее
# пик питу
# прошел пошел
# романович романтичная
# глав главное
# работы работаю
# доллар дождусь
# не нее
# занимаешься
# жень день
# приветик привет
# мм ммм
# выглядят выглядит
# крот корот
# потому помиримся
# что что-то
# не нее
# привете привет
# не нее
# ест есть
# во вопрос
# лежит делись
# дека днем
# да да-да
# ту туту
# екб куб
# же желе
# прожить пожить
# марин марии
# подпрыгнул продолжаешь
# знаю знают
# не нее
# лай дай
# был было
# проспект приятного
# вы вый
# считал считай
# нами наст
# ну не
# система систем
# проснулась проснулся
# но нот
# заварили звонили
# понятно понятного
# наказаний наказывай
# ок окей
# выход выходи
# мине минера
# пе пепе
# здорова здорово
# мерк мерку
# забей заберу
# лэйбл любой
# ска скака
# что что-то
# билет билеты
# поверить поворот
# виза ариша
# скользко сколько
# бать брат
# что что-то
# спасителя спасибо
# все вместе
# души луги
# зажимают задерживаю
# бугун
# запах зараза
# вот вот-вот
# эволюцию эволюция
# уговорить уговорил
# реабилитироваться реабилитировать
# пеши решим
# ишачий играй
# не на
# попил платил
# работать работает
# др дорого
# подложку положу
# что что-то
# полнейшей полнейший
# не нее
# бел бед
# не нее
# анаста анастасия
# дела делала
# норм ели
# вернуть вернут
# девиз делать
# ка как
# он один
# мм ммм
# моей мой
# др дорого
# береги берем
# так та
# россию ростом
# ну ней
# рулит рулить
# мозгов можно
# ваз вах
# до дор
# двум драки
# будет будем
# махровый мажоры
# оно одно
# бан баг
# что что-то
# такое точно
# каток каталась
# хотин хотите
# бе бее
# не нее
# попасть плачь
# парк правок
# он одного
# го ого
# не нее
# лох плохо
# привожу приводу
# вам вас
# по попробую
# сопьюсь сопьются
# муму сумму
# давай двойка
# то ото
# иди или
# зарплату характер
# сиди сидим
# восстановить
# убила удобно
# ха-ха захар
# вон волн
# да да-да-да
# чехова чехол
# час часам
# ну не
# деградирующая легендарная
# ся мя
# вкус вкусу
# антоном антон
# не нее
# состав составы
# вы вый
# нас нам
# ромку россии
# ли лилии
# или идеи
# сожалению сожелению
# говоря говорят
# шорты готовы
# нравиться нравится
# выбивается выберемся
# мыть рыбы
# то ото
# сообщили сообщишь
# наименований наименование
# он одной
# кинула кинуло
# приливов приливы
# не нее
# отдыхаешь отдыхать
# из их
# то ото
# входная взрослая
# древняя деревня
# сигну смогу
# не нее
# снов серв
# называется назначения
# не нее
# глазам глаза
# хахаха хахахаха
# скачать скучать
# чей чай
# готовить готовиться
# удава удар
# про по
# стикер сбер
# блин болин
# что что-то
# супер скорее
# ахах ахахах
# до дол
# ахаха ахахах
# по попробую
# не нее
# насыпала насыпка
# луж дед
# что что-то
# да да-да
# любую глеб
# зарабатывали заработал
# не нее
# присел примерно
# замечательное замечать
# чет черт
# знаю загадаю
# не нее
# что что-то
# срочно солнышко
# радиатор работать
# жак дак
# сетку сестру
# не нее
# приходит приходи
# калл калла
# нк нее
# яр яро
# намного настроение
# хай зай
# сек сану
# поспи поспал
# давным дыня
# кайфовать
# уже уле
# уже удобно
# большее больше
# он один
# произведение произвели
# се себе
# ок оке
# попадаются попадают
# идеей идей
# проверять проверяю
# да да-да
# пупка пупсика
# из из-за
# папа пара
# встретимся встретиться
# конца конечно
# не нее
# здарова здорово
# если ели
# хз хахах
# ок оке
# гудят гулять
# белы белый
# вшивая вторая
# умеет кинет
# заявкам зачем
# ном нос
# не неа
# ахах ахахах
# то точно
# разрешил разрешили
# брюшной большое
# разная развелся
# не нее
# ли дили
# будут будет
# случае солнце
# кп квартира
# сливаю сливать
# не нее
# уж ужас
# вот аль
# звонил занимаешься
# то ото
# мыслями мысля
# не нее
# понедельник поедет
# призывников праздником
# жесть знаю
# то ото
# колдуешь коллеги
# покупку покупай
# тобой ильей
# мда мода
# мин мне
# каре капок
# выбил выбить
# созвучия созвонимся
# две даче
# ок оке
# не нее
# смотала смотрела
# классный кассовый
# вот ворот
# гости госта
# обезболивающие обезболивающее
# удалила кидали
# крошка кошка
# не нее
# походом похожи
# читов чтобы
# мам мама
# меня песня
# что что-то
# ок оке
# или иди
# представляю представлю
# то ото
# напала напал
# ахах ахахах
# то ото
# акк аккаунт
# зашить хочешь
# кто кто-то
# научится научиться
# школьники школьном
# ок оке
# кто-то кто
# что что-то
# виталия
# пс пасс
# не нее
# то ото
# няней начинай
# не нее
# во вопрос
# одни один
# дилшод жизнь
# ветчина внимание
# то ото
# балл бал
# домой зимой
# подали продали
# эдит жить
# цирк цирки
# толик только
# гнут гут
# лежишь решишь
# ладно залет
# фу фу-фу
# игре игру
# девушка девушку
# встретимся встретим
# сердечко сердце
# любовь люблю
# ка как
# кто утро
# ул удобно
# ма иа
# он оке
# убрать уезжать
# теперь таню
# не ну
# или иди
# брать бояться
# приехали приезжай
# это жизнь
# авито авто
# перестанет перестал
# клан классно
# лице
# рф раф
# делать доедать
# нормалек нормальнее
# дорогостоящие дорогие
# девкам девки
# ха за
# не нее
# не нее
# нет него
# стене стена
# что что-то
# то итог
# пороге порогу
# хороших хорошо
# будут буду
# да да-да
# же деле
# хахах хахаха
# знакомых занимаешься
# фрик факту
# оставьте остаться
# объяснений объясни
# появилась появился
# не нее
# ок окей
# спасибо спать
# не нее
# россии россия
# таки тупи
# далеко далее
# опал орал
# есть кси
# аккорды аккорда
# то ото
# сказать чехол
# горит готовить
# дразнишься дозвонишься
# щенка зеленка
# бе теле
# ду душу
# ну ней
# ахаха ахахах
# читаю стирал
# тетя тебя
# им ммм
# выключи выключить
# делала делаешь
# плохое попозже
# дело деньги
# фролов фолов
# машину машины
# авито авто
# может идет
# еда нда
# помогу потому
# он одного
# цезарь узнать
# забиваю заработать
# надо над
# не нее
# счастьем счастье
# замерим заменим
# во вопрос
# сч ся
# печорина ресторана
# сказали скажи
# не нее
# бахает базарит
# что что-то
# самсонова самогона
# мен медленно
# данилом данила
# вор вопрос
# дочь достать
# старая старым
# энди этом
# нормальное нормальнее
# работу работе
# считается считает
# водонагреватель
# братцы батуты
# он одного
# да дыры
# ухе узнаешь
# не нее
# забыл забирать
# оно одно
# абу аптеку
# эту этом
# почитай поставят
# пеги решим
# ей ней
# отошел отвечаешь
# фото фото-то
# про по
# ха за
# не нее
# фото фото-то
# гас щас
# кто кто-то
# ил или
# что что-то
# но нот
# ок оке
# делай дней
# не нее
# на га
# ее елена
# было отдала
# чушь чувствуешь
# ок окей
# максимальном максимально
# угу агу
# математика материка
# ко коко
# есть ест
# но нот
# до да
# хм хи
# что что-то
# поселок командировку
# германии геометри
# нечего ничего
# сделать сдать
# вы вый
# надеж надежда
# ахаха ахахах
# доброй добрый
# маг маз
# до додо
# за ха
# кофточку кофту
# не нее
# значки заявки
# пешим решим
# ввиду вижу
# та трав
# исключим искренним
# температур температура
# самара самый
# треню тень
# без тез
# кто кто-то
# что что-то
# вы авы
# да дака
# нормативы нормы
# не нее
# юбилейной билетной
# ответственно ответствен
# красне краснее
# говорю говорить
# что что-то
# нета нету
# дворе двое
# просила послала
# спорт сорт
# что что-то
# горы года
# трест тесте
# любим любимая
# во вол
# служило сделал
# да для
# сидел силе
# фотку формула
# аванс пароль
# на га
# на га
# альба адидас
# что что-то
# ок окей
# снюс себя
# была было
# знаешь здесь
# не нее
# наступающим наступишь
# кармане картинка
# ей ну
# не нее
# тебе телеге
# съездить сбежать
# не нее
# спокойнее справляйся
# мен мене
# не на
# вставил вставать
# ждать жрать
# менде медленно
# ахах ахахах
# брюнетку брюками
# имя ия
# приехать приехал
# не нее
# не нее
# ан анна
# спросить спортом
# жесть одевать
# овен равно
# чем вес
# че чечен
# стоят стоя
# не нее
# му мк
# земельный землей
# завтрак забрала
# не нее
# не нее
# детройт дельфин
# продавал подруга
# специалиста специально
# от отто
# требований требование
# димуль дискорд
# но едет
# кузьмина евгений
# что что-то
# см ммм
# климент удивить
# мама маму
# показывают показать
# уж ужен
# не нее
# космо кем-то
# положить положу
# превысил первыми
# питере пионер
# по под
# что что-то
# придешь приедешь
# варик вариант
# это этот
# овощей окей
# деле лебеде
# случится случиться
# денег леше
# от ооо
# альбом адрес
# отличник отличное
# промо после
# денег деген
# да да-да-да
# чемпионом чемпион
# успех успехи
# пан папа
# во вол
# мной можно
# тц ту
# назвали назначает
# вк
# заметила замена
# до додо
# бы ты
# изо из-за
# осталась осталось
# задержка забуду
# да да-да
# щас зачем
# документы другие
# озера озеру
# не нее
# не нее
# вк
# го одного
# до да
# мне мене
# встать вставать
# пожалуйста продайте
# на га
# ален алене
# подзатыльник пожалуйста
# или иди
# не нее
# про по
# капец карев
# туч трус
# му су
# не на
# тебе инете
# ранг ранга
# раза разве
# кто кто-то
# минут минутки
# крута крутая
# на рев
# че ян
# магната маргарита
# довела давно
# корейцы корейца
# ша ща
# не нее
# назвала название
# успеваю скрыть
# дочь даст
# вернусь вернуть
# хотя родится
# ку куку
# смыла ставлю
# но
# авы аву
# не нее
# не нее
# ок оке
# не нее
# иринка инка
# хочет хочешь
# вакуумные вкусные
# тосно точно
# хоро хорошо
# не нее
# две данные
# эм эс
# однокурсницы одноклассница
# получится волчки
# что что-то
# кто кто-то
# года голова
# сектор скинь
# сложно солнышко
# негр неге
# ато аил
# воды алы
# или иди
# не нее
# ранняя раня
# ок оке
# се себе
# камень-на-оби
# смолу смогу
# сама масса
# имея искусств
# нега негр
# пойдем пойдет
# речи речь
# закончили закончим
# не нее
# лариска дарина
# не нее
# котят удобрять
# что что-то
# кричи кричит
# написала нарисовала
# не нее
# не нее
# муза муха
# не нее
# не на
# сум сумка
# не нее
# мягко мягких
# прилетаете прилетает
# готово горел
# да да-да-да
# не нее
# нудна нужна
# салам салом
# люди жаба
# если есть
# хочу худой
# про по
# го ого
# разорвало раздавало
# под подряд
# конец колей
# он одного
# ну не
# направлении наработаешь
# ах азах
# оттепель откроешь
# начало начал
# света все-таки
# что что-то
# не нее
# хуже зелено
# таджикистан таджики
# се себе
# то ото
# видео видел
# казино козино
# пн правильно
# топ том
# не нее
# требуется треугольник
# тут тупи
# было был
# на га
# снов сена
# заказ зако
# сверхъестественного серьезно
# он один
# пожарить подпись
# хз хахахаха
# ив ива
# череп черепа
# внимания внимание
# двери дании
# наконец-то нации
# уж удобно
# кроссовки красавки
# галочкой
# наорала направлять
# единственное ездишь
# поменять поменяешь
# наверно наверное
# не нее
# пойдешь пойдет
# па папа
# не нее
# не нее
# хеппи херь
# душ друг
# холод холодно
# го ого
# трио три-то
# ковтун клубе
# уж удобно
# аз азах
# маленьких маленький
# обидел обидно
# павильоне пароле
# алисы полив
# памяти пасти
# похож подход
# комп компе
# присяги приятного
# сентября сестра
# что что-то
# брад бад
# фу пенные
# заряжается заражается
# раз разве
# топ топа
# бургер будет
# ок оке
# менее мнение
# наггетсы нашелся
# клиент едет
# призвание пришел
# вена вагона
# нас на
# про по
# подругой подруга
# ну гугу
# участок участке
# ух узнаешь
# банд баню
# ух узнаешь
# там таким
# объекте объект
# своим своими
# двухстороннем двухсторонний
# таких твоих
# что что-то
# катта ката
# над народ
# любом любим
# ипотеку ипотеке
# по алло
# человек чела
# лог лого
# аллохол плохо
# из из-за
# есть ест
# он одного
# буду буд
# такое твое
# что что-то
# не нее
# не нее
# блонд блинд
# кук куку
# мной могу
# уже увижу
# скок скорее
# не нее
# не нее
# выходит выходить
# хот хоть
# почитаю прочитаю
# ярмак ярма
# придете прилете
# оплате оплата
# района район
# не нее
# что что-то
# ом ос
# аз азах
# удлинитель водитель
# переделаем переделает
# ставок старые
# ок окей
# его угол
# про по
# ок окей
# бред тред
# лодки одет
# кто кто-то
# впереди вернешь
# отвезли отвези
# по пол
# посмотрим пособии
# норидж норд
# все-таки все
# единорога единое
# инк игру
# не нее
# ура уда
# же желе
# не нее
# гей шоу
# во вол
# твою работаю
# вы вый
# русской рублей
# инсайд инсайды
# бабуина бабушки
# кто кто-то
# буду будут
# возьми возьму
# курят кусал
# прослушал послушал
# предлагает предлагал
# не нее
# поль побью
# стоял стоят
# он один
# ели едет
# миф мой
# виде видел
# встретиться вспомнить
# дошло дорого
# ок окей
# кошмаров комаров
# расставлены расстановка
# попала пропадала
# стад стадо
# раз разве
# блюд люблю
# уж ужас
# тряпки тряпке
# предал предатель
# твои твоим
# то ото
# из из-за
# есть ест
# политикам плиткам
# опять отправят
# отвлекайте отвлекай
# го ого
# можно может
# но ноо
# под подряд
# брат трата
# веселее вселенные
# балан бригада
# церкви цена
# там так
# ок окей
# лан лага
# спряталась считалось
# папу пару
# взаимно админом
# схожу схоже
# постоянно последняя
# город голод
# оденьте одному
# знаю наю
# машине магните
# чем сем
# юля бюджет
# го ооо
# трезв тореза
# аптека аппетита
# удобно убери
# дома драм
# так тара
# ок оке
# катала катал
# лови дат
# не нее
# свершилось свершилась
# присылай привыкай
# банан бананан
# приват привет
# ахах ахахах
# кун кунг
# сегодня себя
# узнаешь узнает
# не нее
# жен
# че чечен
# хахаха хахахаха
# не нее
# разочарован разочаровала
# ко кол
# которой которые
# кто кто-то
# во вол
# почти прям
# бяка быка
# заходишь захочешь
# межрайонным международная
# моей мой
# что что-то
# или иди
# до да
# желаю делаю
# не нее
# фольсваген фольксваген
# ок оке
# эй жду
# бери берите
# оформляем оформляет
# ок оке
# выглядите выглядит
# твитом татом
# мам мама
# хз хахахаха
# что что-то
# за ща
# да дак
# то ото
# ты тв
# канала канада
# что что-то
# то ото
# лиц лицу
# что сто
# дают делают
# не нее
# менеджеру менеджере
# выиграл август
# звуковой закрывай
# мак су
# спекулятивной специальный
# вывелись вывесить
# мироточить миртом
# кв ев
# отгадали отдали
# скорее скоро
# кори корми
# работы оплата
# отсталый отсталой
# то ото
# скорее селен
# нашел нашего
# не нее
# александр александра
# крыльцо крыльца
# поел плед
# иди или
# не нее
# смыла смысл
# ванн ванна
# похвастаться позвать
# не на
# что что-то
# смс симс
# аксен аксенов
# му муму
# облегчить обменами
# выспаться выспался
# оставить оставь
# не нее
# смысла святой
# четверг сметан
# иле идее
# уходит уходить
# из из-за
# не нее
# не нее
# анют анюта
# интересно интересе
# печаль поняла
# фо форд
# адрес адресе
# то ото
# не нее
# то ото
# из из-за
# мин смирн
# не нее
# токо тонко
# икает ткань
# ничем очень
# се себе
# навигаторе неправильно
# ку куку
# что что-то
# дл дим
# брат брата
# не нечего
# не нее
# продаю продут
# обойдусь обойду
# не нее
# съезди страшно
# мерь мет
# он одного
# спросила спросите
# страшного страшно
# но ноо
# пап папа
# мертвая серия
# ок окей
# не нее
# сек санек
# больница больнице
# но
# садике садики
# ссориться смотря
# культ культура
# наше нашел
# воскресенье воспитатели
# ты та
# конечной конченый
# ман мана
# половины половина
# заварка заправка
# еловой новой
# ок окей
# дорой дорогой
# не нее
# до додо
# планировала планировал
# выборе выйдет
# боятся бесятся
# написал нарисовал
# ту туту
# завотделением
# вас вам
# ура уровень
# скороходов скорохода
# офигенный двигайся
# да да-да-да
# аргонавтов аппаратов
# свечи снять
# спокойной спокойно
# др да
# обзор общаться
# того ого
# хз хахаха
# скетч суета
# под пол
# вождения вождение
# не ну
# не нее
# что что-то
# что что-то
# ок окей
# ок окей
# ножом ножи
# выдержу выхожу
# александр александра
# ездил ездили
# вспомни вспомнить
# все всем
# вернут вернуть
# выдано выдан
# что что-то
# перерыл перевод
# силу сижу
# данила дарила
# терпеливее терпелива
# робот оборот
# пике пикник
# заявления зачарования
# пес песня
# франция франты
# так тапе
# живем живет
# те теле
# рим ним
# сосуды соскучился
# спасибо спрашивал
# умею америка
# сын сыны
# пил пилил
# км кам
# момент москва
# не нее
# сам саму
# видел видео
# неделе нужен
# хз хахахаха
# изменчивости изменению
# урожай кодой
# мамбо масло
# во вол
# удалила удала
# знакомств зеркала
# ок оке
# что что-то
# не нее
# не нее
# го ого
# было буду
# больше большое
# буру буду
# рукам руки
# другое другие
# моя идти
# следила сделал
# ха за
# тебе ребенок
# ли лили
# па папа
# сф мы
# штекера штукатура
# пе пепе
# не нее
# катридж кирилл
# директор живете
# занятия заняться
# заработал заработать
# дружбу дружба
# димой дмитрий
# знаем знании
# раздевала раздевалась
# не нее
# пойдет пойдут
# говорить говорит
# дора жоры
# гог ого
# копится копиться
# перезаписала переезжаем
# пк пака
# стою сб
# не нее
# ок оке
# именно медленно
# хочется хочет
# кисель кисел
# вес весна
# нурлан купал
# когда кеды
# дума думаю
# не нее
# глаза гараже
# вольтаж владимир
# что что-то
# не нее
# хорош хорошо
# нами наст
# то ото
# аренда поела
# как кан
# леша лещ
# то ооо
# себе честно
# русский русская
# появляется проявляется
# тайна тайга
# лада орала
# он один
# увезет увезти
# милаш позвонишь
# от отто
# октмо ответил
# сделана сделает
# вызвать вызови
# не нее
# запчасти запчастями
# цена угадай
# мартовские мартов
# шаманил шаманим
# нужно нужна
# ночи ночь
# не нее
# ростовом ростова
# испортить историю
# случайно
# расскажу рассказу
# не нее
# откроется откровения
# из их
# тандыра танцевал
# из из-за
# что что-то
# го ого
# алис алиса
# проиграть приготовила
# огромное оригинале
# сколько склад
# ха хахаха
# хиро хитро
# не нее
# игра игру
# буду буд
# апелляции апельсин
# подразделение подавление
# еду еде
# про по
# понятно понятном
# думаю детскую
# тебе третье
# им ммм
# не нее
# бод бодро
# кривда кричала
# подарки продает
# не нее
# офигеть двигать
# гм гиги
# про пол
# да даже
# это этого
# то ото
# дешевое дешевле
# придти пришли
# не
# нее не
# го ого
# на га
# поел поезд
# колер колени
# он одного
# что что-то
# по попробую
# тима типа
# вон вое
# стояк старые
# лена легче
# перед передел
# александров александр
# ка как
# не нее
# пополняют пополняются
# воскреснет воскресенье
# кровных кроватных
# не нее
# се себе
# то ото
# внимания внимание
# да да-да
# овощами рахмат
# успею успеваю
# мы иры
# не нее
# было был
# пап папа
# не на
# дома одам
# баран барана
# не нее
# цементом цементной
# будет будем
# подсолнечное подсолнечного
# обеда обедала
# разговаривать раздавать
# он они
# мне моне
# сони пони
# про пол
# выпало выпала
# то ото
# по пил
# он одного
# вдруг волосы
# не нее
# да дала
# посмотреть посидеть
# мам мама
# го ого
# что что-то
# сообщений союзный
# де деле
# аж поддержка
# пожалуйста пожалуйся
# звони заполни
# го ого
# про по
# прости помоюсь
# еду еще
# ассоциируюсь ассоциацию
# по пошла
# то точно
# народу наберу
# на га
# обтираться обираться
# не нее
# не нее
# гране грана
# стала стало
# просто нормально
# вечер вечно
# интересуется интересная
# не нее
# пока попу
# гдз глаз
# нс нас
# сон солнце
# проводов провод
# что что-то
# иди или
# графике график
# ваще важен
# сделала сделал
# кто кир
# быть бесить
# просто просит
# будешь будет
# было был
# гашека шашка
# не нее
# болеют болью
# нами нам
# технология технолог
# не нее
# врача воскресе
# это этот
# что что-то
# дают-бери далеко
# промыл помыл
# баб бабки
# ок оке
# не нее
# следующий сделаю
# интересно инсте
# говорю говори
# записал занимаешься
# он огонь
# то ото
# не нее
# не нее
# леш легенд
# режиссер режет
# работы работа
# сообщу ольгу
# нег неге
# сделаю можно
# прилетела придумал
# но нового
# прощаю подъезжаю
# люблю любовь
# обещаю общаюсь
# скин скинь
# гулять гуляю
# пошлое прошлое
# не нее
# то того
# ель едь
# узбекский унижай
# посмотри простом
# он одной
# приятно приятного
# не нее
# фиат фита
# нравится новости
# сестренка сестра
# та ты
# не нее
# не нечего
# хату зови
# нее не
# оке окну
# зоя злая
# крестить крепись
# не нее
# твоя таджик
# люби любит
# не нее
# существительные существенные
# ок оке
# влезет влезешь
# не нее
# хоп хора
# тепло терпеть
# давид дарил
# пластмассовые пластиковые
# роспотребнадзор
# мс мсс
# калеки калки
# дилер жидко
# ник никак
# ай ппц
# что что-то
# ку куку
# вылил формы
# валерьевич
# пойдешь пойду
# здравствуйте здарова
# то ото
# две дан
# мелочи мелочь
# класса карса
# будет бедер
# ок оке
# не нее
# це цену
# мне минера
# ну не
# ватт варит
# холод холодом
# да ща
# прошла пошла
# не нее
# то ото
# мечты сняты
# города годом
# видео видел
# было был
# булкой будкой
# алма алиса
# что что-то
# не нее
# денете ленте
# общения общаешься
# серым снесет
# тан банке
# не нее
# одежда одного
# не нее
# обращайся обращай
# до дол
# поста посмотрим
# не нее
# качки какие
# во вал
# опаздывай опаздываю
# отдал отдать
# ооо оператор
# полковником практиком
# не нее
# долго одного
# сказал сказать
# вот ворот
# налетят надеяться
# рассмеялся рассеялся
# ерундой ерунда
# не нее
# возьмем возьмет
# муз мух
# ниже нижнее
# не нее
# аст всю
# звонит звонить
# кеча участие
# пропадут попадет
# ха за
# факел фактор
# кака как
# шрам грам
# про пол
# если несли
# встаю встать
# да дак
# раз разве
# ножовка ножка
# не нее
# куп кур
# бед обед
# ясно что
# что что-то
# не нее
# общаюсь общаться
# не нее
# этим житься
# защищаться заниматься
# кто кто-то
# до дорого
# беларуси беларусь
# более болел
# венецианский верейский
# украинский украински
# возим водили
# учи уст
# согласна согласно
# не нее
# заходить защит
# не нее
# те теле
# расстраивайся расставайся
# поорет пораньше
# вот вали
# ля для
# завистливый зависимый
# ирина мормона
# ок окей
# не нее
# про по
# люк любое
# ян няня
# что что-то
# расстались реально
# двигается двигаться
# понравилось поговорю
# задать задам
# дед дел
# кто кто-то
# аз ахах
# что что-то
# занимаетесь занимайтесь
# ну не
# не нее
# бывало было
# быстрей быстрее
# восход восходом
# груш груз
# подстригаться подстроился
# ваш виз
# плевал плево
# пойдет пойду
# январь января
# рекорд
# ок окей
# жор это
# го ого
# кто кто-то
# хорошего хорошее
# сети смерти
# же эле
# хз хахах
# аза ахаха
# жкх желез
# ок окей
# ехать уехать
# понедельник поедем
# эд эл
# пф рф
# дизель жизнь
# чон сон
# под подряд
# начнет насте
# самую самолет
# военное военно
# то ото
# со сможешь
# турист турить
# что что-то
# морковкой московской
# вариантов вариант
# го ого
# помню помогаю
# не нее
# спасибо спасти
# что что-то
# картриджем катаем
# поискать поиски
# кто кто-то
# висит вита
# бессонница бессонницы
# вопросу волосы
# лол доллар
# те теле
# иметь ита
# переломе переживай
# что что-то
# не нее
# германа георга
# на га
# своих сах
# досвидос появился
# выскакивает высказал
# нас нет
# что что-то
# выходим выходи
# стену стану
# удачного классного
# арктик артема
# до додо
# ман манга
# что что-то
# де деле
# нет лет
# своей свое
# варик вариант
# вел ведер
# скажу скажешь
# не нее
# работать работаю
# продан план
# бы бывает
# на нас
# газ газа
# что что-то
# что что-то
# дул дуд
# твой травка
# не на
# повод провод
# что что-то
# приехал приезжай
# вика все
# его ешь
# выключен выкладывает
# не нее
# дочь дичь
# великолукский великолепный
# потерпи потерпишь
# неа на
# про по
# прости прост
# не нее
# то ото
# местом место
# подходит пожить
# легко леша
# ждет дет
# пола план
# ну не
# тебе теле
# проблемы проблем
# кто круто
# что что-то
# сказки сказали
# чет чем
# мы ива
# же эле
# был было
# сто что-то
# дочь дат
# тв ты
# хаз хахахаха
# поняла понравится
# худам худом
# этому живу
# наклейки наклейку
# эффект живет
# юра баба
# входящие входите
# total=10000 corr=8272 err=1728, accuracy: 0.8272
# 0.8272

# %%
test_u2w, test_u2l = pl_module.cuda().predict_topk(test_dataloader, tokenizer=tokenizer, topk=8)
test_lv = limit_vocab(test_u2w)
# Out:
# 0it [00:00, ?it/s]
# 2023-11-11 15:34:45,419 root /mnt/asr_hot/mitrofanov-aa/projects/chime7/chime7_stc_recipe/egs/it9/ya/maatool/data/feats_itdataset_v2.py:68 - INFO - Processing ark:data_feats/test/feats.ark
# 2023-11-11 15:35:21,218 root /tmp/ipykernel_1214228/1821149600.py:112 - WARNING - tgt_ready is 0 for test-1184. tgt.shape=torch.Size([27, 8]). Use all hyps as ready hyps
# 2023-11-11 15:38:22,579 root /tmp/ipykernel_1214228/1821149600.py:112 - WARNING - tgt_ready is 0 for test-7264. tgt.shape=torch.Size([27, 8]). Use all hyps as ready hyps
# 2023-11-11 15:39:39,096 root /tmp/ipykernel_1214228/1821149600.py:112 - WARNING - tgt_ready is 0 for test-9835. tgt.shape=torch.Size([27, 8]). Use all hyps as ready hyps
# 2023-11-11 15:39:43,776 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-187' doesn't have any vocab hyp. v=['ленен', 'лененен', 'ленененен', 'лененененен', 'ленененененен', 'лененененененен', 'ленененененененен', 'лененененененененен']
# 2023-11-11 15:39:43,782 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-960' doesn't have any vocab hyp. v=['яня', 'янян', 'ясняя', 'яняня', 'яняя', 'яняня', 'я ясняя', 'я ясня', 'янячная']
# 2023-11-11 15:39:43,783 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1002' doesn't have any vocab hyp. v=['рини', 'ринин', 'ринина', 'ринини', 'ринии', 'рининин', 'рининина', 'ринину', 'рининини', 'ри']
# 2023-11-11 15:39:43,783 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1037' doesn't have any vocab hyp. v=['вк вк вк вк вк вк', 'вк вк вк вк вк вк вк', 'вк вк вк вк вк вк вк вк', 'вк вк вк вк вк вк вк вк вк', 'вк вк вк вк вк вк вк вк вк вк', 'вк вк вк вк вк вк вк вк вк вк вк', 'вк вк вк вк вк вк вк вк вк вк вк вк', 'вк вк вк вк вк вк вк вк вк вк вк вк вк']
# 2023-11-11 15:39:43,784 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1045' doesn't have any vocab hyp. v=['кенке', 'кненке', 'кнке', 'кнен к', 'кенкеке', 'кен кенке', 'кн кенке', 'кн кен к', 'кен кен к', 'кнкен']
# 2023-11-11 15:39:43,785 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1184' doesn't have any vocab hyp. v=['но но но но но но но но но но но но но но но но но но но но но но но но но но', 'о но но но но но но но но но но но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но но но но но но но но но но но но о', 'но но но но но но но но но но но но но но но но но но но но но но но но о но', 'но но но но но но но но но но но но но но но но но но но но но но но о но но', 'но но но но но но но но но но но но но но но но но но но но но но о но но но', 'но но но но но но но но но но но но но но но но но но но но но о но но но но', 'но но но но но но но но но но но но но но но но но но но но о но но но но но']
# 2023-11-11 15:39:43,786 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1319' doesn't have any vocab hyp. v=['гостерика', 'госпориемка', 'гостериемка', 'госпитаемка', 'гостроиемка', 'гостиника', 'госпоринска', 'госпитарием']
# 2023-11-11 15:39:43,788 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1703' doesn't have any vocab hyp. v=['циклофен', 'цикоферон', 'цикофрон', 'циклоферн', 'цикоферн', 'цикофре', 'цикофрен', 'циклофеон', 'циклоферо']
# 2023-11-11 15:39:43,789 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-1905' doesn't have any vocab hyp. v=['гененененененененененененене', 'генененененененененененененене', 'генененененененененененене', 'гененененененененененененененене', 'генененененененененененененененене', 'гененененененененененененененененене', 'генененененененененененененененененене', 'гененененененененененененененененененене']
# 2023-11-11 15:39:43,790 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-2005' doesn't have any vocab hyp. v=['питервой', 'питеровой', 'пиервой', 'питеравой', 'питерай', 'питеревой', 'пивой', 'питератор']
# 2023-11-11 15:39:43,794 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-2678' doesn't have any vocab hyp. v=['денежежен', 'денежежжежже', 'жележеженжежен', 'жележежеженжежен', 'денежежжежжежже', 'жележеженжежжежен', 'жележежежеженжежен', 'жележежежежеженжежен']
# 2023-11-11 15:39:43,799 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-4095' doesn't have any vocab hyp. v=['йошкола', 'йошкеров', 'йошкой', 'йошки', 'йошкера', 'йошколад', 'цизкола', 'йошкерола', 'йошкарла']
# 2023-11-11 15:39:43,805 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-5806' doesn't have any vocab hyp. v=['гезетный', 'гезерный', 'гензетный', 'гнезетный', 'гещетный', 'гещестный', 'гещертный', 'геозерный']
# 2023-11-11 15:39:43,806 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-6130' doesn't have any vocab hyp. v=['тть', 'ттья', 'ттьи', 'ттью', 'ттьють', 'т тть', 'ттьть', 'ть', 'т ттьть', 'т т тть']
# 2023-11-11 15:39:43,807 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-6427' doesn't have any vocab hyp. v=['пкку', 'пкпу', 'пктуу', 'пкрук', 'пкпуу', 'пкук', 'пкрукпу', 'пккрук']
# 2023-11-11 15:39:43,808 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-6560' doesn't have any vocab hyp. v=['фиси', 'фисси', 'фисифи', 'фисиф', 'фисифис', 'фисифси', 'фиссифи', 'фисифс']
# 2023-11-11 15:39:43,809 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-6600' doesn't have any vocab hyp. v=['плеседо', 'плечело', 'полесело', 'полегчело', 'плесело', 'плеседок', 'алекседов', 'алекседо', 'александ', 'алекседол']
# 2023-11-11 15:39:43,811 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-7264' doesn't have any vocab hyp. v=['коло коло коло кол ко ко ко кол ко ко ко ко ко ко ко ко ко ко ко ко ко', 'коло коло коло кол ко ко ко ко кол ко ко ко ко ко ко ко ко ко ко ко ко', 'коло коло коло кол ко ко ко кол ко ко ко ко ко кол ко ко ко ко ко ко', 'коло коло коло кол ко ко ко ко ко ко ко кол ко ко ко ко ко ко ко ко ко', 'коло коло коло кол ко ко ко кол ко ко ко ко ко ко кол ко ко ко ко ко', 'коло коло коло кол ко ко ко кол ко ко ко ко ко ко ко кол ко ко ко ко', 'коло коло коло кол ко ко ко ко ко ко ко ко кол ко ко ко ко ко ко ко ко', 'коло коло коло кол ко ко ко кол ко ко ко ко ко ко ко ко ко ко ко кол']
# 2023-11-11 15:39:43,812 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-7769' doesn't have any vocab hyp. v=['перевокающее', 'первоказе', 'первокажен', 'перевокажде', 'перевокающей', 'первокажение', 'перевокружен', 'первокружен']
# 2023-11-11 15:39:43,813 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-7786' doesn't have any vocab hyp. v=['хелоун', 'хедруг', 'хедунг', 'хедоруг', 'хедун', 'хедуг', 'хеллоун', 'хелоунг', 'хедоун', 'хедоругло']
# 2023-11-11 15:39:43,814 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-8058' doesn't have any vocab hyp. v=['фондюк', 'флешде', 'фондэк', 'флегде', 'флешэк', 'флагелье', 'фондэкс', 'фондюшка', 'флагельд']
# 2023-11-11 15:39:43,815 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-8486' doesn't have any vocab hyp. v=['героз', 'герроз', 'герз', 'герозз', 'нероз', 'геррозз', 'георз', 'герозе']
# 2023-11-11 15:39:43,818 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-9411' doesn't have any vocab hyp. v=['ростановле', 'ростанавле', 'ростов-нале', 'ростов-налек', 'ростановлек', 'россивнале', 'ростанвлек', 'ростов-на-до']
# 2023-11-11 15:39:43,819 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-9717' doesn't have any vocab hyp. v=['щекоторы', 'щекоторые', 'щекотовая', 'зекотовая', 'щекоторым', 'щекотая', 'щекоторыя', 'щекотлова']
# 2023-11-11 15:39:43,819 root /tmp/ipykernel_1214228/554815814.py:9 - WARNING - k='test-9835' doesn't have any vocab hyp. v=['но но но но но но но но но но но но но но но но но но но но но но но но но но', 'о но но но но но но но но но но но но но но но но но но но но но но но но но', 'но но но но но но но но но но но но но но но но но но но но но но но но но о', 'но но но но но но но но но но но но но но но но но но но но но но но но о но', 'но но но но но но но но но но но но но но но но но но но но но но но о но но', 'но но но но но но но но но но но но но но но но но но но но но но о но но но', 'но но но но но но но но но но но но но но но но но но но но но о но но но но', 'но но но но но но но но но но но но но но но но но но но но о но но но но но']

# %%
baseline_result = pd.read_csv('./keyboard_start/result/baseline.csv', sep=',', names=['main', 'second', 'third', 'trash'])
#baseline_result = pd.read_csv('exp/models/ctc_trans/lightning_logs/version_50422251/test_submit.v1.csv', sep=',', names=['main', 'second', 'third', 'trash'])
#baseline_result = 
baseline_result['uid'] = [f'test-{i}' for i in range(len(baseline_result))]
baseline_result.head()

baseline_result['predict'] = baseline_result.uid.apply(lambda x: test_lv[x])
baseline_result.head()
rows = []
for i, row in baseline_result.iterrows():
    ps = row['predict']
    for p in [row['main'], row['second'], row['third'], row['trash']]:
        if p not in ps:
            ps.append(p)
    rows.append(ps[:4])
        
submission = pd.DataFrame(rows, columns=['main', 'second', 'third', 'trash'])
submission.to_csv("exp/models/t_finetune_test/lightning_logs/version_50454149/test_submit.v11.csv", 
                  sep=',', header=False, index=False)
submission.head()
# Out:
#         main     second       third       trash
# 0         на        нас        нана        нага
# 1        что     что-то         сто        чтоб
# 2  опоздания  опоздание  опозданиям   опозданий
# 3    сколько    скольки     сколько     столько
# 4    дремать   донимать    дописать  дюрренматт

# %%
import pandas as pd

# %%
baseline_result = pd.read_csv('exp/models/ctc_trans/lightning_logs/version_50422251/test_submit.v1.csv', sep=',', names=['main', 'second', 'third', 'trash'])
baseline_result['uid'] = [f'test-{i}' for i in range(len(baseline_result))]
baseline_result.head()
# Out:
#         main       second          third        trash     uid
# 0         на          неа             на        ненка  test-0
# 1        что        часто        частого        чисто  test-1
# 2  опоздания   опозданиям  оприходования  опозданиями  test-2
# 3    сколько  сокольского  свердловского      скроено  test-3
# 4    дремать     дописать       донимать   дюрренматт  test-4

# %%
baseline_result['predict'] = baseline_result.uid.apply(lambda u: test_lv[u])
baseline_result.head()
# Out:
#         main       second          third        trash     uid
# 0         на          неа             на        ненка  test-0  \
# 1        что        часто        частого        чисто  test-1
# 2  опоздания   опозданиям  оприходования  опозданиями  test-2
# 3    сколько  сокольского  свердловского      скроено  test-3
# 4    дремать     дописать       донимать   дюрренматт  test-4
#
#                                              predict
# 0                   [на, нас, нана, нам, неа, на-на]
# 1   [что, что-то, сто, чтоб, чисто, со, часто, чмок]
# 2  [опоздания, опоздание, опозданиям, опозданий, ...
# 3  [сколько, скольки, сколько, столько, только, с...
# 4                        [дремать, донимать, думать]

# %%
rows = []

for i, row in baseline_result.iterrows():
    ps = row['predict']
    for p in [row['main'], row['second'], row['third'], row['trash']]:
        if p not in ps:
            ps.append(p)
    rows.append(ps[:4])
        
submission = pd.DataFrame(rows, columns=['main', 'second', 'third', 'trash'])
submission.head()
# Out:
#         main     second       third      trash
# 0         на        нас        нана        нам
# 1        что     что-то         сто       чтоб
# 2  опоздания  опоздание  опозданиям  опозданий
# 3    сколько    скольки     сколько    столько
# 4    дремать   донимать      думать   дописать

# %%
submission.to_csv("exp/models/transformer_sc/lightning_logs/version_50424998/test_submit.v5.csv", 
                  sep=',', header=False, index=False)
